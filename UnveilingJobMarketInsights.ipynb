# %% [markdown]
# ## LDA Topic Model for Text Analysis

# %% [raw]
# In natural language processing, Latent Dirichlet allocation (LDA) is a generative statistical model that allows sets of observations to be explained by unobserved groups that explain why some parts of the data are similar. So this is categorized as unsupervised learning. For example, if observations are words collected into documents, it posits that each document is a mixture of a small number of topics and that each word’s presence is attributable to one of the document’s topics. LDA is an example of a topic model.

# %% [markdown]
# ## DATA COLLECTION USING WEBSCRAPING

# %%
# import libraries

import pandas as pd
import matplotlib.pyplot as plt
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By
import time
import warnings
warnings.filterwarnings('ignore')

# %%
# webdriver for Firefox - geckodriver
driver = webdriver.Chrome()

# sticky timeout to implicitly wait for an element to be found
driver.implicitly_wait(10) 

# open url in the browser
driver.get('https://www.naukri.com/')

# %%
# enter job role - data scientist
role=driver.find_element(By.XPATH,"//*[@id='root']/div[7]/div/div/div[1]/div/div/div/div[1]/div/input")
role.send_keys('big data')

# location - India
location=driver.find_element(By.XPATH,"//*[@id='root']/div[7]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys('')

# click search
driver.find_element(By.CLASS_NAME,'qsbSubmit').click()

# %%
# new dataframe fwith required columns
df=pd.DataFrame(columns=['Job_Role','Company','Location','Job Experience','Skills','Job_Description'])
df
# Out:
# Empty DataFrame
# Columns: [Job_Role, Company, Location, Job Experience, Skills, Job_Description]
# Index: []

# %%
# helper function

# Function to convert  a list to string
def listToString(s): 
    
    # initialize an empty string
    str1 = ", " 
    
    # return string  
    return (str1.join(s))

# %%
# %%time
from selenium.common.exceptions import NoSuchElementException

# Initialize the page number
page = 1

# Set the maximum number of pages to scrape
max_pages = 20

while page <= max_pages:
    try:
        # Scrape up to 20 results on the current page
        for i in range(1, 21):
            try:
                role = driver.find_element(By.XPATH, '//*[@id="root"]/div[4]/div/div/section[2]/div[2]/article[{}]/div[1]/div[1]/a'.format(i)).text
                company = driver.find_element(By.XPATH, '//*[@id="root"]/div[4]/div/div/section[2]/div[2]/article[{}]/div[1]/div[1]/div/a[1]'.format(i)).text
                location = driver.find_element(By.XPATH, '//*[@id="root"]/div[4]/div/div/section[2]/div[2]/article[{}]/div[1]/ul/li[3]/span'.format(i)).text
                experience = driver.find_element(By.XPATH, '//*[@id="root"]/div[4]/div/div/section[2]/div[2]/article[{}]/div[1]/ul/li[1]/span[1]'.format(i)).text.replace(' Yrs', '')
                job_description = driver.find_element(By.XPATH, '//*[@id="root"]/div[4]/div/div/section[2]/div[2]/article[{}]/div[2]'.format(i)).text
                skill_lst = driver.find_element(By.XPATH, '//*[@id="root"]/div[4]/div/div/section[2]/div[2]/article[{}]/ul'.format(i)).text.split('\n')
                skill = listToString(skill_lst)
                # Append collected information to the DataFrame df
                df.loc[len(df.index)] = [role, company, location, experience, skill, job_description]
            except NoSuchElementException:
                pass

        page += 1

        # Click the "Next" button
        try:
            nxt = driver.find_element(By.XPATH, '//*[@id="root"]/div[4]/div/div/section[2]/div[3]/div/a[2]')
            driver.execute_script("arguments[0].click();", nxt)
        except NoSuchElementException:
            print("No more pages to scrape. Exiting the loop.")
            break

    except Exception as e:
        print("An error occurred:", e)
        break
# Out:
# No more pages to scrape. Exiting the loop.
# CPU times: total: 0 ns
# Wall time: 3min 30s

# %%
df.shape
# Out:
# (0, 6)

# %%
df = df.drop_duplicates()

df.shape
# Out:
# (0, 6)

# %%
df.to_csv("big_data_roles.csv")

# %% [markdown]
# ## CHALLANGE 1 : BIG DATA JOB FAMILY IDENTIFICATION

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Maram
# [nltk_data]     Aashritha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
dfs=['business_analyst.csv','Hadoop_developer.csv','data_scientist.csv','data_engineer.csv']
df = pd.concat(map(pd.read_csv, dfs))
#df.to_csv("big_data_roles.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0                                           Job_Role  \
# 0           0          Merilytics - Business Analyst (Analytics)
# 1           1                             Stars Business Analyst
# 2           2                                   Business Analyst
# 3           3                                   Business Analyst
# 4           4                                   Business Analyst
# 5           5                                   Business Analyst
# 6           6     Job Opportunity For Guidewire Business Analyst
# 7           7                         Guidewire Business Analyst
# 8           8  Opening For Business Analyst Mumbai (Thane) Lo...
# 9           9                                   Business Analyst
#
#                        Company  \
# 0                   Merilytics
# 1                         Ford
# 2                   Isoftstone
# 3              NCR Corporation
# 4                      Regalix
# 5           In2IT Technologies
# 6  PwC Service Delivery Center
# 7  PwC Service Delivery Center
# 8                      Experis
# 9                       Turing
#
#                                             Location Job Experience  \
# 0                             Hyderabad/Secunderabad            0-2
# 1                                            Chennai            0-5
# 2  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...            0-5
# 3                             Hyderabad/Secunderabad           5-10
# 4                                             Remote            1-4
# 5              Noida, Uttar Pradesh(Noida Extension)            0-1
# 6  Hybrid - Hyderabad/Secunderabad, Bangalore/Ben...            3-5
# 7  Hybrid - Hyderabad/Secunderabad, Bangalore/Ben...            5-9
# 8                                 Mumbai (All Areas)            4-8
# 9  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...            2-3
#
#                                               Skills  \
# 0  excel, Business Analytics, Problem Solving, Da...
# 1  Training, Application support, Business Analys...
# 2  Automation, digital content, Business Analyst,...
# 3  Telecom, Hospitality, Business Analyst, Agile ...
# 4  Business Analytics, SQL, Business Analysis, Po...
# 5  Business Analytics, analytical, Requirement Ga...
# 6  Policy Administration, Casualty, Property, Bus...
# 7  Guidewire, Forms, Integration, Billing Center,...
# 8  business analysis, vendor management, Life Ins...
# 9  Product training, Automation, Usage, Business ...
#
#                                      Job_Description
# 0  (v) Cab reimbursement for women employees beyo...
# 1  Coordinate and / or deliver training to custom...
# 2  A Bachelors or Masters in Computer Science or ...
# 3  Along with the BA role, candidate should be ab...
# 4  Location: Bangalore/ Hyderabad ( Work From Hom...
# 5  Bachelors degree in Computer Science, Informat...
# 6  HiWe have an opportunity for Guidewire Busines...
# 7  Roles and Responsibilities of Business Analyst...
# 8  Dear Candidates , We are hiring for Mumbai loc...
# 9  Use data and analysis to support arguments for...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3757 entries, 0 to 978
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       3757 non-null   int64
#  1   Job_Role         3757 non-null   object
#  2   Company          3757 non-null   object
#  3   Location         3757 non-null   object
#  4   Job Experience   3757 non-null   object
#  5   Skills           3757 non-null   object
#  6   Job_Description  3757 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 234.8+ KB

# %%
df.shape
# Out:
# (3757, 7)

# %%
df['Job_Role'].nunique()
# Out:
# 1246

# %%
df['Job_Role']=df['Job_Role'].str.replace('[\'\/\-\(\)\|\||]','')

# %%
df['Job_Role'].unique()
# Out:
# array(['Merilytics - Business Analyst (Analytics)',
#        'Stars Business Analyst', 'Business Analyst', ...,
#        'Hiring GCP / Data Engineering Lead',
#        'Tech Lead - Data Engineering', 'Data Engineering Lead / SME'],
#       dtype=object)

# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Assuming your DataFrame is named 'df' and the column containing the text is named 'text_column'

# Load the NLTK English stopwords
stop_words = set(stopwords.words('english'))

# Define a function to remove stop words from a given text
def remove_stop_words(text):
    tokens = word_tokenize(text)  # Tokenize the text into individual words
    filtered_tokens = [word for word in tokens if word.lower() not in stop_words]  # Filter out stop words
    return ' '.join(filtered_tokens)  # Join the filtered tokens back into a string

# Apply the remove_stop_words function to the text_column and store the results in a new column
df['Job_Role'] = df['Job_Role'].apply(remove_stop_words)

# Display the resulting DataFrame with stop words removed
print(df['Job_Role'])
# Out:
# 0      Merilytics - Business Analyst ( Analytics )
# 1                           Stars Business Analyst
# 2                                 Business Analyst
# 3                                 Business Analyst
# 4                                 Business Analyst
#                           ...
# 974             Hiring GCP / Data Engineering Lead
# 975                             Lead Data Engineer
# 976                   Tech Lead - Data Engineering
# 977                    Data Engineering Lead / SME
# 978                             Lead Data Engineer
# Name: Job_Role, Length: 3757, dtype: object

# %%
import pandas as pd
from nltk import ngrams
from collections import Counter

# Assuming your DataFrame is named 'df' and the job title column is named 'job_title'

# Concatenate all job titles into a single string
all_titles = ' '.join(df['Job_Role'].values)

# Tokenize the job titles into individual words
tokens = all_titles.split()

# Generate all possible bigrams from the tokens
bigrams =  ngrams(tokens,2)
trigrams = ngrams(tokens,3)

# Count the occurrences of each bigram
bigram_counts = Counter(bigrams)
trigram_counts = Counter(trigrams)

# Sort the bigrams by their frequency count in descending order
sorted_bigrams = sorted(bigram_counts.items(), key=lambda x: x[1], reverse=True)
sorted_trigrams = sorted(trigram_counts.items(), key=lambda x: x[1], reverse=True)

# Display the sorted list of bigrams and their counts

# %%
for bigram, count in sorted_bigrams:
    print('Bigram:', bigram, 'Count:', count)
# Out:
# Bigram: ('Business', 'Analyst') Count: 907
# Bigram: ('Data', 'Engineer') Count: 884
# Bigram: ('Application', 'Developer') Count: 755
# Bigram: ('Analyst', 'Business') Count: 679
# Bigram: ('Data', 'Scientist') Count: 647
# Bigram: ('Engineer', 'Data') Count: 450
# Bigram: ('Developer', 'SAP') Count: 322
# Bigram: ('Scientist', 'Data') Count: 279
# Bigram: ('Senior', 'Data') Count: 187
# Bigram: ('Developer', 'Microsoft') Count: 167
# Bigram: ('Engineer', '-') Count: 107
# Bigram: ('Services', 'Application') Count: 102
# Bigram: ('Big', 'Data') Count: 97
# Bigram: ('Data', 'Services') Count: 97
# Bigram: ('Azure', 'Data') Count: 97
# Bigram: ('Microsoft', 'Dynamics') Count: 83
# Bigram: ('Scientist', 'Senior') Count: 82
# Bigram: ('SAP', 'ABAP') Count: 81
# Bigram: ('Engineer', 'Senior') Count: 73
# Bigram: (')', 'Application') Count: 70
# Bigram: ('Technical', 'Application') Count: 70
# Bigram: ('Scientist', '-') Count: 68
# Bigram: ('Hadoop', 'Developer') Count: 67
# Bigram: ('HANA', 'Application') Count: 67
# Bigram: ('-', 'Data') Count: 65
# Bigram: ('ABAP', 'Development') Count: 62
# Bigram: ('Development', 'Application') Count: 55
# Bigram: ('Lead', 'Data') Count: 55
# Bigram: ('Engineer', '(') Count: 54
# Bigram: ('Analyst', '-') Count: 53
# Bigram: ('Data', 'Science') Count: 53
# Bigram: ('Development', 'HANA') Count: 52
# Bigram: ('Microsoft', 'Azure') Count: 49
# Bigram: ('Java', 'Developer') Count: 48
# Bigram: ('Developer', 'Java') Count: 46
# Bigram: (')', 'Data') Count: 46
# Bigram: ('SAP', 'FI') Count: 44
# Bigram: ('Developer', 'Hadoop') Count: 43
# Bigram: ('Dynamics', '365') Count: 42
# Bigram: ('Data', 'Engineering') Count: 41
# Bigram: ('Finance', 'Application') Count: 39
# Bigram: ('Dynamics', 'CRM') Count: 34
# Bigram: ('CRM', 'Technical') Count: 34
# Bigram: ('Developer', '-') Count: 33
# Bigram: ('Full', 'Stack') Count: 33
# Bigram: ('SAP', 'Sales') Count: 33
# Bigram: ('Distribution', '(') Count: 33
# Bigram: ('(', 'SD') Count: 33
# Bigram: ('SD', ')') Count: 33
# Bigram: ('Sales', 'Distribution') Count: 32
# Bigram: ('Analyst', '(') Count: 31
# Bigram: ('Data', 'Developer') Count: 31
# Bigram: ('Manager', '-') Count: 30
# Bigram: ('Scientist', 'Lead') Count: 30
# Bigram: ('SAP', 'BusinessObjects') Count: 29
# Bigram: ('BusinessObjects', 'Data') Count: 29
# Bigram: ('Management', 'Application') Count: 29
# Bigram: ('FI', 'CO') Count: 29
# Bigram: ('CO', 'Finance') Count: 29
# Bigram: ('Sr.', 'Data') Count: 29
# Bigram: ('Developer', ':') Count: 28
# Bigram: ('Stack', 'Development') Count: 27
# Bigram: ('Engineer', 'Azure') Count: 27
# Bigram: (')', 'Business') Count: 26
# Bigram: ('365', 'ERP') Count: 26
# Bigram: ('ERP', 'Technical') Count: 26
# Bigram: (':', 'SAP') Count: 26
# Bigram: ('Snowflake', 'Data') Count: 25
# Bigram: ('Microsoft', 'SQL') Count: 24
# Bigram: ('SQL', 'Server') Count: 24
# Bigram: ('Scientist', '(') Count: 24
# Bigram: ('Engineer', 'Big') Count: 23
# Bigram: ('Engineering', 'Application') Count: 22
# Bigram: ('Data', 'Warehouse') Count: 21
# Bigram: ('Java', 'Full') Count: 21
# Bigram: ('Warehouse', 'Application') Count: 20
# Bigram: ('Power', 'BI') Count: 20
# Bigram: ('Developer', 'Data') Count: 19
# Bigram: ('SAP', 'CPI') Count: 19
# Bigram: ('/', 'Data') Count: 19
# Bigram: ('Developer', 'Advanced') Count: 19
# Bigram: ('Advanced', 'Embedded') Count: 19
# Bigram: ('Embedded', 'System') Count: 19
# Bigram: ('System', 'Engineering') Count: 19
# Bigram: ('Principal', 'Data') Count: 19
# Bigram: ('Machine', 'Learning') Count: 19
# Bigram: ('Analyst', 'BUSINESS') Count: 18
# Bigram: ('BUSINESS', 'ANALYST') Count: 18
# Bigram: ('Master', 'Data') Count: 18
# Bigram: ('CPI', 'Data') Count: 18
# Bigram: ('Developer', 'Snowflake') Count: 18
# Bigram: ('Platform', 'Application') Count: 18
# Bigram: ('SAP', 'Master') Count: 17
# Bigram: ('Data', 'Modeling') Count: 17
# Bigram: ('ANALYST', 'Business') Count: 16
# Bigram: ('Developer', 'Application') Count: 16
# Bigram: ('Lead', '-') Count: 16
# Bigram: ('-', 'Business') Count: 15
# Bigram: ('Developer', 'Big') Count: 15
# Bigram: ('Developer', 'Oracle') Count: 15
# Bigram: ('ABAP', 'HANA') Count: 15
# Bigram: ('Sr', 'Data') Count: 15
# Bigram: ('Scientist', '/') Count: 15
# Bigram: (',', 'Data') Count: 15
# Bigram: ('-', 'B2C') Count: 15
# Bigram: ('B2C', 'Underwriting') Count: 15
# Bigram: (')', '-') Count: 14
# Bigram: ('Developer', '/') Count: 14
# Bigram: ('Data', 'Governance') Count: 14
# Bigram: ('Governance', 'MDG') Count: 14
# Bigram: ('MDG', 'Tool') Count: 14
# Bigram: ('Tool', 'Application') Count: 14
# Bigram: ('Accounting', 'Application') Count: 14
# Bigram: ('Manufacturing', 'Engineering') Count: 14
# Bigram: ('Engineering', 'MES') Count: 14
# Bigram: ('MES', 'Application') Count: 14
# Bigram: ('FI', 'S/4HANA') Count: 13
# Bigram: ('Server', 'Integration') Count: 13
# Bigram: ('Integration', 'Services') Count: 13
# Bigram: ('Services', 'SSIS') Count: 13
# Bigram: ('SSIS', 'Application') Count: 13
# Bigram: ('Microsoft', 'Power') Count: 13
# Bigram: ('Developer', 'Manufacturing') Count: 13
# Bigram: ('Research', 'Scientist') Count: 13
# Bigram: ('Data', 'Engineers') Count: 13
# Bigram: ('Senior', 'Big') Count: 12
# Bigram: ('Functional', 'Application') Count: 12
# Bigram: ('S/4HANA', 'Accounting') Count: 12
# Bigram: ('Junior', 'Data') Count: 12
# Bigram: ('Science', 'Data') Count: 12
# Bigram: ('Associate', 'Data') Count: 12
# Bigram: ('-', 'Machine') Count: 12
# Bigram: ('Python', 'Data') Count: 12
# Bigram: ('Data', 'engineer') Count: 12
# Bigram: ('Software', 'Engineer') Count: 11
# Bigram: (')', 'Senior') Count: 11
# Bigram: ('Administration', 'Application') Count: 11
# Bigram: ('Server', 'Analysis') Count: 11
# Bigram: ('Analysis', 'Services') Count: 11
# Bigram: ('Services', '(') Count: 11
# Bigram: ('(', 'SSAS') Count: 11
# Bigram: ('SSAS', ')') Count: 11
# Bigram: ('Developer', '.Net') Count: 11
# Bigram: ('.Net', 'Full') Count: 11
# Bigram: ('Underwriting', 'Rural') Count: 11
# Bigram: ('GCP', 'Data') Count: 11
# Bigram: ('|', 'FedEx') Count: 10
# Bigram: ('-', 'Big') Count: 10
# Bigram: ('Sr', '.') Count: 10
# Bigram: ('Developer', 'Senior') Count: 10
# Bigram: ('Pegasystems', 'Platform') Count: 10
# Bigram: ('Developer', 'Salesforce') Count: 10
# Bigram: ('Manager', 'Data') Count: 10
# Bigram: ('Deputy', 'Area') Count: 10
# Bigram: ('Area', 'Manager') Count: 10
# Bigram: ('(', 'Data') Count: 10
# Bigram: ('Engineering', 'Data') Count: 10
# Bigram: ('Business', 'Analyst-') Count: 9
# Bigram: ('-', 'Python') Count: 9
# Bigram: ('&', 'Development') Count: 9
# Bigram: ('Engineer', 'Java') Count: 9
# Bigram: ('DATA', 'Engineer') Count: 9
# Bigram: ('SAP', 'Business') Count: 9
# Bigram: ('SAP', 'MM') Count: 9
# Bigram: ('MM', 'Materials') Count: 9
# Bigram: ('Materials', 'Management') Count: 9
# Bigram: ('SAP', 'FICO') Count: 9
# Bigram: ('FICO', 'Finance') Count: 9
# Bigram: ('BI', 'Application') Count: 9
# Bigram: ('Development', '-') Count: 9
# Bigram: ('Edition', 'Application') Count: 9
# Bigram: ('Hiring', 'Data') Count: 9
# Bigram: ('Engineer', '|') Count: 9
# Bigram: ('Manager', 'Business') Count: 8
# Bigram: ('Business', 'analyst') Count: 8
# Bigram: ('/', 'Business') Count: 8
# Bigram: ('/', 'Senior') Count: 8
# Bigram: ('Modeling', '&') Count: 8
# Bigram: ('Data', 'Analysis') Count: 8
# Bigram: ('-', 'HANA') Count: 8
# Bigram: ('Java', 'Enterprise') Count: 8
# Bigram: ('Enterprise', 'Edition') Count: 8
# Bigram: ('Management', '(') Count: 8
# Bigram: ('Science', '-') Count: 8
# Bigram: ('Scientist', 'Research') Count: 8
# Bigram: ('Scientist', 'Sr.') Count: 8
# Bigram: ('Architect', 'Data') Count: 8
# Bigram: ('FedEx', 'Data') Count: 8
# Bigram: ('Engineer', '/') Count: 8
# Bigram: ('Scientist', 'Principal') Count: 8
# Bigram: ('Senior', 'Manager') Count: 8
# Bigram: ('engineer', 'Data') Count: 8
# Bigram: ('Engineer', 'Lead') Count: 8
# Bigram: ('Engineer', ':') Count: 8
# Bigram: ('AWS', 'Data') Count: 8
# Bigram: ('Engineer', ',') Count: 8
# Bigram: ('Business', 'Analysts') Count: 7
# Bigram: ('Urgent', 'Opening') Count: 7
# Bigram: ('Analyst', ',') Count: 7
# Bigram: ('(', 'Spark') Count: 7
# Bigram: ('(', 'SAP') Count: 7
# Bigram: ('SAP', 'GRC') Count: 7
# Bigram: ('Analysis', '&') Count: 7
# Bigram: ('&', 'Interpretation') Count: 7
# Bigram: ('Interpretation', 'Application') Count: 7
# Bigram: ('365', 'Finance') Count: 7
# Bigram: ('Finance', 'Functional') Count: 7
# Bigram: ('Developer', 'Pegasystems') Count: 7
# Bigram: ('Staff', 'Data') Count: 7
# Bigram: ('Scientist', 'Junior') Count: 7
# Bigram: ('Scientist', 'Sr') Count: 7
# Bigram: ('NLP', 'Data') Count: 7
# Bigram: ('ML', 'Engineer') Count: 7
# Bigram: ('Senior', 'Associate') Count: 7
# Bigram: ('Rural', 'Deputy') Count: 7
# Bigram: ('DATA', 'ENGINEER') Count: 7
# Bigram: ('Engineer', 'Python') Count: 7
# Bigram: ('Engineer', 'Sr.') Count: 7
# Bigram: ('-', 'Power') Count: 7
# Bigram: ('Engineers', 'Data') Count: 7
# Bigram: ('Analyst', 'Job') Count: 6
# Bigram: ('Job', 'Opportunity') Count: 6
# Bigram: ('Project', 'Manager') Count: 6
# Bigram: ('Hadoop', 'Developers') Count: 6
# Bigram: ('Spark', '/') Count: 6
# Bigram: ('Senior', 'Java') Count: 6
# Bigram: ('SAP', 'HCM') Count: 6
# Bigram: ('Process', 'Automation') Count: 6
# Bigram: ('Automation', 'Application') Count: 6
# Bigram: ('Dynamics', 'AX') Count: 6
# Bigram: ('AX', 'Technical') Count: 6
# Bigram: ('SAP', 'PO/PI') Count: 6
# Bigram: ('PO/PI', '&') Count: 6
# Bigram: ('&', 'APIs') Count: 6
# Bigram: ('APIs', 'Development') Count: 6
# Bigram: ('SAP', 'UX') Count: 6
# Bigram: ('Salesforce', 'Lightning') Count: 6
# Bigram: ('Components', 'Application') Count: 6
# Bigram: ('-', 'Senior') Count: 6
# Bigram: ('Data', 'Scientist/') Count: 6
# Bigram: ('Data', 'scientist') Count: 6
# Bigram: ('Scientist', 'NLP') Count: 6
# Bigram: ('.', 'Data') Count: 6
# Bigram: ('Deputy', 'Manager') Count: 6
# Bigram: ('Scientist', 'Associate') Count: 6
# Bigram: ('-', 'Computer') Count: 6
# Bigram: ('&', 'Data') Count: 6
# Bigram: ('Scientist', 'Manager') Count: 6
# Bigram: ('Science', 'Manager') Count: 6
# Bigram: ('Engineer', 'DATA') Count: 6
# Bigram: (':', 'Data') Count: 6
# Bigram: ('Engineer', '||') Count: 6
# Bigram: ('Engineering', 'Analyst') Count: 6
# Bigram: ('Analyst', '|') Count: 5
# Bigram: ('analyst', 'Business') Count: 5
# Bigram: ('(', 'PM') Count: 5
# Bigram: ('PM', ')') Count: 5
# Bigram: ('-', 'Hadoop') Count: 5
# Bigram: ('Engineer', 'Hiring') Count: 5
# Bigram: ('(', 'Java') Count: 5
# Bigram: ('Developer', ')') Count: 5
# Bigram: ('Java', 'Big') Count: 5
# Bigram: ('SAP', 'BW') Count: 5
# Bigram: ('BW', 'HANA') Count: 5
# Bigram: ('HANA', 'Data') Count: 5
# Bigram: ('SAP', 'SCM') Count: 5
# Bigram: ('SCM', 'APO') Count: 5
# Bigram: ('APO', 'Advanced') Count: 5
# Bigram: ('Advanced', 'Planning') Count: 5
# Bigram: ('Planning', '&') Count: 5
# Bigram: ('&', 'Optimization') Count: 5
# Bigram: ('Optimization', 'Application') Count: 5
# Bigram: ('365', 'Operations') Count: 5
# Bigram: ('Operations', 'Functional') Count: 5
# Bigram: ('SAP', 'Governance') Count: 5
# Bigram: ('Governance', 'Risk') Count: 5
# Bigram: ('Risk', 'Compliance') Count: 5
# Bigram: ('Compliance', '(') Count: 5
# Bigram: ('GRC', ')') Count: 5
# Bigram: ('(', 'Big') Count: 5
# Bigram: ('Business', 'Objects') Count: 5
# Bigram: ('Objects', 'Data') Count: 5
# Bigram: ('Solutions', 'Application') Count: 5
# Bigram: ('Warehouse', 'Management') Count: 5
# Bigram: ('SAP', 'Ariba') Count: 5
# Bigram: ('Power', 'Apps') Count: 5
# Bigram: ('SAP', 'PP') Count: 5
# Bigram: ('Developer', 'Siemens') Count: 5
# Bigram: ('Siemens', 'Teamcenter') Count: 5
# Bigram: ('Teamcenter', 'Application') Count: 5
# Bigram: ('DATA', 'SCIENTIST') Count: 5
# Bigram: ('Scientist', ',') Count: 5
# Bigram: ('Scientist', 'Deputy') Count: 5
# Bigram: ('Scientist', 'II') Count: 5
# Bigram: ('Technical', 'Lead') Count: 5
# Bigram: ('Learning', 'Senior') Count: 5
# Bigram: ('Research', 'Scientist/Engineer') Count: 5
# Bigram: ('Scientist/Engineer', '-') Count: 5
# Bigram: ('Computer', 'Vision/Machine') Count: 5
# Bigram: ('Scientist', 'ML') Count: 5
# Bigram: ('-', 'Remote') Count: 5
# Bigram: ('II', 'Data') Count: 5
# Bigram: ('-', 'NLP') Count: 5
# Bigram: ('Engineer', 'Principal') Count: 5
# Bigram: ('Spark', ',') Count: 5
# Bigram: ('Aws', 'Data') Count: 5
# Bigram: ('Engineer', 'AWS') Count: 5
# Bigram: ('Engineering', 'Lead') Count: 5
# Bigram: ('-', 'Azure') Count: 5
# Bigram: ('Engineer', 'Sr') Count: 5
# Bigram: ('Opening', 'Business') Count: 4
# Bigram: ('Location', 'Business') Count: 4
# Bigram: ('Analyst', 'Manager') Count: 4
# Bigram: ('Work', 'Office') Count: 4
# Bigram: ('Business', 'Analyst/Project') Count: 4
# Bigram: ('Analyst', 'Project') Count: 4
# Bigram: ('-', 'Life') Count: 4
# Bigram: ('-', 'Gurgaon') Count: 4
# Bigram: ('Hiring', 'Business') Count: 4
# Bigram: ('Analysts', 'Business') Count: 4
# Bigram: ('!', '!') Count: 4
# Bigram: ('-', '(') Count: 4
# Bigram: ('Analyst', '/') Count: 4
# Bigram: ('(', 'Travel') Count: 4
# Bigram: ('Travel', '&') Count: 4
# Bigram: ('Manager', '/') Count: 4
# Bigram: ('Developer', '(') Count: 4
# Bigram: ('Developers', 'Hadoop') Count: 4
# Bigram: ('Big', 'Data/') Count: 4
# Bigram: ('-', 'Hadoop/') Count: 4
# Bigram: ('Architecture', 'Application') Count: 4
# Bigram: ('HCM', 'Personnel') Count: 4
# Bigram: ('Personnel', 'Administration') Count: 4
# Bigram: ('SAP', 'Global') Count: 4
# Bigram: ('Global', 'Trade') Count: 4
# Bigram: ('Trade', 'Services') Count: 4
# Bigram: ('SAP', 'SuccessFactors') Count: 4
# Bigram: ('Developer', 'Sr') Count: 4
# Bigram: ('Microsoft', 'Robotic') Count: 4
# Bigram: ('Robotic', 'Process') Count: 4
# Bigram: ('HANA', 'SAP') Count: 4
# Bigram: ('Apps', 'Application') Count: 4
# Bigram: ('PP', '&') Count: 4
# Bigram: ('&', 'Control') Count: 4
# Bigram: ('Industries', 'Application') Count: 4
# Bigram: ('SAP', 'Plant') Count: 4
# Bigram: ('Plant', 'Maintenance') Count: 4
# Bigram: ('Maintenance', '(') Count: 4
# Bigram: ('365', 'Commerce') Count: 4
# Bigram: ('Commerce', 'Technical') Count: 4
# Bigram: ('UX', 'Application') Count: 4
# Bigram: ('Lightning', 'Aura') Count: 4
# Bigram: ('Aura', 'Components') Count: 4
# Bigram: ('SAP', 'Warehouse') Count: 4
# Bigram: ('System', '(') Count: 4
# Bigram: ('Senior', 'Software') Count: 4
# Bigram: (',', 'Pune') Count: 4
# Bigram: ('Lead', 'Java') Count: 4
# Bigram: ('Oracle', 'Agile') Count: 4
# Bigram: ('Agile', 'Product') Count: 4
# Bigram: ('Product', 'Lifecycle') Count: 4
# Bigram: ('Lifecycle', 'Management') Count: 4
# Bigram: ('Modeling', 'Techniques') Count: 4
# Bigram: ('Techniques', 'Methodologies') Count: 4
# Bigram: ('Methodologies', 'Application') Count: 4
# Bigram: ('Tech', 'Lead') Count: 4
# Bigram: ('Data', 'Management') Count: 4
# Bigram: ('Microsoft', 'BOT') Count: 4
# Bigram: ('BOT', 'Framework') Count: 4
# Bigram: ('Framework', 'Application') Count: 4
# Bigram: ('/', 'Lead') Count: 4
# Bigram: ('Principal', 'Engineer') Count: 4
# Bigram: ('Engineer', 'Snowflake') Count: 4
# Bigram: ('Science', 'Lead') Count: 4
# Bigram: ('Scientist/', 'Senior') Count: 4
# Bigram: ('Scientist', '||') Count: 4
# Bigram: ('||', 'Immediate') Count: 4
# Bigram: ('/', 'Sr') Count: 4
# Bigram: ('Data', 'Scientists') Count: 4
# Bigram: ('Immediate', 'Joiner') Count: 4
# Bigram: ('Learning', 'Data') Count: 4
# Bigram: ('Analyst', 'Data') Count: 4
# Bigram: ('Vision/Machine', 'Learning/Image') Count: 4
# Bigram: ('Analytics', 'Data') Count: 4
# Bigram: ('Remote', 'Data') Count: 4
# Bigram: ('Specialist', 'Data') Count: 4
# Bigram: ('Data', 'Scientist-') Count: 4
# Bigram: ('Data', 'Scientist/Senior') Count: 4
# Bigram: ('Scientist/Senior', 'Data') Count: 4
# Bigram: ('Computer', 'Vision') Count: 4
# Bigram: ('Professional', 'Data') Count: 4
# Bigram: ('Lead', '/') Count: 4
# Bigram: ('Modeling', 'Data') Count: 4
# Bigram: ('(', 'Power') Count: 4
# Bigram: ('Engineer', 'II') Count: 4
# Bigram: ('Module', 'Lead') Count: 4
# Bigram: ('Engineer', 'IV') Count: 4
# Bigram: ('BI', 'Data') Count: 4
# Bigram: ('Engineer', '1') Count: 4
# Bigram: ('Data', 'Engineer-') Count: 4
# Bigram: ('Senior', 'Azure') Count: 4
# Bigram: ('Engineering', 'Manager') Count: 4
# Bigram: ('Engineer', ')') Count: 4
# Bigram: (')', 'Azure') Count: 4
# Bigram: ('Analytics', ')') Count: 3
# Bigram: ('Guidewire', 'Business') Count: 3
# Bigram: ('Analyst', 'Duck') Count: 3
# Bigram: ('Duck', 'Creek') Count: 3
# Bigram: ('Analyst', 'Urgent') Count: 3
# Bigram: ('Urgent', 'Hiring') Count: 3
# Bigram: (':', 'Business') Count: 3
# Bigram: ('-', 'Analytics') Count: 3
# Bigram: ('-', 'Work') Count: 3
# Bigram: ('.', 'Business') Count: 3
# Bigram: ('Consultant', 'Business') Count: 3
# Bigram: ('Analyst', 'Hiring') Count: 3
# Bigram: ('Analyst', '||') Count: 3
# Bigram: ('Domain', 'Business') Count: 3
# Bigram: ('-', 'Manufacturing') Count: 3
# Bigram: ('Manufacturing', 'Firm') Count: 3
# Bigram: ('Firm', 'Business') Count: 3
# Bigram: (')', '@') Count: 3
# Bigram: ('Coordinator', 'Business') Count: 3
# Bigram: ('Azure', 'Analytics') Count: 3
# Bigram: ('Analytics', 'Services') Count: 3
# Bigram: ('Senior', 'Business') Count: 3
# Bigram: ('BUSINESS', 'ANALYSTS') Count: 3
# Bigram: ('ANALYSTS', 'Business') Count: 3
# Bigram: ('PLM', 'Business') Count: 3
# Bigram: ('-', 'SQL') Count: 3
# Bigram: ('-', 'AI/ML') Count: 3
# Bigram: ('&', 'Hospitality') Count: 3
# Bigram: ('Hospitality', ')') Count: 3
# Bigram: ('TM', 'Business') Count: 3
# Bigram: ('(', 'Work') Count: 3
# Bigram: ('/', 'Hive') Count: 3
# Bigram: ('Sr', 'Hadoop') Count: 3
# Bigram: ('Data/', 'Hadoop') Count: 3
# Bigram: ('Spark', '&') Count: 3
# Bigram: ('&', 'Scala') Count: 3
# Bigram: ('Hadoop', 'Data') Count: 3
# Bigram: ('Engineer', 'Leading') Count: 3
# Bigram: ('Staff', 'Engineer') Count: 3
# Bigram: ('Scala', ')') Count: 3
# Bigram: (')', 'Sr') Count: 3
# Bigram: ('Mobile', 'Application') Count: 3
# Bigram: ('Cloud', 'Platform') Count: 3
# Bigram: ('Data', 'Platform') Count: 3
# Bigram: ('Cloud', 'Application') Count: 3
# Bigram: ('SAP', 'TM') Count: 3
# Bigram: ('TM', 'Transportation') Count: 3
# Bigram: ('Transportation', 'Management') Count: 3
# Bigram: ('Technical', 'Architecture') Count: 3
# Bigram: ('Oracle', 'HCM') Count: 3
# Bigram: ('HCM', 'Cloud') Count: 3
# Bigram: ('Developer', 'PeopleSoft') Count: 3
# Bigram: ('SAP', 'UI5') Count: 3
# Bigram: ('UI5', 'Development') Count: 3
# Bigram: ('SuccessFactors', 'Employee') Count: 3
# Bigram: ('Employee', 'Central') Count: 3
# Bigram: ('Central', 'Application') Count: 3
# Bigram: ('Business', 'Planning') Count: 3
# Bigram: ('Planning', 'Consolidation') Count: 3
# Bigram: ('Developer', 'React.js') Count: 3
# Bigram: ('React.js', 'Application') Count: 3
# Bigram: ('Developer', 'Workday') Count: 3
# Bigram: ('Workday', 'Financial') Count: 3
# Bigram: ('Financial', 'Accounting') Count: 3
# Bigram: ('Accounting', 'Core') Count: 3
# Bigram: ('Core', 'Application') Count: 3
# Bigram: ('Java', 'Developers') Count: 3
# Bigram: ('Senior', 'Application') Count: 3
# Bigram: ('Ariba', 'Application') Count: 3
# Bigram: ('Developer', 'Informatica') Count: 3
# Bigram: ('SAP', 'FSCM') Count: 3
# Bigram: ('FSCM', 'Treasury') Count: 3
# Bigram: ('Treasury', '&') Count: 3
# Bigram: ('&', 'Risk') Count: 3
# Bigram: ('Risk', 'Management') Count: 3
# Bigram: ('Control', 'Discrete') Count: 3
# Bigram: ('Discrete', 'Industries') Count: 3
# Bigram: ('SAP', 'Analytics') Count: 3
# Bigram: ('Analytics', 'Cloud') Count: 3
# Bigram: ('Cloud', 'Development') Count: 3
# Bigram: ('Developer', 'Lead') Count: 3
# Bigram: ('ABAP', 'Application') Count: 3
# Bigram: ('Mgmt', '.') Count: 3
# Bigram: ('Team', 'Lead') Count: 3
# Bigram: ('Developer', 'O9') Count: 3
# Bigram: ('O9', 'Solutions') Count: 3
# Bigram: ('Management', 'System') Count: 3
# Bigram: ('SAP', 'Quality') Count: 3
# Bigram: ('Quality', 'Management') Count: 3
# Bigram: ('(', 'QM') Count: 3
# Bigram: ('QM', ')') Count: 3
# Bigram: ('Salesforce', 'Development') Count: 3
# Bigram: ('SAP', 'BW/4HANA') Count: 3
# Bigram: ('BW/4HANA', 'Data') Count: 3
# Bigram: ('-', 'AWS') Count: 3
# Bigram: ('Stack', 'Developer') Count: 3
# Bigram: ('Java', 'Hadoop') Count: 3
# Bigram: ('Supply', 'Chain') Count: 3
# Bigram: ('HANA', 'Microsoft') Count: 3
# Bigram: ('Content', 'Management') Count: 3
# Bigram: (')', 'Sr.') Count: 3
# Bigram: ('Developer', 'Architecture/Design/Development') Count: 3
# Bigram: ('Architecture/Design/Development', '-') Count: 3
# Bigram: ('-', 'Application') Count: 3
# Bigram: ('Data', 'Migration') Count: 3
# Bigram: ('-', 'Consultant') Count: 3
# Bigram: ('Consultant', 'Data') Count: 3
# Bigram: ('Specialist', '-') Count: 3
# Bigram: ('Associate', 'Director') Count: 3
# Bigram: ('Deep', 'Learning') Count: 3
# Bigram: ('ML', '/') Count: 3
# Bigram: ('Scientist', '|') Count: 3
# Bigram: ('Scientist', ')') Count: 3
# Bigram: ('SENIOR', 'DATA') Count: 3
# Bigram: ('Expert', 'Data') Count: 3
# Bigram: ('Drug', 'Discovery') Count: 3
# Bigram: ('Scientist', 'Team') Count: 3
# Bigram: ('Senior', 'Lead') Count: 3
# Bigram: ('Scientist', 'Staff') Count: 3
# Bigram: ('BI', '-') Count: 3
# Bigram: ('Assistant', 'Manager') Count: 3
# Bigram: ('Scientist', 'Machine') Count: 3
# Bigram: ('Learning', 'Engineer') Count: 3
# Bigram: ('-', 'Artificial') Count: 3
# Bigram: ('Artificial', 'Intelligence') Count: 3
# Bigram: ('Learning/Image', 'Data') Count: 3
# Bigram: ('Sr.ML', 'Expert') Count: 3
# Bigram: ('Associate', '-') Count: 3
# Bigram: ('Engineer', '&') Count: 3
# Bigram: ('Senior/Lead-', 'Data') Count: 3
# Bigram: ('Associate', 'Principal') Count: 3
# Bigram: ('Scientist', '1') Count: 3
# Bigram: ('1', 'Data') Count: 3
# Bigram: ('AI', 'Data') Count: 3
# Bigram: ('Data', 'Scientist/Data') Count: 3
# Bigram: ('Scientist/Data', 'Scientist') Count: 3
# Bigram: ('Science', ',') Count: 3
# Bigram: ('Senior', 'Manager/Operations') Count: 3
# Bigram: ('Manager/Operations', 'Research') Count: 3
# Bigram: ('scientist', 'Data') Count: 3
# Bigram: ('data', 'engineer') Count: 3
# Bigram: ('Enterprise', 'Data') Count: 3
# Bigram: ('Scientist', 'Hiring') Count: 3
# Bigram: ('Opening', 'Data') Count: 3
# Bigram: ('-', 'Mumbai') Count: 3
# Bigram: ('Python', ')') Count: 3
# Bigram: ('MNC', 'Data') Count: 3
# Bigram: ('data', 'scientist') Count: 3
# Bigram: ('BI', ')') Count: 3
# Bigram: ('Senior', 'Cloud') Count: 3
# Bigram: (',', 'Scala') Count: 3
# Bigram: ('looking', 'Data') Count: 3
# Bigram: (')', 'DATA') Count: 3
# Bigram: ('-', 'ETL/Python') Count: 3
# Bigram: ('Architect', ',') Count: 3
# Bigram: ('Engineer', 'Architect') Count: 3
# Bigram: ('IV', 'Data') Count: 3
# Bigram: ('Java', ')') Count: 3
# Bigram: ('Gcp', 'Data') Count: 3
# Bigram: ('Sr.', 'Talend') Count: 3
# Bigram: ('-', 'Spark') Count: 3
# Bigram: ('Engineer', 'GCP') Count: 3
# Bigram: ('Lead', 'Engineer') Count: 3
# Bigram: ('Engineering', 'Senior') Count: 3
# Bigram: ('Infogain', 'India') Count: 3
# Bigram: ('(', 'Analytics') Count: 2
# Bigram: ('Analyst', 'Guidewire') Count: 2
# Bigram: ('Analyst', 'Opening') Count: 2
# Bigram: ('Claims', 'Business') Count: 2
# Bigram: ('Creek', 'Policy') Count: 2
# Bigram: ('Policy', 'Business') Count: 2
# Bigram: ('-', 'CSAT') Count: 2
# Bigram: ('CSAT', 'Business') Count: 2
# Bigram: ('!', 'Business') Count: 2
# Bigram: ('(', 'BA') Count: 2
# Bigram: ('BA', ')') Count: 2
# Bigram: ('Analytics', 'Business') Count: 2
# Bigram: ('Analyst', 'Microsoft') Count: 2
# Bigram: ('-', 'DS') Count: 2
# Bigram: ('DS', 'Business') Count: 2
# Bigram: ('Job', 'opportunity') Count: 2
# Bigram: ('|', 'Business') Count: 2
# Bigram: ('Ahmedabad', 'Business') Count: 2
# Bigram: ('Kolkata', '-') Count: 2
# Bigram: ('Office', 'Business') Count: 2
# Bigram: ('(', 'WFO') Count: 2
# Bigram: ('Hiring', '-') Count: 2
# Bigram: ('Analyst/Project', 'Manager') Count: 2
# Bigram: ('Analyst', 'LoanIQ') Count: 2
# Bigram: ('LoanIQ', '-') Count: 2
# Bigram: ('Analyst', 'Consultant') Count: 2
# Bigram: ('-', 'SQL/Python') Count: 2
# Bigram: ('Analyst', 'Training') Count: 2
# Bigram: ('Network', 'Business') Count: 2
# Bigram: ('Experience', 'Business') Count: 2
# Bigram: ('Job', 'Opening') Count: 2
# Bigram: ('Analyst', 'FICO') Count: 2
# Bigram: ('Analyst', 'Service') Count: 2
# Bigram: ('-', 'Hyderabad') Count: 2
# Bigram: ('Health', 'Business') Count: 2
# Bigram: ('Bangalore', 'Location') Count: 2
# Bigram: ('Subject', 'Matter') Count: 2
# Bigram: ('Matter', 'Expert') Count: 2
# Bigram: ('Analyst/Project', 'Coordinator') Count: 2
# Bigram: (',', 'Pan') Count: 2
# Bigram: ('Pan', 'India') Count: 2
# Bigram: ('Job', 'opening') Count: 2
# Bigram: ('opening', 'Business') Count: 2
# Bigram: ('-', 'IIM') Count: 2
# Bigram: ('IIM', '/') Count: 2
# Bigram: ('/', 'ISB') Count: 2
# Bigram: ('ISB', '/') Count: 2
# Bigram: ('/', 'MDI') Count: 2
# Bigram: ('MDI', '/') Count: 2
# Bigram: ('/', 'FMS') Count: 2
# Bigram: ('Services', 'Business') Count: 2
# Bigram: ('Analyst', 'Role') Count: 2
# Bigram: ('(', 'Technical') Count: 2
# Bigram: ('Technical', ')') Count: 2
# Bigram: ('Analyst', 'Airline') Count: 2
# Bigram: ('Airline', 'domain') Count: 2
# Bigram: ('domain', 'Business') Count: 2
# Bigram: ('&', 'Business') Count: 2
# Bigram: ('Data', '(') Count: 2
# Bigram: ('HANA', 'DW') Count: 2
# Bigram: ('DW', 'Business') Count: 2
# Bigram: ('/', 'Project') Count: 2
# Bigram: ('TS', '-') Count: 2
# Bigram: ('Python', '/') Count: 2
# Bigram: ('Immediate', 'Hiring') Count: 2
# Bigram: ('Analyst', 'TM') Count: 2
# Bigram: ('Developer/Tester/Business', 'Analyst') Count: 2
# Bigram: ('Analysts', '.') Count: 2
# Bigram: ('Analytics', 'Analyst') Count: 2
# Bigram: ('/', 'Consultant') Count: 2
# Bigram: ('Full', 'Time') Count: 2
# Bigram: ('Office', ')') Count: 2
# Bigram: ('/', 'Admin') Count: 2
# Bigram: ('Admin', 'Support') Count: 2
# Bigram: ('Support', 'Hadoop') Count: 2
# Bigram: ('Developer', 'Immediate') Count: 2
# Bigram: ('Hadoop', 'developer') Count: 2
# Bigram: ('-', 'Kafka') Count: 2
# Bigram: ('GCP', '/') Count: 2
# Bigram: ('/', 'Hadoop') Count: 2
# Bigram: ('Hadoop', '/') Count: 2
# Bigram: ('/', 'Spark') Count: 2
# Bigram: ('Developer', 'Job') Count: 2
# Bigram: ('Hadoop', 'Developer/') Count: 2
# Bigram: ('Developer/', 'Architect') Count: 2
# Bigram: ('Bigdata', 'Hadoop') Count: 2
# Bigram: ('-', 'Hadoop/Scala') Count: 2
# Bigram: ('Hadoop/Scala', 'Big') Count: 2
# Bigram: ('Hiring', 'Big') Count: 2
# Bigram: ('Developer/', 'Lead') Count: 2
# Bigram: ('Lead', '(') Count: 2
# Bigram: ('Hiring', 'Hadoop') Count: 2
# Bigram: ('Leading', 'Banking') Count: 2
# Bigram: ('Banking', 'Client') Count: 2
# Bigram: ('Hadoop/', 'Java') Count: 2
# Bigram: ('hiring', 'Big') Count: 2
# Bigram: ('Hadoop', 'Administration') Count: 2
# Bigram: ('Azure', 'Modern') Count: 2
# Bigram: ('Modern', 'Data') Count: 2
# Bigram: ('Big', 'data') Count: 2
# Bigram: ('data', 'Developer') Count: 2
# Bigram: ('Architect', '-') Count: 2
# Bigram: ('SAP', 'S/4HANA') Count: 2
# Bigram: ('S/4HANA', 'Group') Count: 2
# Bigram: ('Group', 'Reporting') Count: 2
# Bigram: ('Reporting', 'Application') Count: 2
# Bigram: ('PeopleSoft', 'PeopleTools') Count: 2
# Bigram: ('PeopleTools', 'Application') Count: 2
# Bigram: ('Consolidation', '(') Count: 2
# Bigram: ('SAP', 'BPC') Count: 2
# Bigram: ('BPC', ')') Count: 2
# Bigram: ('Senior', 'Hadoop') Count: 2
# Bigram: ('PAN', 'India') Count: 2
# Bigram: ('India', 'Java') Count: 2
# Bigram: ('.', 'Application') Count: 2
# Bigram: ('-', 'Java') Count: 2
# Bigram: ('Python', 'Big') Count: 2
# Bigram: ('Data', 'Infrastructure') Count: 2
# Bigram: ('Developers', 'Java') Count: 2
# Bigram: ('End', 'Developer') Count: 2
# Bigram: ('Java', 'Developer/') Count: 2
# Bigram: ('Developer', 'Kronos') Count: 2
# Bigram: ('SAP', 'BASIS') Count: 2
# Bigram: ('BASIS', 'Administration') Count: 2
# Bigram: ('Developer', 'Urgent') Count: 2
# Bigram: (':', 'EAI') Count: 2
# Bigram: ('Developer', 'Full') Count: 2
# Bigram: ('Developer', 'Pega') Count: 2
# Bigram: ('Pega', 'Platform') Count: 2
# Bigram: ('Salesforce', 'Technical') Count: 2
# Bigram: ('Informatica', 'PowerCenter') Count: 2
# Bigram: ('PowerCenter', 'Application') Count: 2
# Bigram: ('Appian', 'Process') Count: 2
# Bigram: ('Management', 'TRM') Count: 2
# Bigram: ('TRM', 'Application') Count: 2
# Bigram: ('Developer', 'Drupal') Count: 2
# Bigram: ('Drupal', 'Application') Count: 2
# Bigram: ('SAP', 'Data') Count: 2
# Bigram: ('-', '8') Count: 2
# Bigram: ('5', '-') Count: 2
# Bigram: ('Developer', '&') Count: 2
# Bigram: ('Analyst', 'Big') Count: 2
# Bigram: ('/', 'HBase') Count: 2
# Bigram: ('Urgent', 'opening') Count: 2
# Bigram: ('Sr.', 'Big') Count: 2
# Bigram: ('Cloud', 'Time') Count: 2
# Bigram: ('Time', '&') Count: 2
# Bigram: ('&', 'Labor') Count: 2
# Bigram: ('Labor', 'Application') Count: 2
# Bigram: ('SAP', 'Vendor') Count: 2
# Bigram: ('Vendor', 'Invoice') Count: 2
# Bigram: ('Invoice', 'Management') Count: 2
# Bigram: ('FI', 'Joint') Count: 2
# Bigram: ('Joint', 'Venture') Count: 2
# Bigram: ('Venture', 'Accounting') Count: 2
# Bigram: ('SAP', 'BTP') Count: 2
# Bigram: ('Suite', 'Application') Count: 2
# Bigram: ('Ariba', 'Cloud') Count: 2
# Bigram: ('Cloud', 'Integration') Count: 2
# Bigram: ('Integration', 'Gateway') Count: 2
# Bigram: ('Gateway', 'CIG') Count: 2
# Bigram: ('CIG', 'Application') Count: 2
# Bigram: ('Lightning', 'Web') Count: 2
# Bigram: ('Web', 'Components') Count: 2
# Bigram: ('SAP', 'Environment') Count: 2
# Bigram: ('Environment', 'Health') Count: 2
# Bigram: ('Health', '&') Count: 2
# Bigram: ('&', 'Safety') Count: 2
# Bigram: ('Safety', 'Management') Count: 2
# Bigram: ('(', 'WMS') Count: 2
# Bigram: ('WMS', ')') Count: 2
# Bigram: ('SAP', 'FIORI/Gateway') Count: 2
# Bigram: ('FIORI/Gateway', 'architecture') Count: 2
# Bigram: ('architecture', 'Application') Count: 2
# Bigram: ('GRC', 'BusinessObjects') Count: 2
# Bigram: ('BusinessObjects', 'Application') Count: 2
# Bigram: ('Developer', 'MuleSoft') Count: 2
# Bigram: ('MuleSoft', 'Anypoint') Count: 2
# Bigram: ('Anypoint', 'Platform') Count: 2
# Bigram: ('Data', 'Analytics') Count: 2
# Bigram: (')', 'Java') Count: 2
# Bigram: ('AWS', '/') Count: 2
# Bigram: ('Application', 'Development') Count: 2
# Bigram: ('@', 'Tech') Count: 2
# Bigram: ('Tech', 'Mahindra') Count: 2
# Bigram: ('Senior', 'Developer') Count: 2
# Bigram: ('Developer', 'Spark') Count: 2
# Bigram: ('Developer', 'Supply') Count: 2
# Bigram: ('Chain', 'Management') Count: 2
# Bigram: ('(', 'SCM') Count: 2
# Bigram: ('SCM', ')') Count: 2
# Bigram: (')', 'Applications') Count: 2
# Bigram: ('Applications', 'Application') Count: 2
# Bigram: ('SAP', 'NextGen') Count: 2
# Bigram: ('NextGen', 'UX') Count: 2
# Bigram: ('UX', '&') Count: 2
# Bigram: ('&', 'Mobile') Count: 2
# Bigram: ('Mobile', 'Microsoft') Count: 2
# Bigram: ('Reporting', 'Analytics') Count: 2
# Bigram: ('(', 'Immediate') Count: 2
# Bigram: ('Immediate', 'joiner') Count: 2
# Bigram: ('joiner', ')') Count: 2
# Bigram: ('Data', 'Structure') Count: 2
# Bigram: ('Structure', '&') Count: 2
# Bigram: ('Data', 'Applications') Count: 2
# Bigram: ('Hadoop', 'Admin') Count: 2
# Bigram: ('Job', '|') Count: 2
# Bigram: ('Developer', '|') Count: 2
# Bigram: ('Migration', 'Application') Count: 2
# Bigram: ('Data', 'Analyst') Count: 2
# Bigram: ('-', 'Applied') Count: 2
# Bigram: ('Consultant', '(') Count: 2
# Bigram: ('(', 'Retail') Count: 2
# Bigram: ('Retail', ')') Count: 2
# Bigram: ('Scientist', 'Specialist') Count: 2
# Bigram: ('Lead-', 'Data') Count: 2
# Bigram: ('Science', 'Associate') Count: 2
# Bigram: ('Learning', '/') Count: 2
# Bigram: ('/', 'ML') Count: 2
# Bigram: ('-', 'Engine') Count: 2
# Bigram: ('Engine', 'Algorithm') Count: 2
# Bigram: ('Algorithm', 'Data') Count: 2
# Bigram: ('Solution', 'Architect') Count: 2
# Bigram: ('Senior', '/') Count: 2
# Bigram: ('SCIENTIST', 'Senior') Count: 2
# Bigram: (',', 'CAT') Count: 2
# Bigram: ('CAT', 'Proc') Count: 2
# Bigram: ('Immediate', 'Joiners') Count: 2
# Bigram: ('(', 'Clinical') Count: 2
# Bigram: ('Clinical', 'Consultant/Clinical') Count: 2
# Bigram: ('Consultant/Clinical', 'Data') Count: 2
# Bigram: ('SCIENTIST', 'Data') Count: 2
# Bigram: ('Discovery', 'Associate') Count: 2
# Bigram: ('Senior', 'Specialist') Count: 2
# Bigram: ('DATA', 'SCIENCE') Count: 2
# Bigram: ('Associate', ',') Count: 2
# Bigram: ('Scientist', 'AVP') Count: 2
# Bigram: ('AVP', '-') Count: 2
# Bigram: ('Credit', 'Risk') Count: 2
# Bigram: ('Scientist', '&') Count: 2
# Bigram: ('&', 'Predictive') Count: 2
# Bigram: ('/', 'Machine') Count: 2
# Bigram: ('Senior', 'Engineer') Count: 2
# Bigram: ('Scientist', 'Sr.ML') Count: 2
# Bigram: ('-', 'ML') Count: 2
# Bigram: ('ML', 'Data') Count: 2
# Bigram: ('-', 'Mortgage') Count: 2
# Bigram: ('Mortgage', 'Finance') Count: 2
# Bigram: ('Finance', 'Data') Count: 2
# Bigram: ('Scientist', 'DATA') Count: 2
# Bigram: ('Specialist', ',') Count: 2
# Bigram: ('engineers', 'Data') Count: 2
# Bigram: ('Science', '(') Count: 2
# Bigram: ('Scientist', 'Senior/Lead-') Count: 2
# Bigram: ('Architect', ')') Count: 2
# Bigram: ('Senior', 'ML') Count: 2
# Bigram: ('ML', 'Ops') Count: 2
# Bigram: ('NLP', ')') Count: 2
# Bigram: ('Life', 'Insurance') Count: 2
# Bigram: ('Manager', ',') Count: 2
# Bigram: ('Engineer', 'Scientist') Count: 2
# Bigram: ('Hiring', 'Senior') Count: 2
# Bigram: ('Scientist', 'Engineer') Count: 2
# Bigram: ('Marketing', 'Customer') Count: 2
# Bigram: ('Customer', 'analytics') Count: 2
# Bigram: ('Mumbai', ')') Count: 2
# Bigram: ('Science', 'Senior') Count: 2
# Bigram: ('Scientist', 'Jr.') Count: 2
# Bigram: ('Quant', 'Researcher') Count: 2
# Bigram: ('Researcher', '-') Count: 2
# Bigram: (')', 'Job') Count: 2
# Bigram: ('Modeling', 'Senior') Count: 2
# Bigram: ('NLP', '/') Count: 2
# Bigram: ('AI/ML', 'Professional') Count: 2
# Bigram: ('Learning', 'Development') Count: 2
# Bigram: ('Manager', 'Research') Count: 2
# Bigram: ('-', 'R/Python') Count: 2
# Bigram: ('Speech', 'Scientist') Count: 2
# Bigram: ('Artificial', 'Intelligence/Machine') Count: 2
# Bigram: ('Intelligence/Machine', 'Learning') Count: 2
# Bigram: ('Development', 'Senior') Count: 2
# Bigram: ('Bangalore', 'Data') Count: 2
# Bigram: ('-', 'Quantum') Count: 2
# Bigram: ('Quantum', 'Computing') Count: 2
# Bigram: ('Processing', 'Engineer') Count: 2
# Bigram: ('/', 'Sr.') Count: 2
# Bigram: ('-', 'Healthcare') Count: 2
# Bigram: ('Science', 'Sr') Count: 2
# Bigram: ('R', '&') Count: 2
# Bigram: ('/', 'Staff') Count: 2
# Bigram: ('Staff', 'ML') Count: 2
# Bigram: ('ML', 'Scientist') Count: 2
# Bigram: ('Scientist', 'data') Count: 2
# Bigram: ('Scientist', 'Knowledge') Count: 2
# Bigram: ('Knowledge', 'Graph') Count: 2
# Bigram: ('Learning', ',') Count: 2
# Bigram: ('ML', '&') Count: 2
# Bigram: ('Scientist', 'Assistant') Count: 2
# Bigram: ('(', 'M.Tech') Count: 2
# Bigram: ('M.Tech', '/') Count: 2
# Bigram: ('/', 'PHD') Count: 2
# Bigram: ('PHD', ')') Count: 2
# Bigram: ('-', 'Product') Count: 2
# Bigram: ('Product', 'MNC') Count: 2
# Bigram: ('MNC', ',') Count: 2
# Bigram: (',', 'Kharadi') Count: 2
# Bigram: ('Kharadi', ',') Count: 2
# Bigram: ('Data', 'Modeler') Count: 2
# Bigram: ('Natural', 'Language') Count: 2
# Bigram: ('Language', 'Processing') Count: 2
# Bigram: ('Analytics', '(') Count: 2
# Bigram: ('Learning', '&') Count: 2
# Bigram: ('Manager', 'Sr.') Count: 2
# Bigram: ('NLP', 'Engineer') Count: 2
# Bigram: ('Science', 'Engineer') Count: 2
# Bigram: ('Scientist', 'Consultant') Count: 2
# Bigram: (',', 'Python') Count: 2
# Bigram: ('Python', ',') Count: 2
# Bigram: ('Years', ')') Count: 2
# Bigram: ('scientist', 'Lead') Count: 2
# Bigram: ('Lead', 'data') Count: 2
# Bigram: ('Data', 'Data') Count: 2
# Bigram: ('&', 'AI') Count: 2
# Bigram: ('Cloud', 'Engineer') Count: 2
# Bigram: ('Lead', 'Sr.') Count: 2
# Bigram: ('Scientist', 'Search') Count: 2
# Bigram: ('Modeler', 'Data') Count: 2
# Bigram: ('Senior', 'Analyst') Count: 2
# Bigram: ('Engineer', '3') Count: 2
# Bigram: ('Jobs', 'Data') Count: 2
# Bigram: ('Scientist', 'AI') Count: 2
# Bigram: ('(', 'f/m/x') Count: 2
# Bigram: ('f/m/x', ')') Count: 2
# Bigram: ('Data', 'bricks') Count: 2
# Bigram: ('Data', 'Engineer/') Count: 2
# Bigram: ('Engineer/', 'Data') Count: 2
# Bigram: ('Database/', 'Data') Count: 2
# Bigram: ('Data', 'Engineer/Data') Count: 2
# Bigram: ('ENGINEER', 'Data') Count: 2
# Bigram: ('Databricks', ')') Count: 2
# Bigram: ('Big', 'Data/AWS') Count: 2
# Bigram: ('-', 'Scala') Count: 2
# Bigram: (',', 'GTM') Count: 2
# Bigram: ('GTM', '&') Count: 2
# Bigram: ('&', 'Enabling') Count: 2
# Bigram: ('Analyst/Data', 'Engineer') Count: 2
# Bigram: ('Application', 'Architect') Count: 2
# Bigram: (',', 'Azure') Count: 2
# Bigram: ('Engineering', 'Professional') Count: 2
# Bigram: ('(', 'India') Count: 2
# Bigram: ('India', 'Remote') Count: 2
# Bigram: ('Remote', ')') Count: 2
# Bigram: ('Engineering', 'Specialist') Count: 2
# Bigram: ('Kronos', 'Data') Count: 2
# Bigram: ('Engineer', 'Web') Count: 2
# Bigram: ('Web', 'Data') Count: 2
# Bigram: ('-', 'BI') Count: 2
# Bigram: ('-', 'EDW') Count: 2
# Bigram: ('EDW', '(') Count: 2
# Bigram: ('Java', 'Data') Count: 2
# Bigram: ('||', 'Remote') Count: 2
# Bigram: ('DAX', ')') Count: 2
# Bigram: (':', 'Enterprise') Count: 2
# Bigram: ('Enterprise', 'Content') Count: 2
# Bigram: ('Management', 'Data') Count: 2
# Bigram: ('&', 'Azure') Count: 2
# Bigram: ('Data', 'Bricks') Count: 2
# Bigram: ('-Data', 'Engineer') Count: 2
# Bigram: ('(', 'Python') Count: 2
# Bigram: ('-', 'IoT') Count: 2
# Bigram: ('Engineer', 'SENIOR') Count: 2
# Bigram: ('-', 'Snowflake') Count: 2
# Bigram: ('Data', 'Engineers-') Count: 2
# Bigram: ('Engineer', 'Urgent') Count: 2
# Bigram: ('Talend', 'Data') Count: 2
# Bigram: ('BI', 'Senior') Count: 2
# Bigram: ('Engineer', 'Immediate') Count: 2
# Bigram: ('ADF', ',') Count: 2
# Bigram: (',', 'ADB') Count: 2
# Bigram: ('ADB', ',') Count: 2
# Bigram: ('Pyspark', '-') Count: 2
# Bigram: ('Engineer', 'Associate') Count: 2
# Bigram: ('ETL/Python', 'Big') Count: 2
# Bigram: ('Analyst', 'DataBeat') Count: 2
# Bigram: ('-', 'VBA') Count: 2
# Bigram: ('/', 'Python') Count: 2
# Bigram: ('1', '-') Count: 2
# Bigram: (',', 'Platform') Count: 2
# Bigram: ('Platform', 'DevOps') Count: 2
# Bigram: ('DevOps', 'Lead') Count: 2
# Bigram: ('-', 'Metadata') Count: 2
# Bigram: (',', 'Client') Count: 2
# Bigram: ('Client', 'Ops') Count: 2
# Bigram: ('engineer', 'Solution') Count: 2
# Bigram: ('-', 'DPaaS') Count: 2
# Bigram: ('DPaaS', 'Foundation') Count: 2
# Bigram: ('Foundation', 'POD') Count: 2
# Bigram: ('Engineer', 'ETL') Count: 2
# Bigram: ('-', 'Module') Count: 2
# Bigram: ('Manager', '(') Count: 2
# Bigram: ('Data', 'Senior') Count: 2
# Bigram: ('Data', 'Engineer-Lead/Architect') Count: 2
# Bigram: ('Engineer', 'III') Count: 2
# Bigram: ('|', 'Snowflake') Count: 2
# Bigram: (')', 'GCP') Count: 2
# Bigram: ('Engineer', 'Gurgaon') Count: 2
# Bigram: ('Gurgaon', 'VS') Count: 2
# Bigram: ('Solutions', 'Architect') Count: 2
# Bigram: ('Engineering', ')') Count: 2
# Bigram: ('India', 'Hiring') Count: 2
# Bigram: ('Engineer', 'Technical') Count: 2
# Bigram: (',', 'SQL') Count: 2
# Bigram: ('SQL', ',') Count: 2
# Bigram: ('Hiring', 'GCP') Count: 2
# Bigram: ('Engineer', '@') Count: 2
# Bigram: ('@', 'Bangalore') Count: 2
# Bigram: ('(', 'ADF') Count: 2
# Bigram: ('Azure', 'Synapse') Count: 2
# Bigram: ('Principal', 'Software') Count: 2
# Bigram: ('-', 'Pricing') Count: 2
# Bigram: ('Merilytics', '-') Count: 1
# Bigram: (')', 'Stars') Count: 1
# Bigram: ('Stars', 'Business') Count: 1
# Bigram: ('Opportunity', 'Guidewire') Count: 1
# Bigram: ('Analyst', 'Mumbai') Count: 1
# Bigram: ('Mumbai', '(') Count: 1
# Bigram: ('(', 'Thane') Count: 1
# Bigram: ('Thane', ')') Count: 1
# Bigram: (')', 'Location') Count: 1
# Bigram: ('Creek', 'Claims') Count: 1
# Bigram: ('-', 'PS') Count: 1
# Bigram: ('PS', '&') Count: 1
# Bigram: ('&', 'F') Count: 1
# Bigram: ('F', '-') Count: 1
# Bigram: ('-', 'Collateral') Count: 1
# Bigram: ('Collateral', 'Business') Count: 1
# Bigram: ('Hiring', ':') Count: 1
# Bigram: ('Analyst', '!') Count: 1
# Bigram: ('-', 'Big4') Count: 1
# Bigram: ('Big4', 'Business') Count: 1
# Bigram: ('Dynamics', 'NAV') Count: 1
# Bigram: ('NAV', 'Business') Count: 1
# Bigram: ('Analyst', 'Guidewire/Duckcreek') Count: 1
# Bigram: ('Guidewire/Duckcreek', '-') Count: 1
# Bigram: ('ANALYST', 'Lending') Count: 1
# Bigram: ('Lending', '-') Count: 1
# Bigram: ('opportunity', '|') Count: 1
# Bigram: ('-', 'Bearing') Count: 1
# Bigram: ('Bearing', 'Manufacturing') Count: 1
# Bigram: ('Manufacturing', '-') Count: 1
# Bigram: ('-', 'Changodar') Count: 1
# Bigram: ('Changodar', '-') Count: 1
# Bigram: ('-', 'Ahmedabad') Count: 1
# Bigram: ('-', 'Kolkata') Count: 1
# Bigram: ('WFO', 'Only-') Count: 1
# Bigram: ('Only-', 'Noida') Count: 1
# Bigram: ('Noida', 'sector') Count: 1
# Bigram: ('sector', '125') Count: 1
# Bigram: ('125', ')') Count: 1
# Bigram: ('Analyst', '.') Count: 1
# Bigram: ('Manager', 'Job') Count: 1
# Bigram: ('Job', 'Oppurtunity') Count: 1
# Bigram: ('Oppurtunity', 'freshers') Count: 1
# Bigram: ('freshers', 'Business') Count: 1
# Bigram: ('Analyst', 'role') Count: 1
# Bigram: ('role', 'Business') Count: 1
# Bigram: ('Business', 'Analyst-HCS') Count: 1
# Bigram: ('Analyst-HCS', 'Business') Count: 1
# Bigram: ('|', 'Info') Count: 1
# Bigram: ('Info', 'Edge') Count: 1
# Bigram: ('Edge', 'Business') Count: 1
# Bigram: ('Business', 'Analyst-Finacle') Count: 1
# Bigram: ('Analyst-Finacle', 'Business') Count: 1
# Bigram: ('SQL/Python', 'Business') Count: 1
# Bigram: ('(', 'Service') Count: 1
# Bigram: ('Service', ')') Count: 1
# Bigram: ('(', 'Governance') Count: 1
# Bigram: ('Governance', ')') Count: 1
# Bigram: ('Analysts', 'Immediate') Count: 1
# Bigram: ('Immediate', 'Requirement') Count: 1
# Bigram: ('Requirement', 'Business') Count: 1
# Bigram: ('Business', 'Analyst/Keylent/Hyderabad') Count: 1
# Bigram: ('Analyst/Keylent/Hyderabad', 'Business') Count: 1
# Bigram: ('Training', 'CMDB') Count: 1
# Bigram: ('CMDB', 'Business') Count: 1
# Bigram: ('-', 'TPA') Count: 1
# Bigram: ('TPA', 'Business') Count: 1
# Bigram: ('Analyst-', 'Navi') Count: 1
# Bigram: ('Navi', 'Mumbai-WFO') Count: 1
# Bigram: ('Mumbai-WFO', 'Manager-Business') Count: 1
# Bigram: ('Manager-Business', 'Analyst') Count: 1
# Bigram: ('Analyst', 'Caliper') Count: 1
# Bigram: ('Caliper', 'BSL') Count: 1
# Bigram: ('BSL', ':') Count: 1
# Bigram: ('Hiring', 'Network') Count: 1
# Bigram: ('Analyst', '5+') Count: 1
# Bigram: ('5+', 'yrs') Count: 1
# Bigram: ('yrs', 'Experience') Count: 1
# Bigram: ('-', 'SaaS') Count: 1
# Bigram: ('SaaS', 'PaaS') Count: 1
# Bigram: ('PaaS', 'Business') Count: 1
# Bigram: ('-', 'Reputed') Count: 1
# Bigram: ('Reputed', 'Pharma') Count: 1
# Bigram: ('Pharma', 'Company') Count: 1
# Bigram: ('Company', 'Kandivali') Count: 1
# Bigram: ('Kandivali', 'Business') Count: 1
# Bigram: ('Analyst', 'Fraud') Count: 1
# Bigram: ('Fraud', 'Business') Count: 1
# Bigram: ('-', 'Plsql+XML') Count: 1
# Bigram: ('Plsql+XML', 'Business') Count: 1
# Bigram: ('||', '3+') Count: 1
# Bigram: ('3+', 'years') Count: 1
# Bigram: ('years', '||') Count: 1
# Bigram: ('||', 'Gurgaon') Count: 1
# Bigram: ('Gurgaon', 'Job') Count: 1
# Bigram: ('Opening', '(') Count: 1
# Bigram: ('(', 'CA') Count: 1
# Bigram: ('CA', 'Inter') Count: 1
# Bigram: ('Inter', ')') Count: 1
# Bigram: (')', '||') Count: 1
# Bigram: ('||', 'Business') Count: 1
# Bigram: ('Analyst', 'Content') Count: 1
# Bigram: ('Content', 'Analyst/') Count: 1
# Bigram: ('Analyst/', 'Business') Count: 1
# Bigram: ('Analyst', 'RA') Count: 1
# Bigram: ('RA', 'Aviation') Count: 1
# Bigram: ('Aviation', 'Business') Count: 1
# Bigram: ('Project', 'Coordinator/Business') Count: 1
# Bigram: ('Coordinator/Business', 'Analyst') Count: 1
# Bigram: ('Life', 'Asia') Count: 1
# Bigram: ('Asia', 'Business') Count: 1
# Bigram: ('Gurgaon', 'Sahibandhu') Count: 1
# Bigram: ('Sahibandhu', 'fintech') Count: 1
# Bigram: ('fintech', '(') Count: 1
# Bigram: ('(', 'Manipal') Count: 1
# Bigram: ('Manipal', 'Group') Count: 1
# Bigram: ('Group', ')') Count: 1
# Bigram: ('-', 'Autuskey') Count: 1
# Bigram: ('Autuskey', 'Business') Count: 1
# Bigram: ('Analyst', 'VIS') Count: 1
# Bigram: ('VIS', '-') Count: 1
# Bigram: ('Analyst', 'UML') Count: 1
# Bigram: ('UML', 'Business') Count: 1
# Bigram: ('Analyst', '_') Count: 1
# Bigram: ('_', 'Sidbi') Count: 1
# Bigram: ('Sidbi', 'Business') Count: 1
# Bigram: ('Analyst', 'Focus') Count: 1
# Bigram: ('Focus', 'Brands') Count: 1
# Bigram: ('Brands', 'Business') Count: 1
# Bigram: ('Analyst', 'Gurgaon') Count: 1
# Bigram: ('Gurgaon', 'Location') Count: 1
# Bigram: ('-', 'GIS') Count: 1
# Bigram: ('GIS', 'Domain') Count: 1
# Bigram: ('-', 'Education') Count: 1
# Bigram: ('Education', 'Business') Count: 1
# Bigram: ('FICO', 'Analyst') Count: 1
# Bigram: ('-', 'Bureau') Count: 1
# Bigram: ('Bureau', 'Urgent') Count: 1
# Bigram: ('Opening', '-') Count: 1
# Bigram: ('Service', 'based') Count: 1
# Bigram: ('based', 'Company') Count: 1
# Bigram: ('Company', 'Business') Count: 1
# Bigram: ('Hyderabad', 'Business') Count: 1
# Bigram: ('-', 'Health') Count: 1
# Bigram: ('Service', 'Business') Count: 1
# Bigram: ('Analyst', 'Claims') Count: 1
# Bigram: ('(', 'L3') Count: 1
# Bigram: ('L3', ')') Count: 1
# Bigram: (')', 'Opening') Count: 1
# Bigram: ('Analyst', 'Bangalore') Count: 1
# Bigram: ('Analyst', 'Techo') Count: 1
# Bigram: ('Techo', 'Business') Count: 1
# Bigram: ('analyst', '-') Count: 1
# Bigram: ('-', 'Simcorp') Count: 1
# Bigram: ('Simcorp', 'dimensio') Count: 1
# Bigram: ('dimensio', 'Business') Count: 1
# Bigram: ('Analyst', '&') Count: 1
# Bigram: ('&', 'Subject') Count: 1
# Bigram: ('Expert', 'Business') Count: 1
# Bigram: ('Analyst', '/BA') Count: 1
# Bigram: ('/BA', ':') Count: 1
# Bigram: (':', 'Noida') Count: 1
# Bigram: ('Noida', 'Business') Count: 1
# Bigram: ('Analyst-', 'CEO') Count: 1
# Bigram: ('CEO', "'s") Count: 1
# Bigram: ("'s", 'Office') Count: 1
# Bigram: ('Hiring', 'Mid') Count: 1
# Bigram: ('Mid', 'Business') Count: 1
# Bigram: ('Analyst', 'Prabhadevi') Count: 1
# Bigram: ('Prabhadevi', 'Location') Count: 1
# Bigram: ('Analyst', 'Urgently') Count: 1
# Bigram: ('Urgently', 'Hiring') Count: 1
# Bigram: ('(', 'Lending') Count: 1
# Bigram: ('Lending', 'Must') Count: 1
# Bigram: ('Must', ')') Count: 1
# Bigram: ('@', 'Kiya.ai-Airoli') Count: 1
# Bigram: ('Kiya.ai-Airoli', 'Business') Count: 1
# Bigram: ('Analyst', 'Techno') Count: 1
# Bigram: ('Techno', 'Business') Count: 1
# Bigram: ('Analyst', 'Cochin/Bangalore/Calicut') Count: 1
# Bigram: ('Cochin/Bangalore/Calicut', 'Business') Count: 1
# Bigram: ('(', 'Growth') Count: 1
# Bigram: ('Growth', ')') Count: 1
# Bigram: ('Analyst', 'HRSD') Count: 1
# Bigram: ('HRSD', 'Business') Count: 1
# Bigram: ('Analyst', 'Openings') Count: 1
# Bigram: ('Openings', 'Business') Count: 1
# Bigram: ('(', 'finacle') Count: 1
# Bigram: ('finacle', ')') Count: 1
# Bigram: ('Analyst', 'GCP') Count: 1
# Bigram: ('GCP', 'Business') Count: 1
# Bigram: ('Analyst', '_Finacle') Count: 1
# Bigram: ('_Finacle', 'Exciting') Count: 1
# Bigram: ('Exciting', 'Opportunity') Count: 1
# Bigram: ('Opportunity', '|') Count: 1
# Bigram: ('|', 'Pune') Count: 1
# Bigram: ('Pune', 'Business') Count: 1
# Bigram: ('(', 'Ofsaa') Count: 1
# Bigram: ('Ofsaa', ')') Count: 1
# Bigram: ('Business', 'Insights') Count: 1
# Bigram: ('Insights', 'Analyst') Count: 1
# Bigram: ('Analyst', 'mysql') Count: 1
# Bigram: ('mysql', 'IBU') Count: 1
# Bigram: ('IBU', 'Business') Count: 1
# Bigram: ('Analyst', 'Chartered') Count: 1
# Bigram: ('Chartered', 'Accountant') Count: 1
# Bigram: ('Accountant', 'Business') Count: 1
# Bigram: ('analyst', 'Architect') Count: 1
# Bigram: ('Architect', 'Business') Count: 1
# Bigram: ('(', 'Pre') Count: 1
# Bigram: ('Pre', 'Post') Count: 1
# Bigram: ('Post', ')') Count: 1
# Bigram: ('Analyst', 'German') Count: 1
# Bigram: ('German', 'Business') Count: 1
# Bigram: ('BUSINESS', 'DEVELOPER/BUSINESS') Count: 1
# Bigram: ('DEVELOPER/BUSINESS', 'ANALYST') Count: 1
# Bigram: ('analyst', 'indore') Count: 1
# Bigram: ('indore', '.') Count: 1
# Bigram: ('Analyst-', 'Graduate') Count: 1
# Bigram: ('Graduate', 'Business') Count: 1
# Bigram: ('India', 'Business') Count: 1
# Bigram: ('Analyst', 'Python') Count: 1
# Bigram: ('Python', '@') Count: 1
# Bigram: ('@', 'Hyderabad') Count: 1
# Bigram: ('Hyderabad', '/') Count: 1
# Bigram: ('/', 'Remote') Count: 1
# Bigram: ('Remote', 'Network') Count: 1
# Bigram: ('Analyst', 'Looking') Count: 1
# Bigram: ('Looking', 'Business') Count: 1
# Bigram: ('Analyst', 'Assetsoft') Count: 1
# Bigram: ('Assetsoft', 'Pune') Count: 1
# Bigram: ('Pune', '!') Count: 1
# Bigram: ('Analyst', 'Hiring-Business') Count: 1
# Bigram: ('Hiring-Business', 'Analyst-Americana') Count: 1
# Bigram: ('Analyst-Americana', 'Business') Count: 1
# Bigram: ('(', 'Guidewire') Count: 1
# Bigram: ('Guidewire', 'Policy') Count: 1
# Bigram: ('Policy', 'Center') Count: 1
# Bigram: ('Center', ')') Count: 1
# Bigram: ('|', 'Cigna') Count: 1
# Bigram: ('Cigna', 'Business') Count: 1
# Bigram: ('Analyst', 'Drupal') Count: 1
# Bigram: ('Drupal', 'Experience') Count: 1
# Bigram: ('Analyst', 'Scrum') Count: 1
# Bigram: ('Scrum', 'Master') Count: 1
# Bigram: ('Master', '-') Count: 1
# Bigram: ('FedEx', 'Business') Count: 1
# Bigram: ('-', 'CashOS') Count: 1
# Bigram: ('CashOS', 'Business') Count: 1
# Bigram: ('Training', 'Business') Count: 1
# Bigram: ('FMS', 'Business') Count: 1
# Bigram: ('FMS', 'Hexaware') Count: 1
# Bigram: ('Hexaware', 'hiring') Count: 1
# Bigram: ('hiring', 'Business') Count: 1
# Bigram: ('Analyst', '-Chennai/Bangalore/Mumbai/Pune') Count: 1
# Bigram: ('-Chennai/Bangalore/Mumbai/Pune', 'Manager') Count: 1
# Bigram: (',', 'Female') Count: 1
# Bigram: ('Female', ',') Count: 1
# Bigram: (',', 'Kota') Count: 1
# Bigram: ('Kota', 'Business') Count: 1
# Bigram: ('(', 'Duco') Count: 1
# Bigram: ('Duco', ')') Count: 1
# Bigram: ('Analyst', 'GuideWire') Count: 1
# Bigram: ('GuideWire', 'Business') Count: 1
# Bigram: ('Business', 'Analyst//Timing-') Count: 1
# Bigram: ('Analyst//Timing-', '6PM') Count: 1
# Bigram: ('6PM', '2AM//Exp-6yrs+') Count: 1
# Bigram: ('2AM//Exp-6yrs+', 'Business') Count: 1
# Bigram: ('Opportunity', 'Business') Count: 1
# Bigram: ('Role', '!') Count: 1
# Bigram: ('!', 'Senior') Count: 1
# Bigram: ('Analyst-', 'Manager') Count: 1
# Bigram: ('Analyst', 'IV') Count: 1
# Bigram: ('IV', 'Business') Count: 1
# ...
# Bigram: ('Tableau', 'Sr.') Count: 1
# Bigram: ('Engineer-', 'Bangalore') Count: 1
# Bigram: ('Bangalore', '(') Count: 1
# Bigram: ('Work', 'office') Count: 1
# Bigram: ('office', ')') Count: 1
# Bigram: ('Engineer', 'Clinical') Count: 1
# Bigram: ('Clinical', 'Data') Count: 1
# Bigram: ('Immediate', 'opening') Count: 1
# Bigram: ('opening', 'Data') Count: 1
# Bigram: ('(', 'Databricks') Count: 1
# Bigram: ('Engineer', 'ADF') Count: 1
# Bigram: (',', 'Pyspark') Count: 1
# Bigram: ('(', 'Pipeline') Count: 1
# Bigram: ('Pipeline', ')') Count: 1
# Bigram: ('Mumbai', '/') Count: 1
# Bigram: ('/', 'Kolkata') Count: 1
# Bigram: ('-', 'MNC') Count: 1
# Bigram: ('MNC', 'Gcp') Count: 1
# Bigram: ('Associate', 'Big') Count: 1
# Bigram: ('Engineer', 'GCP/Java') Count: 1
# Bigram: ('GCP/Java', 'Data') Count: 1
# Bigram: ('Hive', '/') Count: 1
# Bigram: ('HBase', 'Data') Count: 1
# Bigram: ('-', 'Etl/data') Count: 1
# Bigram: ('Etl/data', 'Warehousing') Count: 1
# Bigram: ('Warehousing', 'Big') Count: 1
# Bigram: ('DataBeat', 'Data') Count: 1
# Bigram: ('VBA', '/') Count: 1
# Bigram: ('-', 'HDFS') Count: 1
# Bigram: ('HDFS', '/') Count: 1
# Bigram: ('Hive', 'Big') Count: 1
# Bigram: ('Engineer', 'DW') Count: 1
# Bigram: ('DW', 'Big') Count: 1
# Bigram: (',', 'SparkSQL') Count: 1
# Bigram: ('SparkSQL', ')') Count: 1
# Bigram: (')', 'Big') Count: 1
# Bigram: ('engineer', 'GCP') Count: 1
# Bigram: ('Engineer', '+') Count: 1
# Bigram: ('+', 'Python') Count: 1
# Bigram: ('DataBeat', 'Azure') Count: 1
# Bigram: ('Data', 'Lead') Count: 1
# Bigram: ('Engineer', 'Integration') Count: 1
# Bigram: ('Integration', ',') Count: 1
# Bigram: ('Data', 'processing') Count: 1
# Bigram: ('processing', 'Senior') Count: 1
# Bigram: ('Scala', 'Python') Count: 1
# Bigram: ('Senior', 'Finance') Count: 1
# Bigram: ('1', 'Sr.') Count: 1
# Bigram: ('-', 'CTO') Count: 1
# Bigram: ('CTO', '-') Count: 1
# Bigram: ('-', 'SDE') Count: 1
# Bigram: ('SDE', 'Senior') Count: 1
# Bigram: ('Engineer', 'Power') Count: 1
# Bigram: ('Power', 'Programmer') Count: 1
# Bigram: ('Programmer', '-') Count: 1
# Bigram: ('Senior', 'Technologist') Count: 1
# Bigram: ('Technologist', 'Data') Count: 1
# Bigram: ('Engineer-', 'GCP') Count: 1
# Bigram: ('GCP', 'Senior') Count: 1
# Bigram: ('(', 'Snowflake') Count: 1
# Bigram: ('Snowflake', '&') Count: 1
# Bigram: ('&', 'DBT') Count: 1
# Bigram: ('DBT', ')') Count: 1
# Bigram: ('Metadata', 'Senior') Count: 1
# Bigram: ('Metadata', 'Data') Count: 1
# Bigram: ('Ops', '-') Count: 1
# Bigram: ('-', 'X') Count: 1
# Bigram: ('X', 'Delivery') Count: 1
# Bigram: ('Delivery', 'Data') Count: 1
# Bigram: ('(', '5') Count: 1
# Bigram: ('-', '10') Count: 1
# Bigram: ('10', 'Years') Count: 1
# Bigram: ('-', 'EnMasse') Count: 1
# Bigram: ('EnMasse', 'Data') Count: 1
# Bigram: ('Engineer-', 'Scientist') Count: 1
# Bigram: ('Scientist', 'Role') Count: 1
# Bigram: ('Role', '.') Count: 1
# Bigram: ('.', 'DATA') Count: 1
# Bigram: ('Engineer', '-Python') Count: 1
# Bigram: ('-Python', '-') Count: 1
# Bigram: ('-', 'Pyspark') Count: 1
# Bigram: ('SQL', '-') Count: 1
# Bigram: ('-', 'Bigdata') Count: 1
# Bigram: ('Bigdata', 'Data') Count: 1
# Bigram: ('Engineer', 'PostgreSQL') Count: 1
# Bigram: ('PostgreSQL', 'Data') Count: 1
# Bigram: ('Engineer', 'Hodoop+hive+HDFS') Count: 1
# Bigram: ('Hodoop+hive+HDFS', 'Data') Count: 1
# Bigram: ('(', 'ADF/ETL') Count: 1
# Bigram: ('ADF/ETL', ')') Count: 1
# Bigram: ('POD', '-') Count: 1
# Bigram: ('-', 'Offshore') Count: 1
# Bigram: ('Offshore', '4') Count: 1
# Bigram: ('4', 'Data') Count: 1
# Bigram: ('/', 'Power') Count: 1
# Bigram: ('Engineer', 'data') Count: 1
# Bigram: ('Engineer', 'ETL/') Count: 1
# Bigram: ('ETL/', 'Data') Count: 1
# Bigram: ('(', 'Talend') Count: 1
# Bigram: ('Talend', ')') Count: 1
# Bigram: ('Joiner', 'Data') Count: 1
# Bigram: ('Joiner', 'Associate') Count: 1
# Bigram: ('-', 'Manager') Count: 1
# Bigram: ('-', 'Assistant') Count: 1
# Bigram: ('Manager', 'Azure') Count: 1
# Bigram: ('Engineer', 'looking') Count: 1
# Bigram: ('Azure', 'AWS') Count: 1
# Bigram: ('Engineer', 'Environmental') Count: 1
# Bigram: ('Environmental', ',') Count: 1
# Bigram: (',', 'Social') Count: 1
# Bigram: ('Social', 'Governance') Count: 1
# Bigram: ('Governance', '(') Count: 1
# Bigram: ('(', 'ESG') Count: 1
# Bigram: ('ESG', ')') Count: 1
# Bigram: (')', 'Reporting') Count: 1
# Bigram: ('Reporting', 'Data') Count: 1
# Bigram: (',', 'Ad') Count: 1
# Bigram: ('Ad', 'Engineering') Count: 1
# Bigram: ('POD', 'Data') Count: 1
# Bigram: ('Engineer', 'ML') Count: 1
# Bigram: ('ML', 'Engineer/') Count: 1
# Bigram: ('(', 'SQL_Informatica') Count: 1
# Bigram: ('SQL_Informatica', ')') Count: 1
# Bigram: ('Engineer', 'Enterprise') Count: 1
# Bigram: ('Engineer', 'Aruba-NaaS') Count: 1
# Bigram: ('Aruba-NaaS', 'Data') Count: 1
# Bigram: ('ETL', 'Data') Count: 1
# Bigram: ('Solution', 'Engineer-') Count: 1
# Bigram: ('Engineer-', 'Data') Count: 1
# Bigram: ('Analyst', 'data') Count: 1
# Bigram: ('-', 'ADF') Count: 1
# Bigram: (',', 'ADL') Count: 1
# Bigram: ('ADL', ',') Count: 1
# Bigram: (',', 'ADLS') Count: 1
# Bigram: ('ADLS', 'Gen2') Count: 1
# Bigram: ('Gen2', ',') Count: 1
# Bigram: (',', 'DWH') Count: 1
# Bigram: ('DWH', ',') Count: 1
# Bigram: (',', 'DM') Count: 1
# Bigram: ('DM', 'Technical') Count: 1
# Bigram: ('/', 'Technical') Count: 1
# Bigram: ('AWS', 'looking') Count: 1
# Bigram: ('Lead', 'ETL/Data') Count: 1
# Bigram: ('ETL/Data', 'Engineer') Count: 1
# Bigram: ('Big', 'Data/GCP') Count: 1
# Bigram: ('Data/GCP', 'Data') Count: 1
# Bigram: ('(', 'Spark-Scala') Count: 1
# Bigram: ('Spark-Scala', ')') Count: 1
# Bigram: ('/', 'Architect') Count: 1
# Bigram: ('Architect', 'Senior') Count: 1
# Bigram: ('Kafka', '/') Count: 1
# Bigram: ('/', 'SQL') Count: 1
# Bigram: ('SQL', 'Sr.') Count: 1
# Bigram: ('Talend', 'Big') Count: 1
# Bigram: ('Engineer/Data', 'Engineer') Count: 1
# Bigram: ('Engineer-', 'Senior') Count: 1
# Bigram: ('Senior', 'Senior') Count: 1
# Bigram: ('-', 'Leading') Count: 1
# Bigram: ('Leading', 'Product') Count: 1
# Bigram: ('Product', 'Based') Count: 1
# Bigram: ('Based', 'Industrial') Count: 1
# Bigram: ('Industrial', 'Automation') Count: 1
# Bigram: ('Automation', 'Senior') Count: 1
# Bigram: ('SQL/Python', 'Senior') Count: 1
# Bigram: ('Engineer-Lead/Architect', 'Senior') Count: 1
# Bigram: ('Engineer-Lead/Architect', 'Data') Count: 1
# Bigram: ('III', '|') Count: 1
# Bigram: ('II', '|') Count: 1
# Bigram: ('ETL', 'Azure') Count: 1
# Bigram: ('Azure', 'Azure') Count: 1
# Bigram: ('-', 'US') Count: 1
# Bigram: ('US', 'MNC') Count: 1
# Bigram: ('Engineer', 'Job') Count: 1
# Bigram: ('opportunity', 'Data') Count: 1
# Bigram: ('Engineer', 'Apexon') Count: 1
# Bigram: ('Apexon', 'Pune') Count: 1
# Bigram: ('Pune', 'Location') Count: 1
# Bigram: ('Location', '(') Count: 1
# Bigram: ('WFO', ')') Count: 1
# Bigram: ('Data', 'Engineer-Python-') Count: 1
# Bigram: ('Engineer-Python-', '(') Count: 1
# Bigram: ('(', 'Bangalore') Count: 1
# Bigram: ('Bangalore', ',') Count: 1
# Bigram: (',', 'Gurgaon') Count: 1
# Bigram: ('Gurgaon', ',') Count: 1
# Bigram: (',', 'Chennai') Count: 1
# Bigram: ('Chennai', ',') Count: 1
# Bigram: ('Pune', ',') Count: 1
# Bigram: (',', 'Mumbai') Count: 1
# Bigram: ('(', 'SunOPS') Count: 1
# Bigram: ('SunOPS', ')') Count: 1
# Bigram: (')', 'Snowflake') Count: 1
# Bigram: ('Snowflake', 'Developer') Count: 1
# Bigram: ('Snowflake', 'Engineer') Count: 1
# Bigram: ('Engineer', 'Opening') Count: 1
# Bigram: ('Platform', ')') Count: 1
# Bigram: ('Mahindra', 'Azure') Count: 1
# Bigram: ('Warehouse', 'Azure') Count: 1
# Bigram: ('Data', 'platform') Count: 1
# Bigram: ('platform', ')') Count: 1
# Bigram: ('-', 'GCP') Count: 1
# Bigram: ('GCP', 'Aws') Count: 1
# Bigram: ('Engineer', 'Solution') Count: 1
# Bigram: ('Solution', 'Design') Count: 1
# Bigram: ('Design', 'Expert') Count: 1
# Bigram: ('Engineer', 'Database/') Count: 1
# Bigram: ('Engineer', 'ELK') Count: 1
# Bigram: ('ELK', '(') Count: 1
# Bigram: ('Work', 'Remotely') Count: 1
# Bigram: ('Remotely', 'Data') Count: 1
# Bigram: ('(', 'Python+SQL+Spark') Count: 1
# Bigram: ('Python+SQL+Spark', ')') Count: 1
# Bigram: ('@', 'Vijayawada') Count: 1
# Bigram: ('Vijayawada', 'L1') Count: 1
# Bigram: ('L1', 'Data') Count: 1
# Bigram: ('Engineer', 'Gurgoan') Count: 1
# Bigram: ('Gurgoan', 'VS') Count: 1
# Bigram: ('VS', 'L2') Count: 1
# Bigram: ('L2', 'Data') Count: 1
# Bigram: ('VS', 'L3') Count: 1
# Bigram: ('L3', 'Data') Count: 1
# Bigram: ('VS', 'Data') Count: 1
# Bigram: ('Data', 'Engineer/ACD/DADW/5167/Amdocs') Count: 1
# Bigram: ('Engineer/ACD/DADW/5167/Amdocs', 'Data') Count: 1
# Bigram: ('Python', '&') Count: 1
# Bigram: ('&', 'SQL') Count: 1
# Bigram: ('SQL', ')') Count: 1
# Bigram: ('-', 'Building') Count: 1
# Bigram: ('Building', 'Reports') Count: 1
# Bigram: ('Reports', '&') Count: 1
# Bigram: ('&', 'Dashboard') Count: 1
# Bigram: ('Dashboard', '-') Count: 1
# Bigram: ('-', '2+') Count: 1
# Bigram: ('2+', 'Years') Count: 1
# Bigram: ('Years', 'Data') Count: 1
# Bigram: ('-', 'Semantics') Count: 1
# Bigram: ('Semantics', 'Data') Count: 1
# Bigram: ('Data', 'Analyst/') Count: 1
# Bigram: ('Analyst/', 'Data') Count: 1
# Bigram: ('Engineer', 'Database/Data') Count: 1
# Bigram: ('Database/Data', 'Infrastructure') Count: 1
# Bigram: ('Infrastructure', 'Engineer') Count: 1
# Bigram: ('(', 'Matillion') Count: 1
# Bigram: ('Matillion', '+') Count: 1
# Bigram: ('+', 'Snowflake') Count: 1
# Bigram: ('Snowflake', ')') Count: 1
# Bigram: ('(', 'Informatica') Count: 1
# Bigram: ('Informatica', 'Power') Count: 1
# Bigram: ('Power', 'Centre') Count: 1
# Bigram: ('Centre', ')') Count: 1
# Bigram: (')', 'Module') Count: 1
# Bigram: ('Data', 'Modeling/Warehousing') Count: 1
# Bigram: ('Modeling/Warehousing', 'Solutions') Count: 1
# Bigram: ('-', 'Presales') Count: 1
# Bigram: ('Presales', '(') Count: 1
# Bigram: ('Data/', 'Data') Count: 1
# Bigram: (')', 'Graduate') Count: 1
# Bigram: ('Graduate', 'Program') Count: 1
# Bigram: ('Program', 'Big') Count: 1
# Bigram: ('Engineering', 'AWS') Count: 1
# Bigram: ('|', 'SQL') Count: 1
# Bigram: ('SQL', '|') Count: 1
# Bigram: ('|', 'Oracle') Count: 1
# Bigram: ('Oracle', '|') Count: 1
# Bigram: ('|', 'Data') Count: 1
# Bigram: ('Migration', 'Infogain') Count: 1
# Bigram: ('-', 'Google') Count: 1
# Bigram: ('Google', 'Cloud') Count: 1
# Bigram: ('Platform', 'Azure') Count: 1
# Bigram: ('Scala', 'Data') Count: 1
# Bigram: ('BI', 'AWS') Count: 1
# Bigram: ('(', 'Contract') Count: 1
# Bigram: ('Contract', ')') Count: 1
# Bigram: ('-', 'Databricks') Count: 1
# Bigram: ('Databricks', '/') Count: 1
# Bigram: ('Data', 'Warehousing') Count: 1
# Bigram: ('Warehousing', 'Solutions') Count: 1
# Bigram: ('Architect', '-Data') Count: 1
# Bigram: ('-Data', 'Engineering') Count: 1
# Bigram: ('Engineer', '-EDW') Count: 1
# Bigram: ('-EDW', 'Azure') Count: 1
# Bigram: ('Engineer', 'Fresher') Count: 1
# Bigram: ('Fresher', '-') Count: 1
# Bigram: ('Engineering', 'Sr') Count: 1
# Bigram: ('-', 'Optum') Count: 1
# Bigram: ('Optum', 'Senior') Count: 1
# Bigram: ('Engineer', '-Oracle') Count: 1
# Bigram: ('-Oracle', 'Data') Count: 1
# Bigram: ('Data', 'Integrator') Count: 1
# Bigram: ('Integrator', 'Senior') Count: 1
# Bigram: ('Senior', 'AWS') Count: 1
# Bigram: ('-', 'Hadoop/hive/pig') Count: 1
# Bigram: ('Hadoop/hive/pig', 'Senior') Count: 1
# Bigram: (',', 'Java') Count: 1
# Bigram: (',', 'Enterprise') Count: 1
# Bigram: ('BI', ',') Count: 1
# Bigram: (',', 'DAX') Count: 1
# Bigram: (')', '-Remote') Count: 1
# Bigram: ('-Remote', 'Senior') Count: 1
# Bigram: ('Cloud', 'Architect') Count: 1
# Bigram: ('Snowflake', 'Senior') Count: 1
# Bigram: ('Senior', 'AC') Count: 1
# Bigram: ('AC', '-Data') Count: 1
# Bigram: ('AWS', 'Redshift') Count: 1
# Bigram: ('Redshift', 'Senior') Count: 1
# Bigram: ('Senior', 'Python') Count: 1
# Bigram: ('Business', 'Analyst/Data') Count: 1
# Bigram: ('Analyst/Data', 'Analyst/Data') Count: 1
# Bigram: ('Senior', 'Analytics') Count: 1
# Bigram: ('Analytics', 'Engineer') Count: 1
# Bigram: ('Senior', 'GCP') Count: 1
# Bigram: ('Sr', 'Azure') Count: 1
# Bigram: ('Senior', 'R') Count: 1
# Bigram: ('&', 'Engineer') Count: 1
# Bigram: ('(', 'C++') Count: 1
# Bigram: ('C++', ',') Count: 1
# Bigram: ('&', 'Algorithms') Count: 1
# Bigram: ('Algorithms', ')') Count: 1
# Bigram: ('Senior', 'Staff') Count: 1
# Bigram: ('Data', ')') Count: 1
# Bigram: ('(', 'Jr/Sr/Lead') Count: 1
# Bigram: ('Jr/Sr/Lead', ')') Count: 1
# Bigram: (',', 'Product') Count: 1
# Bigram: ('Product', 'AWS') Count: 1
# Bigram: ('||', 'bangalore/') Count: 1
# Bigram: ('bangalore/', 'Hyderabad') Count: 1
# Bigram: ('Hyderabad', 'Infogain') Count: 1
# Bigram: ('Bangalore', 'Aws') Count: 1
# Bigram: ('Engineer', 'AZURE') Count: 1
# Bigram: ('AZURE', 'DATA') Count: 1
# Bigram: ('ENGINEER', 'Azure') Count: 1
# Bigram: ('-', 'DataLake/Data') Count: 1
# Bigram: ('DataLake/Data', 'Factory') Count: 1
# Bigram: ('Factory', 'Azure') Count: 1
# Bigram: ('ADF', '&') Count: 1
# Bigram: ('Synapse', 'Azure') Count: 1
# Bigram: ('ADF', 'Azure') Count: 1
# Bigram: ('Synapse', ')') Count: 1
# Bigram: ('III', 'DATA') Count: 1
# Bigram: ('ENGINEER', 'III') Count: 1
# Bigram: ('III', 'Data') Count: 1
# Bigram: ('engineer', 'Snowflake') Count: 1
# Bigram: ('Snowflake', 'Kinaxis') Count: 1
# Bigram: ('Kinaxis', 'Process') Count: 1
# Bigram: ('Process', 'Data') Count: 1
# Bigram: ('Data', 'Engineer/Visualization') Count: 1
# Bigram: ('Engineer/Visualization', 'Expert') Count: 1
# Bigram: ('Expert', 'TS') Count: 1
# Bigram: ('Specialist', 'AWS') Count: 1
# Bigram: ('IoT', 'Data') Count: 1
# Bigram: ('(', 'ETL') Count: 1
# Bigram: ('ETL', 'Developer') Count: 1
# Bigram: ('Technical', 'Program') Count: 1
# Bigram: ('Program', 'Manager') Count: 1
# Bigram: ('Engineer', 'Software') Count: 1
# Bigram: ('3', '-') Count: 1
# Bigram: ('Engineering', 'GCP') Count: 1
# Bigram: ('Data', 'Engineer/Tech') Count: 1
# Bigram: ('Engineer/Tech', 'Python-') Count: 1
# Bigram: ('Python-', 'Data') Count: 1
# Bigram: ('Manager', '|') Count: 1
# Bigram: ('FedEx', 'Principal') Count: 1
# Bigram: ('Immediate', 'Opening') Count: 1
# Bigram: ('Opening', 'Azure') Count: 1
# Bigram: ('Azure', 'Architect') Count: 1
# Bigram: ('Architect', '(') Count: 1
# Bigram: (')', 'Infogain') Count: 1
# Bigram: ('India', 'Principal') Count: 1
# Bigram: ('(', 'DBT/Snowflake') Count: 1
# Bigram: ('DBT/Snowflake', ')') Count: 1
# Bigram: ('-', 'Medical') Count: 1
# Bigram: ('Medical', 'Reporting') Count: 1
# Bigram: ('Analytics', '|') Count: 1
# Bigram: ('|', 'Talent500') Count: 1
# Bigram: ('Talent500', 'Data') Count: 1
# Bigram: (',', 'GCP') Count: 1
# Bigram: ('@', 'pune') Count: 1
# Bigram: ('pune', 'location') Count: 1
# Bigram: ('location', '/Work') Count: 1
# Bigram: ('/Work', 'Ofice') Count: 1
# Bigram: ('Ofice', 'Data') Count: 1
# Bigram: ('AWS', 'DATA') Count: 1
# Bigram: ('ENGINEER', 'Associate') Count: 1
# Bigram: ('Pricing', 'Data') Count: 1
# Bigram: ('Engineer', 'Assistant') Count: 1
# Bigram: ('Opening', ':') Count: 1
# Bigram: (':', 'Gurgaon') Count: 1
# Bigram: ('Gurgaon', ':') Count: 1
# Bigram: (':', 'Hybrid') Count: 1
# Bigram: ('Hybrid', 'Data') Count: 1
# Bigram: ('Analyst', 'Azure') Count: 1
# Bigram: ('Engineer', 'Aws') Count: 1
# Bigram: ('-', 'Gcp') Count: 1
# Bigram: ('Pricing', '(') Count: 1
# Bigram: ('(', '18') Count: 1
# Bigram: ('18', 'months') Count: 1
# Bigram: ('months', 'FTC') Count: 1
# Bigram: ('FTC', ')') Count: 1
# Bigram: (')', 'DataStage') Count: 1
# Bigram: ('DataStage', 'Data') Count: 1
# Bigram: ('engineer', 'Associate') Count: 1
# Bigram: ('Associate', 'Manager-Reporting') Count: 1
# Bigram: ('Manager-Reporting', 'Factory') Count: 1
# Bigram: ('Factory', '-') Count: 1
# Bigram: ('II', 'Azure') Count: 1
# Bigram: ('Engineering', 'Azure') Count: 1
# Bigram: ('Developers', 'Data') Count: 1
# Bigram: ('Data', 'Model') Count: 1
# Bigram: ('Model', 'Engineer') Count: 1
# Bigram: ('Python', 'Backend') Count: 1
# Bigram: ('Backend', 'Developer') Count: 1
# Bigram: ('Engineer', 'Master') Count: 1
# Bigram: ('VBA', 'Data') Count: 1
# Bigram: ('Data', 'Architect') Count: 1
# Bigram: ('Engineering', 'Architect') Count: 1
# Bigram: ('Architect', '@') Count: 1
# Bigram: ('Lead', ',') Count: 1
# Bigram: ('Ops', 'Lead') Count: 1
# Bigram: ('Lead', 'GCP') Count: 1
# Bigram: ('-', 'Python/SQL') Count: 1
# Bigram: ('Python/SQL', 'Data') Count: 1
# Bigram: ('-', 'ETL/Data') Count: 1
# Bigram: ('ETL/Data', 'Pipeline') Count: 1
# Bigram: ('Pipeline', 'Data') Count: 1
# Bigram: (',', 'Kafka') Count: 1
# Bigram: ('Kafka', '&') Count: 1
# Bigram: ('&', 'Spark') Count: 1
# Bigram: ('Spark', 'Streaming') Count: 1
# Bigram: ('Streaming', 'Hiring') Count: 1
# Bigram: ('Lead', 'Lead') Count: 1
# Bigram: ('Engineer', 'Tech') Count: 1
# Bigram: ('/', 'SME') Count: 1
# Bigram: ('SME', 'Lead') Count: 1

# %%
for trigram, count in sorted_trigrams:
    print('Trigram:',trigram, 'Count:', count)
# Out:
# Trigram: ('Business', 'Analyst', 'Business') Count: 673
# Trigram: ('Analyst', 'Business', 'Analyst') Count: 652
# Trigram: ('Data', 'Engineer', 'Data') Count: 430
# Trigram: ('Engineer', 'Data', 'Engineer') Count: 402
# Trigram: ('Application', 'Developer', 'SAP') Count: 318
# Trigram: ('Data', 'Scientist', 'Data') Count: 269
# Trigram: ('Scientist', 'Data', 'Scientist') Count: 245
# Trigram: ('Application', 'Developer', 'Microsoft') Count: 166
# Trigram: ('Services', 'Application', 'Developer') Count: 102
# Trigram: ('Data', 'Services', 'Application') Count: 96
# Trigram: ('Senior', 'Data', 'Scientist') Count: 95
# Trigram: ('Data', 'Engineer', '-') Count: 91
# Trigram: ('Senior', 'Data', 'Engineer') Count: 82
# Trigram: ('Data', 'Scientist', 'Senior') Count: 81
# Trigram: ('Developer', 'Microsoft', 'Dynamics') Count: 78
# Trigram: (')', 'Application', 'Developer') Count: 70
# Trigram: ('Technical', 'Application', 'Developer') Count: 70
# Trigram: ('Data', 'Engineer', 'Senior') Count: 69
# Trigram: ('HANA', 'Application', 'Developer') Count: 67
# Trigram: ('Developer', 'SAP', 'ABAP') Count: 63
# Trigram: ('SAP', 'ABAP', 'Development') Count: 62
# Trigram: ('Scientist', 'Senior', 'Data') Count: 62
# Trigram: ('Development', 'Application', 'Developer') Count: 55
# Trigram: ('Data', 'Scientist', '-') Count: 53
# Trigram: ('Engineer', 'Senior', 'Data') Count: 53
# Trigram: ('ABAP', 'Development', 'HANA') Count: 52
# Trigram: ('Development', 'HANA', 'Application') Count: 52
# Trigram: ('Business', 'Analyst', '-') Count: 51
# Trigram: ('Azure', 'Data', 'Engineer') Count: 50
# Trigram: ('Data', 'Engineer', '(') Count: 48
# Trigram: ('Big', 'Data', 'Engineer') Count: 47
# Trigram: ('Developer', 'Microsoft', 'Azure') Count: 46
# Trigram: ('Developer', 'SAP', 'FI') Count: 44
# Trigram: ('Microsoft', 'Azure', 'Data') Count: 43
# Trigram: ('Azure', 'Data', 'Services') Count: 43
# Trigram: ('Microsoft', 'Dynamics', '365') Count: 42
# Trigram: ('Lead', 'Data', 'Scientist') Count: 40
# Trigram: ('Finance', 'Application', 'Developer') Count: 39
# Trigram: ('Hadoop', 'Developer', 'Hadoop') Count: 38
# Trigram: ('Developer', 'Hadoop', 'Developer') Count: 35
# Trigram: ('Microsoft', 'Dynamics', 'CRM') Count: 34
# Trigram: ('Dynamics', 'CRM', 'Technical') Count: 34
# Trigram: ('CRM', 'Technical', 'Application') Count: 34
# Trigram: ('Developer', 'SAP', 'Sales') Count: 33
# Trigram: ('Distribution', '(', 'SD') Count: 33
# Trigram: ('(', 'SD', ')') Count: 33
# Trigram: ('SD', ')', 'Application') Count: 33
# Trigram: ('SAP', 'Sales', 'Distribution') Count: 32
# Trigram: ('Sales', 'Distribution', '(') Count: 32
# Trigram: ('Business', 'Analyst', '(') Count: 31
# Trigram: ('Big', 'Data', 'Developer') Count: 29
# Trigram: ('SAP', 'BusinessObjects', 'Data') Count: 29
# Trigram: ('BusinessObjects', 'Data', 'Services') Count: 29
# Trigram: ('Management', 'Application', 'Developer') Count: 29
# Trigram: ('SAP', 'FI', 'CO') Count: 29
# Trigram: ('FI', 'CO', 'Finance') Count: 29
# Trigram: ('CO', 'Finance', 'Application') Count: 29
# Trigram: ('Data', 'Scientist', 'Lead') Count: 29
# Trigram: (')', 'Data', 'Engineer') Count: 29
# Trigram: ('Application', 'Developer', ':') Count: 28
# Trigram: ('Developer', 'SAP', 'BusinessObjects') Count: 27
# Trigram: ('Full', 'Stack', 'Development') Count: 27
# Trigram: ('Stack', 'Development', 'Application') Count: 27
# Trigram: ('Dynamics', '365', 'ERP') Count: 26
# Trigram: ('365', 'ERP', 'Technical') Count: 26
# Trigram: ('ERP', 'Technical', 'Application') Count: 26
# Trigram: ('Developer', ':', 'SAP') Count: 26
# Trigram: ('Data', 'Engineer', 'Azure') Count: 26
# Trigram: (')', 'Business', 'Analyst') Count: 25
# Trigram: ('Application', 'Developer', 'Java') Count: 25
# Trigram: ('Engineer', 'Azure', 'Data') Count: 25
# Trigram: ('Microsoft', 'SQL', 'Server') Count: 24
# Trigram: ('Scientist', 'Lead', 'Data') Count: 24
# Trigram: ('Engineer', 'Big', 'Data') Count: 23
# Trigram: ('Data', 'Scientist', '(') Count: 23
# Trigram: ('Developer', 'Microsoft', 'SQL') Count: 22
# Trigram: ('Data', 'Engineer', 'Big') Count: 22
# Trigram: ('Java', 'Full', 'Stack') Count: 21
# Trigram: ('Snowflake', 'Data', 'Warehouse') Count: 20
# Trigram: ('Data', 'Warehouse', 'Application') Count: 20
# Trigram: ('Warehouse', 'Application', 'Developer') Count: 20
# Trigram: ('Engineering', 'Application', 'Developer') Count: 20
# Trigram: ('-', 'Data', 'Scientist') Count: 20
# Trigram: ('Application', 'Developer', 'Advanced') Count: 19
# Trigram: ('Developer', 'Advanced', 'Embedded') Count: 19
# Trigram: ('Advanced', 'Embedded', 'System') Count: 19
# Trigram: ('Embedded', 'System', 'Engineering') Count: 19
# Trigram: ('System', 'Engineering', 'Application') Count: 19
# Trigram: ('Sr.', 'Data', 'Scientist') Count: 19
# Trigram: ('Business', 'Analyst', 'BUSINESS') Count: 18
# Trigram: ('Developer', 'SAP', 'CPI') Count: 18
# Trigram: ('SAP', 'CPI', 'Data') Count: 18
# Trigram: ('CPI', 'Data', 'Services') Count: 18
# Trigram: ('Application', 'Developer', 'Snowflake') Count: 18
# Trigram: ('Developer', 'Snowflake', 'Data') Count: 18
# Trigram: ('Platform', 'Application', 'Developer') Count: 18
# Trigram: (':', 'SAP', 'ABAP') Count: 18
# Trigram: ('SAP', 'Master', 'Data') Count: 17
# Trigram: ('Engineer', '-', 'Data') Count: 17
# Trigram: ('Analyst', 'BUSINESS', 'ANALYST') Count: 16
# Trigram: ('Developer', 'Java', 'Full') Count: 16
# Trigram: ('Application', 'Developer', 'Application') Count: 16
# Trigram: ('BUSINESS', 'ANALYST', 'Business') Count: 15
# Trigram: ('Data', 'Developer', '-') Count: 15
# Trigram: ('Developer', 'SAP', 'Master') Count: 15
# Trigram: ('Application', 'Developer', 'Oracle') Count: 15
# Trigram: ('Developer', 'Java', 'Developer') Count: 15
# Trigram: ('Developer', 'Application', 'Developer') Count: 15
# Trigram: ('SAP', 'ABAP', 'HANA') Count: 15
# Trigram: ('-', 'Data', 'Science') Count: 15
# Trigram: ('Data', 'Scientist', '/') Count: 15
# Trigram: ('Manager', '-', 'B2C') Count: 15
# Trigram: ('-', 'B2C', 'Underwriting') Count: 15
# Trigram: ('-', 'Business', 'Analyst') Count: 14
# Trigram: ('Master', 'Data', 'Governance') Count: 14
# Trigram: ('Data', 'Governance', 'MDG') Count: 14
# Trigram: ('Governance', 'MDG', 'Tool') Count: 14
# Trigram: ('MDG', 'Tool', 'Application') Count: 14
# Trigram: ('Tool', 'Application', 'Developer') Count: 14
# Trigram: ('Application', 'Developer', 'Data') Count: 14
# Trigram: ('Accounting', 'Application', 'Developer') Count: 14
# Trigram: ('Manufacturing', 'Engineering', 'MES') Count: 14
# Trigram: ('Engineering', 'MES', 'Application') Count: 14
# Trigram: ('MES', 'Application', 'Developer') Count: 14
# Trigram: (')', 'Data', 'Scientist') Count: 14
# Trigram: ('ANALYST', 'Business', 'Analyst') Count: 13
# Trigram: ('SAP', 'FI', 'S/4HANA') Count: 13
# Trigram: ('SQL', 'Server', 'Integration') Count: 13
# Trigram: ('Server', 'Integration', 'Services') Count: 13
# Trigram: ('Integration', 'Services', 'SSIS') Count: 13
# Trigram: ('Services', 'SSIS', 'Application') Count: 13
# Trigram: ('SSIS', 'Application', 'Developer') Count: 13
# Trigram: ('Developer', 'Microsoft', 'Power') Count: 13
# Trigram: ('Developer', 'Manufacturing', 'Engineering') Count: 13
# Trigram: ('Scientist', 'Data', 'Science') Count: 13
# Trigram: ('-', 'Data', 'Engineer') Count: 13
# Trigram: ('Developer', 'Big', 'Data') Count: 12
# Trigram: ('Senior', 'Big', 'Data') Count: 12
# Trigram: ('Java', 'Developer', 'Java') Count: 12
# Trigram: ('Functional', 'Application', 'Developer') Count: 12
# Trigram: ('FI', 'S/4HANA', 'Accounting') Count: 12
# Trigram: ('S/4HANA', 'Accounting', 'Application') Count: 12
# Trigram: ('Application', 'Developer', 'Manufacturing') Count: 12
# Trigram: ('Junior', 'Data', 'Scientist') Count: 12
# Trigram: ('Administration', 'Application', 'Developer') Count: 11
# Trigram: ('SQL', 'Server', 'Analysis') Count: 11
# Trigram: ('Server', 'Analysis', 'Services') Count: 11
# Trigram: ('Analysis', 'Services', '(') Count: 11
# Trigram: ('Services', '(', 'SSAS') Count: 11
# Trigram: ('(', 'SSAS', ')') Count: 11
# Trigram: ('SSAS', ')', 'Application') Count: 11
# Trigram: ('Application', 'Developer', '.Net') Count: 11
# Trigram: ('Developer', '.Net', 'Full') Count: 11
# Trigram: ('.Net', 'Full', 'Stack') Count: 11
# Trigram: ('B2C', 'Underwriting', 'Rural') Count: 11
# Trigram: ('-', 'Machine', 'Learning') Count: 11
# Trigram: ('Lead', 'Data', 'Engineer') Count: 11
# Trigram: ('Python', 'Data', 'Engineer') Count: 11
# Trigram: ('Pegasystems', 'Platform', 'Application') Count: 10
# Trigram: ('Application', 'Developer', 'Salesforce') Count: 10
# Trigram: ('Data', 'Science', 'Data') Count: 10
# Trigram: ('Principal', 'Data', 'Scientist') Count: 10
# Trigram: ('Deputy', 'Area', 'Manager') Count: 10
# Trigram: ('Area', 'Manager', '-') Count: 10
# Trigram: ('Scientist', '-', 'Machine') Count: 10
# Trigram: ('GCP', 'Data', 'Engineer') Count: 10
# Trigram: ('&', 'Development', 'Application') Count: 9
# Trigram: ('Data', 'Engineer', 'Java') Count: 9
# Trigram: ('/', 'Data', 'Engineer') Count: 9
# Trigram: ('Developer', 'SAP', 'Business') Count: 9
# Trigram: ('Developer', 'SAP', 'MM') Count: 9
# Trigram: ('SAP', 'MM', 'Materials') Count: 9
# Trigram: ('MM', 'Materials', 'Management') Count: 9
# Trigram: ('Materials', 'Management', 'Application') Count: 9
# Trigram: ('SAP', 'FICO', 'Finance') Count: 9
# Trigram: ('FICO', 'Finance', 'Application') Count: 9
# Trigram: ('Microsoft', 'Power', 'BI') Count: 9
# Trigram: ('Power', 'BI', 'Application') Count: 9
# Trigram: ('BI', 'Application', 'Developer') Count: 9
# Trigram: ('Edition', 'Application', 'Developer') Count: 9
# Trigram: ('Sr', 'Data', 'Scientist') Count: 9
# Trigram: ('Lead', '-', 'Data') Count: 9
# Trigram: ('Research', 'Scientist', '-') Count: 9
# Trigram: ('Engineer', 'Data', 'engineer') Count: 9
# Trigram: ('Data', 'Engineer', '|') Count: 9
# Trigram: ('Data', 'Engineering', 'Data') Count: 9
# Trigram: ('Manager', 'Business', 'Analyst') Count: 8
# Trigram: ('Hadoop', 'Developer', '-') Count: 8
# Trigram: ('Data', 'Modeling', '&') Count: 8
# Trigram: ('Modeling', '&', 'Development') Count: 8
# Trigram: ('Developer', '/', 'Data') Count: 8
# Trigram: ('ABAP', 'Development', '-') Count: 8
# Trigram: ('Development', '-', 'HANA') Count: 8
# Trigram: ('-', 'HANA', 'Application') Count: 8
# Trigram: ('Java', 'Enterprise', 'Edition') Count: 8
# Trigram: ('Enterprise', 'Edition', 'Application') Count: 8
# Trigram: ('Data', 'Science', '-') Count: 8
# Trigram: ('Data', 'Scientist', 'Research') Count: 8
# Trigram: ('Science', 'Data', 'Scientist') Count: 8
# Trigram: ('Data', 'Scientist', 'Sr.') Count: 8
# Trigram: ('Scientist', 'Sr.', 'Data') Count: 8
# Trigram: ('|', 'FedEx', 'Data') Count: 8
# Trigram: ('Associate', 'Data', 'Scientist') Count: 8
# Trigram: ('Data', 'Scientist', 'Principal') Count: 8
# Trigram: ('Engineer', 'Data', 'Scientist') Count: 8
# Trigram: (')', 'Senior', 'Data') Count: 8
# Trigram: ('Engineer', 'Data', 'Engineers') Count: 8
# Trigram: ('Sr.', 'Data', 'Engineer') Count: 8
# Trigram: ('Engineer', 'Data', 'Engineering') Count: 8
# Trigram: ('Data', 'Engineer', ':') Count: 8
# Trigram: ('Data', 'Engineer', ',') Count: 8
# Trigram: ('/', 'Business', 'Analyst') Count: 7
# Trigram: ('Engineer', '-', 'Big') Count: 7
# Trigram: ('Java', 'Developer', '/') Count: 7
# Trigram: ('Data', 'Analysis', '&') Count: 7
# Trigram: ('Analysis', '&', 'Interpretation') Count: 7
# Trigram: ('&', 'Interpretation', 'Application') Count: 7
# Trigram: ('Interpretation', 'Application', 'Developer') Count: 7
# Trigram: ('Dynamics', '365', 'Finance') Count: 7
# Trigram: ('365', 'Finance', 'Functional') Count: 7
# Trigram: ('Finance', 'Functional', 'Application') Count: 7
# Trigram: ('ABAP', 'HANA', 'Application') Count: 7
# Trigram: ('Application', 'Developer', 'Pegasystems') Count: 7
# Trigram: ('Developer', 'Pegasystems', 'Platform') Count: 7
# Trigram: ('Developer', 'SAP', 'FICO') Count: 7
# Trigram: ('Manager', '-', 'Data') Count: 7
# Trigram: ('Staff', 'Data', 'Scientist') Count: 7
# Trigram: ('Data', 'Scientist', 'Junior') Count: 7
# Trigram: ('Scientist', 'Junior', 'Data') Count: 7
# Trigram: ('/', 'Data', 'Scientist') Count: 7
# Trigram: ('Data', 'Scientist', 'Sr') Count: 7
# Trigram: ('Scientist', 'Principal', 'Data') Count: 7
# Trigram: (',', 'Data', 'Scientist') Count: 7
# Trigram: ('Underwriting', 'Rural', 'Deputy') Count: 7
# Trigram: ('Rural', 'Deputy', 'Area') Count: 7
# Trigram: ('FedEx', 'Data', 'Engineer') Count: 7
# Trigram: ('Data', 'Engineer', 'Python') Count: 7
# Trigram: ('Data', 'Engineer', 'Sr.') Count: 7
# Trigram: ('engineer', 'Data', 'Engineer') Count: 7
# Trigram: ('Engineer', '-', 'Power') Count: 7
# Trigram: ('Data', 'Engineers', 'Data') Count: 7
# Trigram: ('AWS', 'Data', 'Engineer') Count: 7
# Trigram: ('Data', 'Engineer', 'Lead') Count: 7
# Trigram: ('Business', 'Analyst', 'Job') Count: 6
# Trigram: ('Analyst', 'Business', 'Analysts') Count: 6
# Trigram: ('Analyst', 'Business', 'Analyst-') Count: 6
# Trigram: ('Business', 'Analyst', ',') Count: 6
# Trigram: ('Developer', 'Data', 'Engineer') Count: 6
# Trigram: ('Engineer', '(', 'Spark') Count: 6
# Trigram: ('Java', 'Developer', 'Big') Count: 6
# Trigram: ('Application', 'Developer', 'Senior') Count: 6
# Trigram: ('Developer', 'SAP', 'HCM') Count: 6
# Trigram: ('Process', 'Automation', 'Application') Count: 6
# Trigram: ('Automation', 'Application', 'Developer') Count: 6
# Trigram: ('Microsoft', 'Dynamics', 'AX') Count: 6
# Trigram: ('Dynamics', 'AX', 'Technical') Count: 6
# Trigram: ('AX', 'Technical', 'Application') Count: 6
# Trigram: ('Developer', 'SAP', 'PO/PI') Count: 6
# Trigram: ('SAP', 'PO/PI', '&') Count: 6
# Trigram: ('PO/PI', '&', 'APIs') Count: 6
# Trigram: ('&', 'APIs', 'Development') Count: 6
# Trigram: ('APIs', 'Development', 'Application') Count: 6
# Trigram: (':', 'SAP', 'UX') Count: 6
# Trigram: ('Components', 'Application', 'Developer') Count: 6
# Trigram: ('Developer', 'Data', 'Analysis') Count: 6
# Trigram: ('Software', 'Engineer', '-') Count: 6
# Trigram: ('Data', 'Scientist', 'NLP') Count: 6
# Trigram: ('NLP', 'Data', 'Scientist') Count: 6
# Trigram: ('Data', 'Scientist', 'Associate') Count: 6
# Trigram: ('Data', 'Scientist', 'Manager') Count: 6
# Trigram: ('/', 'Senior', 'Data') Count: 6
# Trigram: ('Data', 'Science', 'Manager') Count: 6
# Trigram: ('Engineer', 'Lead', 'Data') Count: 6
# Trigram: ('Engineer', '-', 'Python') Count: 6
# Trigram: ('Engineering', 'Data', 'Engineer') Count: 6
# Trigram: ('Data', 'Engineer', 'DATA') Count: 6
# Trigram: ('Engineers', 'Data', 'Engineer') Count: 6
# Trigram: ('-', 'Power', 'BI') Count: 6
# Trigram: ('Data', 'Engineer', '||') Count: 6
# Trigram: ('Data', 'Engineering', 'Analyst') Count: 6
# Trigram: ('Business', 'Analyst', '|') Count: 5
# Trigram: ('Analyst', 'Business', 'analyst') Count: 5
# Trigram: ('Business', 'analyst', 'Business') Count: 5
# Trigram: ('analyst', 'Business', 'Analyst') Count: 5
# Trigram: ('(', 'PM', ')') Count: 5
# Trigram: ('Java', 'Big', 'Data') Count: 5
# Trigram: ('Developer', 'SAP', 'BW') Count: 5
# Trigram: ('SAP', 'BW', 'HANA') Count: 5
# Trigram: ('BW', 'HANA', 'Data') Count: 5
# Trigram: ('HANA', 'Data', 'Modeling') Count: 5
# Trigram: ('Senior', 'Java', 'Developer') Count: 5
# Trigram: ('Developer', 'SAP', 'SCM') Count: 5
# Trigram: ('SAP', 'SCM', 'APO') Count: 5
# Trigram: ('SCM', 'APO', 'Advanced') Count: 5
# Trigram: ('APO', 'Advanced', 'Planning') Count: 5
# Trigram: ('Advanced', 'Planning', '&') Count: 5
# Trigram: ('Planning', '&', 'Optimization') Count: 5
# Trigram: ('&', 'Optimization', 'Application') Count: 5
# Trigram: ('Optimization', 'Application', 'Developer') Count: 5
# Trigram: ('Dynamics', '365', 'Operations') Count: 5
# Trigram: ('365', 'Operations', 'Functional') Count: 5
# Trigram: ('Operations', 'Functional', 'Application') Count: 5
# Trigram: ('Developer', 'SAP', 'Governance') Count: 5
# Trigram: ('SAP', 'Governance', 'Risk') Count: 5
# Trigram: ('Governance', 'Risk', 'Compliance') Count: 5
# Trigram: ('Risk', 'Compliance', '(') Count: 5
# Trigram: ('Compliance', '(', 'SAP') Count: 5
# Trigram: ('(', 'SAP', 'GRC') Count: 5
# Trigram: ('SAP', 'GRC', ')') Count: 5
# Trigram: ('GRC', ')', 'Application') Count: 5
# Trigram: ('SAP', 'Business', 'Objects') Count: 5
# Trigram: ('Business', 'Objects', 'Data') Count: 5
# Trigram: ('Objects', 'Data', 'Services') Count: 5
# Trigram: ('Solutions', 'Application', 'Developer') Count: 5
# Trigram: ('Developer', 'SAP', 'PP') Count: 5
# Trigram: ('Developer', 'Java', 'Enterprise') Count: 5
# Trigram: ('Developer', 'Salesforce', 'Lightning') Count: 5
# Trigram: ('Application', 'Developer', 'Siemens') Count: 5
# Trigram: ('Developer', 'Siemens', 'Teamcenter') Count: 5
# Trigram: ('Siemens', 'Teamcenter', 'Application') Count: 5
# Trigram: ('Teamcenter', 'Application', 'Developer') Count: 5
# Trigram: ('Manager', 'Data', 'Scientist') Count: 5
# Trigram: ('Data', 'Scientist', ',') Count: 5
# Trigram: ('Sr', '.', 'Data') Count: 5
# Trigram: ('Scientist', 'Lead', '-') Count: 5
# Trigram: ('Data', 'Scientist', 'Deputy') Count: 5
# Trigram: ('Deputy', 'Manager', '-') Count: 5
# Trigram: ('Data', 'Scientist', 'II') Count: 5
# Trigram: ('Scientist', 'Associate', 'Data') Count: 5
# Trigram: ('Research', 'Scientist/Engineer', '-') Count: 5
# Trigram: ('Scientist/Engineer', '-', 'Computer') Count: 5
# Trigram: ('-', 'Computer', 'Vision/Machine') Count: 5
# Trigram: ('Data', 'Scientist', 'ML') Count: 5
# Trigram: ('Architect', 'Data', 'Engineer') Count: 5
# Trigram: ('Engineer', '|', 'FedEx') Count: 5
# Trigram: ('Engineer', 'Python', 'Data') Count: 5
# Trigram: ('Engineer', 'Sr.', 'Data') Count: 5
# Trigram: ('Data', 'engineer', 'Data') Count: 5
# Trigram: ('Aws', 'Data', 'Engineer') Count: 5
# Trigram: ('Engineer', ':', 'Data') Count: 5
# Trigram: ('Data', 'Engineer', 'AWS') Count: 5
# Trigram: ('Data', 'Engineer', '/') Count: 5
# Trigram: ('-', 'Data', 'Engineering') Count: 5
# Trigram: ('Principal', 'Data', 'Engineer') Count: 5
# Trigram: ('Opening', 'Business', 'Analyst') Count: 4
# Trigram: ('Location', 'Business', 'Analyst') Count: 4
# Trigram: ('Business', 'Analyst', 'Manager') Count: 4
# Trigram: ('Business', 'Analyst', 'Project') Count: 4
# Trigram: ('Hiring', 'Business', 'Analyst') Count: 4
# Trigram: ('Business', 'Analysts', 'Business') Count: 4
# Trigram: ('Analysts', 'Business', 'Analyst') Count: 4
# Trigram: ('Business', 'Analyst', '/') Count: 4
# Trigram: ('Analyst', '(', 'Travel') Count: 4
# Trigram: ('(', 'Travel', '&') Count: 4
# Trigram: ('Hadoop', 'Developers', 'Hadoop') Count: 4
# Trigram: ('Developers', 'Hadoop', 'Developer') Count: 4
# Trigram: ('Data', 'Engineer', 'Hiring') Count: 4
# Trigram: ('Application', 'Developer', 'Hadoop') Count: 4
# Trigram: ('Developer', '-', 'Hadoop/') Count: 4
# Trigram: ('Engineer', 'Java', 'Developer') Count: 4
# Trigram: ('-', 'Big', 'Data') Count: 4
# Trigram: ('Architecture', 'Application', 'Developer') Count: 4
# Trigram: ('SAP', 'HCM', 'Personnel') Count: 4
# Trigram: ('HCM', 'Personnel', 'Administration') Count: 4
# Trigram: ('Personnel', 'Administration', 'Application') Count: 4
# Trigram: ('SAP', 'Global', 'Trade') Count: 4
# Trigram: ('Global', 'Trade', 'Services') Count: 4
# Trigram: ('Trade', 'Services', 'Application') Count: 4
# Trigram: ('Engineer', '(', 'Big') Count: 4
# Trigram: ('(', 'Big', 'Data') Count: 4
# Trigram: ('Developer', 'Microsoft', 'Robotic') Count: 4
# Trigram: ('Microsoft', 'Robotic', 'Process') Count: 4
# Trigram: ('Robotic', 'Process', 'Automation') Count: 4
# Trigram: ('ABAP', 'HANA', 'SAP') Count: 4
# Trigram: ('Microsoft', 'Power', 'Apps') Count: 4
# Trigram: ('Power', 'Apps', 'Application') Count: 4
# Trigram: ('Apps', 'Application', 'Developer') Count: 4
# Trigram: ('SAP', 'PP', '&') Count: 4
# Trigram: ('PP', '&', 'Control') Count: 4
# Trigram: ('Industries', 'Application', 'Developer') Count: 4
# Trigram: ('Developer', 'SAP', 'Plant') Count: 4
# Trigram: ('SAP', 'Plant', 'Maintenance') Count: 4
# Trigram: ('Plant', 'Maintenance', '(') Count: 4
# Trigram: ('Maintenance', '(', 'PM') Count: 4
# Trigram: ('PM', ')', 'Application') Count: 4
# Trigram: ('Dynamics', '365', 'Commerce') Count: 4
# Trigram: ('365', 'Commerce', 'Technical') Count: 4
# Trigram: ('Commerce', 'Technical', 'Application') Count: 4
# Trigram: ('SAP', 'UX', 'Application') Count: 4
# Trigram: ('UX', 'Application', 'Developer') Count: 4
# Trigram: ('Salesforce', 'Lightning', 'Aura') Count: 4
# Trigram: ('Lightning', 'Aura', 'Components') Count: 4
# Trigram: ('Aura', 'Components', 'Application') Count: 4
# Trigram: ('Developer', 'SAP', 'Warehouse') Count: 4
# Trigram: ('SAP', 'Warehouse', 'Management') Count: 4
# Trigram: ('Senior', 'Software', 'Engineer') Count: 4
# Trigram: ('Lead', 'Java', 'Developer') Count: 4
# Trigram: ('Developer', 'Oracle', 'Agile') Count: 4
# Trigram: ('Oracle', 'Agile', 'Product') Count: 4
# Trigram: ('Agile', 'Product', 'Lifecycle') Count: 4
# Trigram: ('Product', 'Lifecycle', 'Management') Count: 4
# Trigram: ('Lifecycle', 'Management', 'Application') Count: 4
# Trigram: ('Developer', 'SAP', 'Ariba') Count: 4
# Trigram: ('Developer', 'Data', 'Modeling') Count: 4
# Trigram: ('Data', 'Modeling', 'Techniques') Count: 4
# Trigram: ('Modeling', 'Techniques', 'Methodologies') Count: 4
# Trigram: ('Techniques', 'Methodologies', 'Application') Count: 4
# Trigram: ('Methodologies', 'Application', 'Developer') Count: 4
# Trigram: ('Developer', 'Microsoft', 'BOT') Count: 4
# Trigram: ('Microsoft', 'BOT', 'Framework') Count: 4
# Trigram: ('BOT', 'Framework', 'Application') Count: 4
# Trigram: ('Framework', 'Application', 'Developer') Count: 4
# Trigram: ('Engineer', 'Snowflake', 'Data') Count: 4
# Trigram: ('Data', 'Science', 'Lead') Count: 4
# Trigram: ('Scientist', 'Data', 'Scientist/') Count: 4
# Trigram: ('Data', 'Scientist/', 'Senior') Count: 4
# Trigram: ('Scientist/', 'Senior', 'Data') Count: 4
# Trigram: ('Scientist', 'Research', 'Scientist') Count: 4
# Trigram: ('Data', 'Scientist', '||') Count: 4
# Trigram: ('.', 'Data', 'Scientist') Count: 4
# Trigram: ('Scientist', '-', 'Data') Count: 4
# Trigram: ('Learning', 'Data', 'Scientist') Count: 4
# Trigram: ('Machine', 'Learning', 'Senior') Count: 4
# Trigram: ('Scientist', 'Research', 'Scientist/Engineer') Count: 4
# Trigram: ('Computer', 'Vision/Machine', 'Learning/Image') Count: 4
# Trigram: ('Scientist', 'Data', 'Engineer') Count: 4
# Trigram: ('&', 'Data', 'Scientist') Count: 4
# Trigram: ('Analytics', 'Data', 'Scientist') Count: 4
# Trigram: ('Engineer', '(', 'Data') Count: 4
# Trigram: ('Hiring', 'Data', 'Scientist') Count: 4
# Trigram: ('Scientist', '/', 'Senior') Count: 4
# Trigram: ('Senior', 'Manager', '-') Count: 4
# Trigram: ('II', 'Data', 'Scientist') Count: 4
# Trigram: ('Data', 'Scientist/Senior', 'Data') Count: 4
# Trigram: ('Scientist', '-', 'NLP') Count: 4
# Trigram: ('(', 'Power', 'BI') Count: 4
# Trigram: ('Engineer', 'Senior', 'Big') Count: 4
# Trigram: ('Data', 'Engineer', 'IV') Count: 4
# Trigram: (':', 'Data', 'Modeling') Count: 4
# Trigram: ('BI', 'Data', 'Engineer') Count: 4
# Trigram: ('Engineer', 'DATA', 'Engineer') Count: 4
# Trigram: ('Hiring', 'Data', 'Engineer') Count: 4
# Trigram: ('Data', 'Engineering', 'Lead') Count: 4
# Trigram: ('Big', 'Data', 'Engineering') Count: 4
# Trigram: ('Senior', 'Azure', 'Data') Count: 4
# Trigram: ('Data', 'Engineering', 'Manager') Count: 4
# Trigram: ('(', 'Data', 'Engineer') Count: 4
# Trigram: ('Data', 'Engineer', ')') Count: 4
# Trigram: ('Sr', 'Data', 'Engineer') Count: 4
# Trigram: ('Snowflake', 'Data', 'Engineer') Count: 4
# Trigram: (')', 'Azure', 'Data') Count: 4
# Trigram: ('-', 'Azure', 'Data') Count: 4
# Trigram: ('Data', 'Engineer', 'Sr') Count: 4
# Trigram: ('Data', 'Engineer', 'Principal') Count: 4
# Trigram: ('Guidewire', 'Business', 'Analyst') Count: 3
# Trigram: ('Analyst', 'Manager', 'Business') Count: 3
# Trigram: ('Business', 'Analyst', 'Duck') Count: 3
# Trigram: ('Analyst', 'Duck', 'Creek') Count: 3
# Trigram: ('Business', 'Analyst', 'Urgent') Count: 3
# Trigram: (':', 'Business', 'Analyst') Count: 3
# Trigram: ('Analyst', 'Business', 'Analyst/Project') Count: 3
# Trigram: ('Business', 'Analyst', 'Hiring') Count: 3
# Trigram: ('Business', 'Analyst', '||') Count: 3
# Trigram: ('Domain', 'Business', 'Analyst') Count: 3
# Trigram: ('Analyst', '-', 'Manufacturing') Count: 3
# Trigram: ('-', 'Manufacturing', 'Firm') Count: 3
# Trigram: ('Manufacturing', 'Firm', 'Business') Count: 3
# Trigram: ('Firm', 'Business', 'Analyst') Count: 3
# Trigram: ('Coordinator', 'Business', 'Analyst') Count: 3
# Trigram: ('Microsoft', 'Azure', 'Analytics') Count: 3
# Trigram: ('Azure', 'Analytics', 'Services') Count: 3
# Trigram: ('BUSINESS', 'ANALYSTS', 'Business') Count: 3
# Trigram: ('ANALYSTS', 'Business', 'Analyst') Count: 3
# Trigram: ('PLM', 'Business', 'Analyst') Count: 3
# Trigram: ('Project', 'Manager', 'Business') Count: 3
# Trigram: ('Travel', '&', 'Hospitality') Count: 3
# Trigram: ('&', 'Hospitality', ')') Count: 3
# Trigram: ('Hospitality', ')', 'Business') Count: 3
# Trigram: ('TM', 'Business', 'Analyst') Count: 3
# Trigram: ('Project', 'Manager', '/') Count: 3
# Trigram: ('Manager', '/', 'Business') Count: 3
# Trigram: ('Hadoop', 'Developer', '/') Count: 3
# Trigram: ('Developer', 'Hadoop', 'Developers') Count: 3
# Trigram: ('Sr', 'Hadoop', 'Developer') Count: 3
# Trigram: ('Big', 'Data/', 'Hadoop') Count: 3
# Trigram: ('(', 'Spark', '&') Count: 3
# Trigram: ('Spark', '&', 'Scala') Count: 3
# Trigram: ('Java', 'Developer', '-') Count: 3
# Trigram: ('Data', 'Engineer', 'Leading') Count: 3
# Trigram: ('Staff', 'Engineer', '(') Count: 3
# Trigram: ('Engineer', '(', 'Java') Count: 3
# Trigram: ('Developer', 'Senior', 'Big') Count: 3
# Trigram: ('Cloud', 'Application', 'Developer') Count: 3
# Trigram: ('Developer', 'SAP', 'TM') Count: 3
# Trigram: ('SAP', 'TM', 'Transportation') Count: 3
# Trigram: ('TM', 'Transportation', 'Management') Count: 3
# Trigram: ('Transportation', 'Management', 'Application') Count: 3
# Trigram: ('Technical', 'Architecture', 'Application') Count: 3
# Trigram: ('Developer', 'Oracle', 'HCM') Count: 3
# Trigram: ('Oracle', 'HCM', 'Cloud') Count: 3
# Trigram: ('Application', 'Developer', 'PeopleSoft') Count: 3
# Trigram: ('Developer', 'SAP', 'Global') Count: 3
# Trigram: ('Developer', 'SAP', 'UI5') Count: 3
# Trigram: ('SAP', 'UI5', 'Development') Count: 3
# Trigram: ('UI5', 'Development', 'Application') Count: 3
# Trigram: ('Developer', 'SAP', 'SuccessFactors') Count: 3
# Trigram: ('SAP', 'SuccessFactors', 'Employee') Count: 3
# Trigram: ('SuccessFactors', 'Employee', 'Central') Count: 3
# Trigram: ('Employee', 'Central', 'Application') Count: 3
# Trigram: ('Central', 'Application', 'Developer') Count: 3
# Trigram: ('SAP', 'Business', 'Planning') Count: 3
# Trigram: ('Business', 'Planning', 'Consolidation') Count: 3
# Trigram: ('Application', 'Developer', 'React.js') Count: 3
# Trigram: ('Developer', 'React.js', 'Application') Count: 3
# Trigram: ('React.js', 'Application', 'Developer') Count: 3
# Trigram: ('Application', 'Developer', 'Workday') Count: 3
# Trigram: ('Developer', 'Workday', 'Financial') Count: 3
# Trigram: ('Workday', 'Financial', 'Accounting') Count: 3
# Trigram: ('Financial', 'Accounting', 'Core') Count: 3
# Trigram: ('Accounting', 'Core', 'Application') Count: 3
# Trigram: ('Core', 'Application', 'Developer') Count: 3
# Trigram: ('Application', 'Developer', 'Big') Count: 3
# Trigram: ('Data', 'Developer', ')') Count: 3
# Trigram: ('Senior', 'Application', 'Developer') Count: 3
# Trigram: ('Java', 'Developer', '(') Count: 3
# Trigram: ('Warehouse', 'Management', 'Application') Count: 3
# Trigram: ('SAP', 'Ariba', 'Application') Count: 3
# Trigram: ('Ariba', 'Application', 'Developer') Count: 3
# Trigram: ('Application', 'Developer', 'Informatica') Count: 3
# Trigram: ('Developer', 'SAP', 'FSCM') Count: 3
# Trigram: ('SAP', 'FSCM', 'Treasury') Count: 3
# Trigram: ('FSCM', 'Treasury', '&') Count: 3
# Trigram: ('Treasury', '&', 'Risk') Count: 3
# Trigram: ('&', 'Risk', 'Management') Count: 3
# Trigram: ('&', 'Control', 'Discrete') Count: 3
# Trigram: ('Control', 'Discrete', 'Industries') Count: 3
# Trigram: ('Discrete', 'Industries', 'Application') Count: 3
# Trigram: ('Developer', 'SAP', 'Analytics') Count: 3
# Trigram: ('SAP', 'Analytics', 'Cloud') Count: 3
# Trigram: ('Analytics', 'Cloud', 'Development') Count: 3
# Trigram: ('Cloud', 'Development', 'Application') Count: 3
# Trigram: ('ABAP', 'Application', 'Developer') Count: 3
# Trigram: ('Application', 'Developer', 'O9') Count: 3
# Trigram: ('Developer', 'O9', 'Solutions') Count: 3
# Trigram: ('O9', 'Solutions', 'Application') Count: 3
# Trigram: ('Management', 'System', '(') Count: 3
# Trigram: ('Developer', 'SAP', 'Quality') Count: 3
# Trigram: ('SAP', 'Quality', 'Management') Count: 3
# Trigram: ('Quality', 'Management', '(') Count: 3
# Trigram: ('Management', '(', 'QM') Count: 3
# Trigram: ('(', 'QM', ')') Count: 3
# Trigram: ('QM', ')', 'Application') Count: 3
# Trigram: ('Developer', 'Salesforce', 'Development') Count: 3
# Trigram: ('Salesforce', 'Development', 'Application') Count: 3
# Trigram: ('Developer', 'SAP', 'BW/4HANA') Count: 3
# Trigram: ('SAP', 'BW/4HANA', 'Data') Count: 3
# Trigram: ('BW/4HANA', 'Data', 'Modeling') Count: 3
# Trigram: ('Full', 'Stack', 'Developer') Count: 3
# Trigram: ('Data', 'Developer', 'Big') Count: 3
# Trigram: ('Java', 'Hadoop', 'Developer') Count: 3
# Trigram: ('Hadoop', 'Developer', 'Java') Count: 3
# Trigram: ('ABAP', 'HANA', 'Microsoft') Count: 3
# Trigram: ('Application', 'Developer', 'Architecture/Design/Development') Count: 3
# Trigram: ('Developer', 'Architecture/Design/Development', '-') Count: 3
# Trigram: ('Architecture/Design/Development', '-', 'Application') Count: 3
# Trigram: ('-', 'Application', 'Developer') Count: 3
# Trigram: ('Tech', 'Lead', '-') Count: 3
# Trigram: ('Scientist', '-', 'Consultant') Count: 3
# Trigram: ('Consultant', 'Data', 'Scientist') Count: 3
# Trigram: ('Lead', 'Data', 'Science') Count: 3
# Trigram: ('Research', 'Scientist', 'Data') Count: 3
# Trigram: ('Scientist', 'Sr', 'Data') Count: 3
# Trigram: ('Data', 'Scientist', '|') Count: 3
# Trigram: ('Data', 'Scientist', ')') Count: 3
# Trigram: ('Scientist', 'NLP', 'Data') Count: 3
# Trigram: ('Data', 'Scientist', 'Team') Count: 3
# Trigram: ('Scientist', 'Deputy', 'Manager') Count: 3
# Trigram: ('Senior', 'Lead', 'Data') Count: 3
# Trigram: ('Data', 'Scientist', 'Staff') Count: 3
# Trigram: ('Scientist', 'Staff', 'Data') Count: 3
# Trigram: ('Technical', 'Lead', 'Data') Count: 3
# Trigram: ('||', 'Immediate', 'Joiner') Count: 3
# Trigram: ('Data', 'Scientist', 'Machine') Count: 3
# Trigram: ('Scientist', 'Machine', 'Learning') Count: 3
# Trigram: ('Scientist', '-', 'Artificial') Count: 3
# Trigram: ('Vision/Machine', 'Learning/Image', 'Data') Count: 3
# Trigram: ('Learning/Image', 'Data', 'Scientist') Count: 3
# Trigram: ('Engineer', '&', 'Data') Count: 3
# Trigram: ('Scientist', 'ML', 'Engineer') Count: 3
# Trigram: (')', '-', 'Remote') Count: 3
# Trigram: ('Senior/Lead-', 'Data', 'Scientist') Count: 3
# Trigram: ('Specialist', 'Data', 'Scientist') Count: 3
# Trigram: ('Engineer', 'Hiring', 'Data') Count: 3
# Trigram: ('Data', 'Scientist', '1') Count: 3
# Trigram: ('Scientist', '1', 'Data') Count: 3
# Trigram: ('1', 'Data', 'Scientist') Count: 3
# Trigram: ('AI', 'Data', 'Scientist') Count: 3
# Trigram: ('Scientist', 'II', 'Data') Count: 3
# Trigram: ('Principal', 'Data', 'Scientist/Senior') Count: 3
# Trigram: ('Scientist/Senior', 'Data', 'Scientist/Data') Count: 3
# Trigram: ('Data', 'Scientist/Data', 'Scientist') Count: 3
# Trigram: ('Data', 'Science', ',') Count: 3
# Trigram: ('Senior', 'Manager/Operations', 'Research') Count: 3
# Trigram: ('Scientist', 'Senior', 'Manager') Count: 3
# Trigram: ('Engineer', 'Data', 'Science') Count: 3
# Trigram: ('Data', 'scientist', 'Data') Count: 3
# Trigram: ('scientist', 'Data', 'Scientist') Count: 3
# Trigram: ('Data', 'Scientist', 'Hiring') Count: 3
# Trigram: ('Scientist', 'Hiring', 'Data') Count: 3
# Trigram: ('Power', 'BI', ')') Count: 3
# Trigram: ('Science', 'Manager', 'Data') Count: 3
# Trigram: ('(', 'Spark', ',') Count: 3
# Trigram: ('Spark', ',', 'Scala') Count: 3
# Trigram: ('Engineer', '(', 'Power') Count: 3
# Trigram: ('looking', 'Data', 'Engineer') Count: 3
# Trigram: ('DATA', 'Engineer', 'Data') Count: 3
# Trigram: ('Engineer', '-', 'ETL/Python') Count: 3
# Trigram: ('Data', 'Engineer', 'Architect') Count: 3
# Trigram: ('Engineer', 'IV', 'Data') Count: 3
# Trigram: ('IV', 'Data', 'Engineer') Count: 3
# Trigram: ('Data', 'Modeling', 'Data') Count: 3
# Trigram: ('Modeling', 'Data', 'Engineer') Count: 3
# Trigram: ('Power', 'BI', 'Data') Count: 3
# Trigram: ('(', 'Java', ')') Count: 3
# Trigram: ('-', 'Python', 'Data') Count: 3
# Trigram: ('Gcp', 'Data', 'Engineer') Count: 3
# Trigram: ('Engineer', '/', 'Senior') Count: 3
# Trigram: ('Manager', 'Data', 'Engineer') Count: 3
# Trigram: ('Engineer', 'Senior', 'Associate') Count: 3
# Trigram: (',', 'Data', 'Engineering') Count: 3
# Trigram: ('Engineer', '-', 'Spark') Count: 3
# Trigram: ('Data', 'Engineer', 'GCP') Count: 3
# Trigram: ('Engineer', 'GCP', 'Data') Count: 3
# Trigram: ('Data', 'Engineering', 'Senior') Count: 3
# Trigram: ('Engineering', 'Senior', 'Data') Count: 3
# Trigram: ('Engineer', 'Senior', 'Azure') Count: 3
# Trigram: ('Data', 'Engineer', 'II') Count: 3
# Trigram: ('Engineer', ')', 'Data') Count: 3
# Trigram: ('Data', 'Engineer', 'Snowflake') Count: 3
# Trigram: ('Engineer', 'Sr', 'Data') Count: 3
# Trigram: ('Engineer', 'Principal', 'Data') Count: 3
# Trigram: ('Analyst', '(', 'Analytics') Count: 2
# Trigram: ('(', 'Analytics', ')') Count: 2
# Trigram: ('Analyst', 'Job', 'Opportunity') Count: 2
# Trigram: ('Business', 'Analyst', 'Guidewire') Count: 2
# Trigram: ('Analyst', 'Guidewire', 'Business') Count: 2
# Trigram: ('Business', 'Analyst', 'Opening') Count: 2
# Trigram: ('Analyst', 'Opening', 'Business') Count: 2
# Trigram: ('Claims', 'Business', 'Analyst') Count: 2
# Trigram: ('Duck', 'Creek', 'Policy') Count: 2
# Trigram: ('Creek', 'Policy', 'Business') Count: 2
# Trigram: ('Policy', 'Business', 'Analyst') Count: 2
# Trigram: ('Analyst', 'Urgent', 'Hiring') Count: 2
# Trigram: ('Analyst', '-', 'CSAT') Count: 2
# Trigram: ('-', 'CSAT', 'Business') Count: 2
# Trigram: ('CSAT', 'Business', 'Analyst') Count: 2
# Trigram: ('!', 'Business', 'Analyst') Count: 2
# Trigram: ('Analyst', '(', 'BA') Count: 2
# Trigram: ('(', 'BA', ')') Count: 2
# Trigram: ('BA', ')', '-') Count: 2
# Trigram: (')', '-', 'Analytics') Count: 2
# Trigram: ('-', 'Analytics', 'Business') Count: 2
# Trigram: ('Analytics', 'Business', 'Analyst') Count: 2
# Trigram: ('Business', 'Analyst', 'Microsoft') Count: 2
# Trigram: ('Analyst', '-', 'DS') Count: 2
# Trigram: ('-', 'DS', 'Business') Count: 2
# Trigram: ('DS', 'Business', 'Analyst') Count: 2
# Trigram: ('|', 'Business', 'Analyst') Count: 2
# Trigram: ('Ahmedabad', 'Business', 'Analyst') Count: 2
# Trigram: ('-', 'Work', 'Office') Count: 2
# Trigram: ('Office', 'Business', 'Analyst') Count: 2
# Trigram: ('.', 'Business', 'Analyst') Count: 2
# Trigram: ('Business', 'Analyst/Project', 'Manager') Count: 2
# Trigram: ('Business', 'Analyst', 'LoanIQ') Count: 2
# Trigram: ('Analyst', 'LoanIQ', '-') Count: 2
# Trigram: ('LoanIQ', '-', 'Business') Count: 2
# Trigram: ('Business', 'Analyst', 'Consultant') Count: 2
# Trigram: ('Analyst', 'Consultant', 'Business') Count: 2
# Trigram: ('Consultant', 'Business', 'Analyst') Count: 2
# Trigram: ('Business', 'Analyst', 'Training') Count: 2
# Trigram: ('Network', 'Business', 'Analyst') Count: 2
# Trigram: ('Experience', 'Business', 'Analyst') Count: 2
# Trigram: ('Analyst', '-', 'Gurgaon') Count: 2
# Trigram: ('Business', 'Analyst', 'FICO') Count: 2
# Trigram: ('Business', 'Analyst', 'Service') Count: 2
# Trigram: ('Health', 'Business', 'Analyst') Count: 2
# Trigram: ('Subject', 'Matter', 'Expert') Count: 2
# Trigram: ('Business', 'Analyst/Project', 'Coordinator') Count: 2
# Trigram: ('Analyst/Project', 'Coordinator', 'Business') Count: 2
# Trigram: (',', 'Pan', 'India') Count: 2
# Trigram: ('Analyst', 'Job', 'opening') Count: 2
# Trigram: ('Job', 'opening', 'Business') Count: 2
# Trigram: ('opening', 'Business', 'Analyst') Count: 2
# Trigram: ('Analyst', '-', 'IIM') Count: 2
# Trigram: ('-', 'IIM', '/') Count: 2
# Trigram: ('IIM', '/', 'ISB') Count: 2
# Trigram: ('/', 'ISB', '/') Count: 2
# Trigram: ('ISB', '/', 'MDI') Count: 2
# Trigram: ('/', 'MDI', '/') Count: 2
# Trigram: ('MDI', '/', 'FMS') Count: 2
# Trigram: ('Manager', '-', 'Business') Count: 2
# Trigram: ('Services', 'Business', 'Analyst') Count: 2
# Trigram: ('Business', 'Analyst', 'Role') Count: 2
# Trigram: ('Analyst', '(', 'Technical') Count: 2
# Trigram: ('(', 'Technical', ')') Count: 2
# Trigram: ('Technical', ')', 'Business') Count: 2
# Trigram: ('Business', 'Analyst', 'Airline') Count: 2
# Trigram: ('Analyst', 'Airline', 'domain') Count: 2
# Trigram: ('Airline', 'domain', 'Business') Count: 2
# Trigram: ('domain', 'Business', 'Analyst') Count: 2
# Trigram: ('&', 'Business', 'Analyst') Count: 2
# Trigram: ('Analyst', 'Project', 'Manager') Count: 2
# Trigram: ('HANA', 'DW', 'Business') Count: 2
# Trigram: ('Analyst', '/', 'Project') Count: 2
# Trigram: ('/', 'Project', 'Manager') Count: 2
# Trigram: ('-', 'Python', '/') Count: 2
# Trigram: ('Business', 'Analyst', 'TM') Count: 2
# Trigram: ('Analyst', 'TM', 'Business') Count: 2
# Trigram: ('Business', 'Analysts', '.') Count: 2
# Trigram: ('(', 'Work', 'Office') Count: 2
# Trigram: ('Work', 'Office', ')') Count: 2
# Trigram: ('Hadoop', 'Developer', 'Data') Count: 2
# Trigram: ('Engineer', '-', 'Hadoop') Count: 2
# Trigram: ('-', 'Hadoop', 'Developers') Count: 2
# Trigram: ('Developer', '/', 'Admin') Count: 2
# Trigram: ('/', 'Admin', 'Support') Count: 2
# Trigram: ('Support', 'Hadoop', 'Developer') Count: 2
# Trigram: ('Developer', '-', 'Hadoop') Count: 2
# Trigram: ('-', 'Hadoop', '/') Count: 2
# Trigram: ('Spark', '/', 'Hive') Count: 2
# Trigram: ('Developer', '-', 'Big') Count: 2
# Trigram: ('Data/', 'Hadoop', 'Developer/') Count: 2
# Trigram: ('Hadoop', 'Developer/', 'Architect') Count: 2
# Trigram: ('Bigdata', 'Hadoop', 'Developer') Count: 2
# Trigram: ('Engineer', '-', 'Hadoop/Scala') Count: 2
# Trigram: ('-', 'Hadoop/Scala', 'Big') Count: 2
# Trigram: ('Hadoop/Scala', 'Big', 'Data') Count: 2
# Trigram: ('Hiring', 'Big', 'Data') Count: 2
# Trigram: ('Hiring', 'Hadoop', 'Data') Count: 2
# Trigram: ('Hadoop', 'Data', 'Engineer') Count: 2
# Trigram: ('Engineer', 'Leading', 'Banking') Count: 2
# Trigram: ('Leading', 'Banking', 'Client') Count: 2
# Trigram: ('-', 'Hadoop/', 'Java') Count: 2
# Trigram: ('Data', 'Developer', 'SAP') Count: 2
# Trigram: ('&', 'Scala', ')') Count: 2
# Trigram: ('hiring', 'Big', 'Data') Count: 2
# Trigram: ('Data', 'Developer', 'Java') Count: 2
# Trigram: ('Developer', 'Java', 'Big') Count: 2
# Trigram: ('Mobile', 'Application', 'Developer') Count: 2
# Trigram: ('Hadoop', 'Administration', 'Application') Count: 2
# Trigram: ('Microsoft', 'Azure', 'Modern') Count: 2
# Trigram: ('Azure', 'Modern', 'Data') Count: 2
# Trigram: ('Modern', 'Data', 'Platform') Count: 2
# Trigram: ('Data', 'Platform', 'Application') Count: 2
# Trigram: ('Developer', 'Senior', 'Java') Count: 2
# Trigram: ('Engineer', 'Java', 'Full') Count: 2
# Trigram: ('Big', 'data', 'Developer') Count: 2
# Trigram: ('Developer', 'SAP', 'S/4HANA') Count: 2
# Trigram: ('SAP', 'S/4HANA', 'Group') Count: 2
# Trigram: ('S/4HANA', 'Group', 'Reporting') Count: 2
# Trigram: ('Group', 'Reporting', 'Application') Count: 2
# Trigram: ('Reporting', 'Application', 'Developer') Count: 2
# Trigram: ('Developer', 'PeopleSoft', 'PeopleTools') Count: 2
# Trigram: ('PeopleSoft', 'PeopleTools', 'Application') Count: 2
# Trigram: ('PeopleTools', 'Application', 'Developer') Count: 2
# Trigram: ('Planning', 'Consolidation', '(') Count: 2
# Trigram: ('Consolidation', '(', 'SAP') Count: 2
# Trigram: ('(', 'SAP', 'BPC') Count: 2
# Trigram: ('SAP', 'BPC', ')') Count: 2
# Trigram: ('BPC', ')', 'Application') Count: 2
# Trigram: ('ABAP', 'Development', 'Application') Count: 2
# Trigram: ('PAN', 'India', 'Java') Count: 2
# Trigram: ('Application', 'Developer', 'Sr') Count: 2
# Trigram: ('Developer', 'Sr', '.') Count: 2
# Trigram: ('.', 'Application', 'Developer') Count: 2
# Trigram: ('Python', 'Big', 'Data') Count: 2
# Trigram: ('-', 'Data', 'Infrastructure') Count: 2
# Trigram: ('Application', 'Developer', 'Kronos') Count: 2
# Trigram: ('Developer', 'SAP', 'BASIS') Count: 2
# Trigram: ('SAP', 'BASIS', 'Administration') Count: 2
# Trigram: ('BASIS', 'Administration', 'Application') Count: 2
# Trigram: ('Application', 'Developer', 'Urgent') Count: 2
# Trigram: ('Developer', ':', 'EAI') Count: 2
# Trigram: ('Application', 'Developer', 'Pega') Count: 2
# Trigram: ('Developer', 'Pega', 'Platform') Count: 2
# Trigram: ('Pega', 'Platform', 'Application') Count: 2
# Trigram: ('Developer', 'Salesforce', 'Technical') Count: 2
# Trigram: ('Salesforce', 'Technical', 'Architecture') Count: 2
# Trigram: ('Developer', 'Informatica', 'PowerCenter') Count: 2
# Trigram: ('Informatica', 'PowerCenter', 'Application') Count: 2
# Trigram: ('PowerCenter', 'Application', 'Developer') Count: 2
# Trigram: ('Appian', 'Process', 'Automation') Count: 2
# Trigram: ('Risk', 'Management', 'TRM') Count: 2
# Trigram: ('Management', 'TRM', 'Application') Count: 2
# Trigram: ('TRM', 'Application', 'Developer') Count: 2
# Trigram: ('Application', 'Developer', 'Drupal') Count: 2
# Trigram: ('Developer', 'Drupal', 'Application') Count: 2
# Trigram: ('Drupal', 'Application', 'Developer') Count: 2
# Trigram: ('Developer', 'SAP', 'Data') Count: 2
# Trigram: ('Engineer', '-', 'Senior') Count: 2
# Trigram: ('Analyst', 'Big', 'Data') Count: 2
# Trigram: ('Sr.', 'Big', 'Data') Count: 2
# Trigram: ('Developer', 'Lead', 'Java') Count: 2
# Trigram: ('HCM', 'Cloud', 'Time') Count: 2
# Trigram: ('Cloud', 'Time', '&') Count: 2
# Trigram: ('Time', '&', 'Labor') Count: 2
# Trigram: ('&', 'Labor', 'Application') Count: 2
# Trigram: ('Labor', 'Application', 'Developer') Count: 2
# Trigram: ('SAP', 'Vendor', 'Invoice') Count: 2
# Trigram: ('Vendor', 'Invoice', 'Management') Count: 2
# Trigram: ('Invoice', 'Management', 'Application') Count: 2
# Trigram: ('SAP', 'FI', 'Joint') Count: 2
# Trigram: ('FI', 'Joint', 'Venture') Count: 2
# Trigram: ('Joint', 'Venture', 'Accounting') Count: 2
# Trigram: ('Venture', 'Accounting', 'Application') Count: 2
# Trigram: ('Developer', 'SAP', 'BTP') Count: 2
# Trigram: ('Suite', 'Application', 'Developer') Count: 2
# Trigram: ('SAP', 'Ariba', 'Cloud') Count: 2
# Trigram: ('Ariba', 'Cloud', 'Integration') Count: 2
# Trigram: ('Cloud', 'Integration', 'Gateway') Count: 2
# Trigram: ('Integration', 'Gateway', 'CIG') Count: 2
# Trigram: ('Gateway', 'CIG', 'Application') Count: 2
# Trigram: ('CIG', 'Application', 'Developer') Count: 2
# Trigram: ('Salesforce', 'Lightning', 'Web') Count: 2
# Trigram: ('Lightning', 'Web', 'Components') Count: 2
# Trigram: ('Web', 'Components', 'Application') Count: 2
# Trigram: ('Developer', 'SAP', 'Environment') Count: 2
# Trigram: ('SAP', 'Environment', 'Health') Count: 2
# Trigram: ('Environment', 'Health', '&') Count: 2
# Trigram: ('Health', '&', 'Safety') Count: 2
# Trigram: ('&', 'Safety', 'Management') Count: 2
# Trigram: ('Safety', 'Management', 'Application') Count: 2
# Trigram: ('Warehouse', 'Management', 'System') Count: 2
# Trigram: ('System', '(', 'WMS') Count: 2
# Trigram: ('(', 'WMS', ')') Count: 2
# Trigram: ('WMS', ')', 'Application') Count: 2
# Trigram: ('Developer', 'SAP', 'FIORI/Gateway') Count: 2
# Trigram: ('SAP', 'FIORI/Gateway', 'architecture') Count: 2
# Trigram: ('FIORI/Gateway', 'architecture', 'Application') Count: 2
# Trigram: ('architecture', 'Application', 'Developer') Count: 2
# Trigram: ('Developer', 'SAP', 'GRC') Count: 2
# Trigram: ('SAP', 'GRC', 'BusinessObjects') Count: 2
# Trigram: ('GRC', 'BusinessObjects', 'Application') Count: 2
# Trigram: ('BusinessObjects', 'Application', 'Developer') Count: 2
# Trigram: ('Application', 'Developer', 'MuleSoft') Count: 2
# Trigram: ('Developer', 'MuleSoft', 'Anypoint') Count: 2
# Trigram: ('MuleSoft', 'Anypoint', 'Platform') Count: 2
# Trigram: ('Anypoint', 'Platform', 'Application') Count: 2
# Trigram: ('Developer', 'Senior', 'Application') Count: 2
# Trigram: (')', 'Java', 'Developer') Count: 2
# Trigram: ('Java', 'Developer', 'Data') Count: 2
# Trigram: ('Developer', '-', 'AWS') Count: 2
# Trigram: ('-', 'AWS', '/') Count: 2
# Trigram: ('Stack', 'Developer', 'Java') Count: 2
# Trigram: ('Developer', 'Java', 'Hadoop') Count: 2
# Trigram: ('@', 'Tech', 'Mahindra') Count: 2
# Trigram: ('Senior', 'Developer', '-') Count: 2
# Trigram: ('Application', 'Developer', 'Supply') Count: 2
# Trigram: ('Developer', 'Supply', 'Chain') Count: 2
# Trigram: ('Supply', 'Chain', 'Management') Count: 2
# Trigram: ('Chain', 'Management', '(') Count: 2
# Trigram: ('Management', '(', 'SCM') Count: 2
# Trigram: ('(', 'SCM', ')') Count: 2
# Trigram: ('SCM', ')', 'Applications') Count: 2
# Trigram: (')', 'Applications', 'Application') Count: 2
# Trigram: ('Applications', 'Application', 'Developer') Count: 2
# Trigram: (':', 'SAP', 'NextGen') Count: 2
# Trigram: ('SAP', 'NextGen', 'UX') Count: 2
# Trigram: ('NextGen', 'UX', '&') Count: 2
# Trigram: ('UX', '&', 'Mobile') Count: 2
# Trigram: ('&', 'Mobile', 'Microsoft') Count: 2
# Trigram: ('Mobile', 'Microsoft', 'Dynamics') Count: 2
# Trigram: ('HANA', 'Microsoft', 'SQL') Count: 2
# Trigram: ('SAP', 'ABAP', 'Application') Count: 2
# Trigram: ('Analytics', 'Services', 'Application') Count: 2
# Trigram: ('(', 'Immediate', 'joiner') Count: 2
# Trigram: ('Immediate', 'joiner', ')') Count: 2
# Trigram: ('Data', 'Structure', '&') Count: 2
# Trigram: ('Data', 'Management', '(') Count: 2
# Trigram: ('Big', 'Data', 'Applications') Count: 2
# Trigram: ('Master', 'Data', 'Migration') Count: 2
# Trigram: ('Data', 'Migration', 'Application') Count: 2
# Trigram: ('Migration', 'Application', 'Developer') Count: 2
# Trigram: ('-', 'Consultant', '(') Count: 2
# Trigram: ('Consultant', '(', 'Retail') Count: 2
# Trigram: ('(', 'Retail', ')') Count: 2
# Trigram: ('Retail', ')', 'Data') Count: 2
# Trigram: ('Data', 'Scientist', 'Specialist') Count: 2
# Trigram: ('Science', 'Lead', 'Data') Count: 2
# Trigram: ('Data', 'Science', 'Associate') Count: 2
# Trigram: ('Science', 'Associate', 'Director') Count: 2
# Trigram: ('Scientist', '-', 'Python') Count: 2
# Trigram: ('Scientist', '-', 'Engine') Count: 2
# Trigram: ('-', 'Engine', 'Algorithm') Count: 2
# Trigram: ('Engine', 'Algorithm', 'Data') Count: 2
# Trigram: ('Solution', 'Architect', 'Data') Count: 2
# Trigram: ('Architect', 'Data', 'Scientist') Count: 2
# Trigram: ('Scientist', 'Senior', '/') Count: 2
# Trigram: ('Senior', '/', 'Lead') Count: 2
# Trigram: ('/', 'Lead', 'Data') Count: 2
# Trigram: ('DATA', 'SCIENTIST', 'Senior') Count: 2
# Trigram: ('SCIENTIST', 'Senior', 'Data') Count: 2
# Trigram: ('Scientist', ',', 'CAT') Count: 2
# Trigram: (',', 'CAT', 'Proc') Count: 2
# Trigram: ('Scientist', '||', 'Immediate') Count: 2
# Trigram: ('Scientist', '(', 'Clinical') Count: 2
# Trigram: ('(', 'Clinical', 'Consultant/Clinical') Count: 2
# Trigram: ('Clinical', 'Consultant/Clinical', 'Data') Count: 2
# Trigram: ('Consultant/Clinical', 'Data', 'Scientist') Count: 2
# Trigram: ('DATA', 'SCIENTIST', 'Data') Count: 2
# Trigram: ('/', 'Sr', '.') Count: 2
# Trigram: ('ML', 'Engineer', '/') Count: 2
# Trigram: ('Engineer', '/', 'Data') Count: 2
# Trigram: ('Drug', 'Discovery', 'Associate') Count: 2
# Trigram: ('Discovery', 'Associate', 'Data') Count: 2
# Trigram: ('BI', '-', 'Data') Count: 2
# Trigram: ('-', 'Senior', 'Software') Count: 2
# Trigram: ('Scientist', 'Senior', 'Associate') Count: 2
# Trigram: ('Senior', 'Associate', ',') Count: 2
# Trigram: ('Data', 'Scientist', 'AVP') Count: 2
# Trigram: ('AVP', '-', 'Data') Count: 2
# Trigram: ('Scientist', 'Deputy', 'Area') Count: 2
# Trigram: ('Machine', 'Learning', 'Engineer') Count: 2
# Trigram: ('Learning', 'Engineer', 'Data') Count: 2
# Trigram: ('Data', 'Scientist', '&') Count: 2
# Trigram: ('Analyst', 'Data', 'Scientist') Count: 2
# Trigram: ('/', 'Machine', 'Learning') Count: 2
# Trigram: ('Learning', 'Senior', 'Data') Count: 2
# Trigram: ('Senior', 'Engineer', '-') Count: 2
# Trigram: ('Data', 'Scientist', 'Sr.ML') Count: 2
# Trigram: ('Scientist', 'Sr.ML', 'Expert') Count: 2
# Trigram: ('Associate', '-', 'Data') Count: 2
# Trigram: ('Data', 'Engineer', '&') Count: 2
# Trigram: ('Scientist', '-', 'ML') Count: 2
# Trigram: ('ML', 'Data', 'Scientist') Count: 2
# Trigram: ('Scientist', '-', 'Mortgage') Count: 2
# Trigram: ('-', 'Mortgage', 'Finance') Count: 2
# Trigram: ('Team', 'Lead', 'Data') Count: 2
# Trigram: ('Data', 'Scientist', 'DATA') Count: 2
# Trigram: ('Scientist', 'DATA', 'SCIENTIST') Count: 2
# Trigram: ('Specialist', ',', 'Data') Count: 2
# Trigram: ('Scientist', 'Manager', 'Data') Count: 2
# Trigram: ('Data', 'Science', '(') Count: 2
# Trigram: ('-', 'Remote', 'Data') Count: 2
# Trigram: ('Data', 'Scientist', 'Senior/Lead-') Count: 2
# Trigram: ('Scientist', 'Senior/Lead-', 'Data') Count: 2
# Trigram: ('Senior', 'ML', 'Engineer') Count: 2
# Trigram: ('ML', 'Engineer', 'Data') Count: 2
# Trigram: ('Scientist', '-', 'Life') Count: 2
# Trigram: ('-', 'Life', 'Insurance') Count: 2
# Trigram: ('Scientist', ')', 'Data') Count: 2
# Trigram: ('DATA', 'Engineer', 'Scientist') Count: 2
# Trigram: ('Engineer', 'Scientist', 'Data') Count: 2
# Trigram: ('Hiring', 'Senior', 'Data') Count: 2
# Trigram: ('Data', 'Scientist', 'Engineer') Count: 2
# Trigram: ('Scientist', 'Engineer', '-') Count: 2
# ...
# Trigram: ('Solutions', 'Architect', '-') Count: 1
# Trigram: ('Architect', '-', 'Presales') Count: 1
# Trigram: ('-', 'Presales', '(') Count: 1
# Trigram: ('Presales', '(', 'Big') Count: 1
# Trigram: ('(', 'Big', 'Data/') Count: 1
# Trigram: ('Big', 'Data/', 'Data') Count: 1
# Trigram: ('Data/', 'Data', 'Engineering') Count: 1
# Trigram: ('Engineering', ')', 'Graduate') Count: 1
# Trigram: (')', 'Graduate', 'Program') Count: 1
# Trigram: ('Graduate', 'Program', 'Big') Count: 1
# Trigram: ('Program', 'Big', 'Data') Count: 1
# Trigram: ('Data', 'Engineering', 'AWS') Count: 1
# Trigram: ('Engineering', 'AWS', 'Data') Count: 1
# Trigram: ('Engineer', '|', 'SQL') Count: 1
# Trigram: ('|', 'SQL', '|') Count: 1
# Trigram: ('SQL', '|', 'Oracle') Count: 1
# Trigram: ('|', 'Oracle', '|') Count: 1
# Trigram: ('Oracle', '|', 'Data') Count: 1
# Trigram: ('|', 'Data', 'Migration') Count: 1
# Trigram: ('Data', 'Migration', 'Infogain') Count: 1
# Trigram: ('Migration', 'Infogain', 'India') Count: 1
# Trigram: ('India', 'Hiring', 'Data') Count: 1
# Trigram: ('Engineer', '-', 'Google') Count: 1
# Trigram: ('-', 'Google', 'Cloud') Count: 1
# Trigram: ('Google', 'Cloud', 'Platform') Count: 1
# Trigram: ('Cloud', 'Platform', 'Azure') Count: 1
# Trigram: ('Platform', 'Azure', 'Data') Count: 1
# Trigram: ('Engineer', 'Lead', '-') Count: 1
# Trigram: ('Lead', '-', 'Scala') Count: 1
# Trigram: ('-', 'Scala', 'Data') Count: 1
# Trigram: ('Scala', 'Data', 'Engineer') Count: 1
# Trigram: ('Engineer', 'Technical', 'Lead') Count: 1
# Trigram: ('Power', 'BI', 'AWS') Count: 1
# Trigram: ('BI', 'AWS', 'Data') Count: 1
# Trigram: ('Engineer', '(', 'Contract') Count: 1
# Trigram: ('(', 'Contract', ')') Count: 1
# Trigram: ('Contract', ')', 'GCP') Count: 1
# Trigram: ('Engineer', '-', 'Databricks') Count: 1
# Trigram: ('-', 'Databricks', '/') Count: 1
# Trigram: ('Databricks', '/', 'Data') Count: 1
# Trigram: ('/', 'Data', 'Warehousing') Count: 1
# Trigram: ('Data', 'Warehousing', 'Solutions') Count: 1
# Trigram: ('Warehousing', 'Solutions', 'Architect') Count: 1
# Trigram: ('Solutions', 'Architect', '-Data') Count: 1
# Trigram: ('Architect', '-Data', 'Engineering') Count: 1
# Trigram: ('-Data', 'Engineering', 'Lead') Count: 1
# Trigram: ('Engineering', 'Lead', 'Engineer') Count: 1
# Trigram: ('Lead', 'Engineer', '-EDW') Count: 1
# Trigram: ('Engineer', '-EDW', 'Azure') Count: 1
# Trigram: ('-EDW', 'Azure', 'Data') Count: 1
# Trigram: ('Engineer', 'Lead', 'Engineer') Count: 1
# Trigram: ('1', '-', 'Azure') Count: 1
# Trigram: ('Data', 'Engineer', 'Fresher') Count: 1
# Trigram: ('Engineer', 'Fresher', '-') Count: 1
# Trigram: ('Fresher', '-', 'Data') Count: 1
# Trigram: ('Engineer', 'Sr', '.') Count: 1
# Trigram: ('.', 'Data', 'Engineer') Count: 1
# Trigram: ('Data', 'Engineering', 'Sr') Count: 1
# Trigram: ('Engineering', 'Sr', 'Data') Count: 1
# Trigram: ('Sr', 'Data', 'Engineering') Count: 1
# Trigram: ('Engineering', 'Analyst', '-') Count: 1
# Trigram: ('Analyst', '-', 'Optum') Count: 1
# Trigram: ('-', 'Optum', 'Senior') Count: 1
# Trigram: ('Optum', 'Senior', 'Data') Count: 1
# Trigram: ('Data', 'Engineer', '-Oracle') Count: 1
# Trigram: ('Engineer', '-Oracle', 'Data') Count: 1
# Trigram: ('-Oracle', 'Data', 'Integrator') Count: 1
# Trigram: ('Data', 'Integrator', 'Senior') Count: 1
# Trigram: ('Integrator', 'Senior', 'Data') Count: 1
# Trigram: ('Engineer', 'Senior', 'AWS') Count: 1
# Trigram: ('Senior', 'AWS', 'Data') Count: 1
# Trigram: ('Engineer', '-', 'Hadoop/hive/pig') Count: 1
# Trigram: ('-', 'Hadoop/hive/pig', 'Senior') Count: 1
# Trigram: ('Hadoop/hive/pig', 'Senior', 'Associate') Count: 1
# Trigram: ('Associate', ',', 'Java') Count: 1
# Trigram: (',', 'Java', 'Data') Count: 1
# Trigram: ('Java', 'Data', 'Engineer') Count: 1
# Trigram: ('Engineer', ',', 'Enterprise') Count: 1
# Trigram: (',', 'Enterprise', 'Data') Count: 1
# Trigram: ('Enterprise', 'Data', 'Senior') Count: 1
# Trigram: ('Data', 'Senior', 'Data') Count: 1
# Trigram: ('-', 'Data', 'Modeling') Count: 1
# Trigram: ('Data', 'Modeling', 'Senior') Count: 1
# Trigram: ('Power', 'BI', ',') Count: 1
# Trigram: ('BI', ',', 'SQL') Count: 1
# Trigram: ('SQL', ',', 'DAX') Count: 1
# Trigram: (',', 'DAX', ')') Count: 1
# Trigram: ('DAX', ')', '-Remote') Count: 1
# Trigram: (')', '-Remote', 'Senior') Count: 1
# Trigram: ('-Remote', 'Senior', 'Data') Count: 1
# Trigram: ('Engineer', 'Senior', 'Cloud') Count: 1
# Trigram: ('Senior', 'Cloud', 'Architect') Count: 1
# Trigram: ('Cloud', 'Architect', 'Data') Count: 1
# Trigram: ('Architect', 'Data', 'Engineering') Count: 1
# Trigram: ('Engineer', '-', 'Snowflake') Count: 1
# Trigram: ('-', 'Snowflake', 'Senior') Count: 1
# Trigram: ('Snowflake', 'Senior', 'AC') Count: 1
# Trigram: ('Senior', 'AC', '-Data') Count: 1
# Trigram: ('AC', '-Data', 'Engineer') Count: 1
# Trigram: ('-Data', 'Engineer', 'Senior') Count: 1
# Trigram: ('Engineer', 'AWS', 'Redshift') Count: 1
# Trigram: ('AWS', 'Redshift', 'Senior') Count: 1
# Trigram: ('Redshift', 'Senior', 'Python') Count: 1
# Trigram: ('Senior', 'Python', 'Data') Count: 1
# Trigram: ('Engineer', 'Senior', 'Business') Count: 1
# Trigram: ('Senior', 'Business', 'Analyst/Data') Count: 1
# Trigram: ('Business', 'Analyst/Data', 'Analyst/Data') Count: 1
# Trigram: ('Analyst/Data', 'Analyst/Data', 'Engineer') Count: 1
# Trigram: ('Analyst/Data', 'Engineer', 'Sr') Count: 1
# Trigram: ('Engineer', 'Senior', 'Analytics') Count: 1
# Trigram: ('Senior', 'Analytics', 'Engineer') Count: 1
# Trigram: ('Analytics', 'Engineer', '-') Count: 1
# Trigram: ('Engineer', 'Senior', 'GCP') Count: 1
# Trigram: ('Senior', 'GCP', 'Data') Count: 1
# Trigram: ('Engineer', 'Sr', 'Azure') Count: 1
# Trigram: ('Sr', 'Azure', 'Data') Count: 1
# Trigram: ('Engineer', 'Senior', 'R') Count: 1
# Trigram: ('Senior', 'R', '&') Count: 1
# Trigram: ('R', '&', 'Engineer') Count: 1
# Trigram: ('&', 'Engineer', '(') Count: 1
# Trigram: ('Engineer', '(', 'C++') Count: 1
# Trigram: ('(', 'C++', ',') Count: 1
# Trigram: ('C++', ',', 'Data') Count: 1
# Trigram: (',', 'Data', 'Structure') Count: 1
# Trigram: ('Structure', '&', 'Algorithms') Count: 1
# Trigram: ('&', 'Algorithms', ')') Count: 1
# Trigram: ('Algorithms', ')', 'Senior') Count: 1
# Trigram: (')', 'Senior', 'Staff') Count: 1
# Trigram: ('Senior', 'Staff', 'Engineer') Count: 1
# Trigram: ('Big', 'Data', ')') Count: 1
# Trigram: ('Data', ')', 'Data') Count: 1
# Trigram: ('Engineer', '(', 'Jr/Sr/Lead') Count: 1
# Trigram: ('(', 'Jr/Sr/Lead', ')') Count: 1
# Trigram: ('Jr/Sr/Lead', ')', 'Data') Count: 1
# Trigram: ('Engineer', ',', 'Product') Count: 1
# Trigram: (',', 'Product', 'AWS') Count: 1
# Trigram: ('Product', 'AWS', 'Data') Count: 1
# Trigram: ('Engineer', '||', 'bangalore/') Count: 1
# Trigram: ('||', 'bangalore/', 'Hyderabad') Count: 1
# Trigram: ('bangalore/', 'Hyderabad', 'Infogain') Count: 1
# Trigram: ('Hyderabad', 'Infogain', 'India') Count: 1
# Trigram: ('India', 'Hiring', 'GCP') Count: 1
# Trigram: ('Hiring', 'GCP', 'Data') Count: 1
# Trigram: ('Engineer', '@', 'Bangalore') Count: 1
# Trigram: ('@', 'Bangalore', 'Aws') Count: 1
# Trigram: ('Bangalore', 'Aws', 'Data') Count: 1
# Trigram: ('Data', 'Engineer', 'AZURE') Count: 1
# Trigram: ('Engineer', 'AZURE', 'DATA') Count: 1
# Trigram: ('AZURE', 'DATA', 'ENGINEER') Count: 1
# Trigram: ('DATA', 'ENGINEER', 'Azure') Count: 1
# Trigram: ('ENGINEER', 'Azure', 'Data') Count: 1
# Trigram: ('Engineer', '-', 'DataLake/Data') Count: 1
# Trigram: ('-', 'DataLake/Data', 'Factory') Count: 1
# Trigram: ('DataLake/Data', 'Factory', 'Azure') Count: 1
# Trigram: ('Factory', 'Azure', 'Data') Count: 1
# Trigram: ('(', 'ADF', '&') Count: 1
# Trigram: ('ADF', '&', 'Azure') Count: 1
# Trigram: ('&', 'Azure', 'Synapse') Count: 1
# Trigram: ('Azure', 'Synapse', 'Azure') Count: 1
# Trigram: ('Synapse', 'Azure', 'Data') Count: 1
# Trigram: ('(', 'ADF', 'Azure') Count: 1
# Trigram: ('ADF', 'Azure', 'Synapse') Count: 1
# Trigram: ('Azure', 'Synapse', ')') Count: 1
# Trigram: ('Synapse', ')', 'Data') Count: 1
# Trigram: ('Engineer', 'III', 'DATA') Count: 1
# Trigram: ('III', 'DATA', 'ENGINEER') Count: 1
# Trigram: ('DATA', 'ENGINEER', 'III') Count: 1
# Trigram: ('ENGINEER', 'III', 'Data') Count: 1
# Trigram: ('III', 'Data', 'Scientist') Count: 1
# Trigram: ('Scientist', ',', 'Data') Count: 1
# Trigram: ('Engineering', 'Manager', 'Data') Count: 1
# Trigram: ('Data', 'engineer', 'Snowflake') Count: 1
# Trigram: ('engineer', 'Snowflake', 'Kinaxis') Count: 1
# Trigram: ('Snowflake', 'Kinaxis', 'Process') Count: 1
# Trigram: ('Kinaxis', 'Process', 'Data') Count: 1
# Trigram: ('Process', 'Data', 'Engineer') Count: 1
# Trigram: ('Engineer', 'Data', 'Engineer/Visualization') Count: 1
# Trigram: ('Data', 'Engineer/Visualization', 'Expert') Count: 1
# Trigram: ('Engineer/Visualization', 'Expert', 'TS') Count: 1
# Trigram: ('Expert', 'TS', '-') Count: 1
# Trigram: ('TS', '-', 'Azure') Count: 1
# Trigram: ('Engineering', 'Specialist', 'AWS') Count: 1
# Trigram: ('Specialist', 'AWS', 'Data') Count: 1
# Trigram: ('-', 'IoT', 'Data') Count: 1
# Trigram: ('IoT', 'Data', 'Engineer') Count: 1
# Trigram: ('Engineer', '(', 'ETL') Count: 1
# Trigram: ('(', 'ETL', 'Developer') Count: 1
# Trigram: ('ETL', 'Developer', ')') Count: 1
# Trigram: ('Developer', ')', 'Azure') Count: 1
# Trigram: ('Engineer', 'Technical', 'Program') Count: 1
# Trigram: ('Technical', 'Program', 'Manager') Count: 1
# Trigram: ('Program', 'Manager', '(') Count: 1
# Trigram: ('(', 'Data', 'Engineering') Count: 1
# Trigram: ('Engineering', ')', 'Azure') Count: 1
# Trigram: ('Data', 'Engineer', 'Software') Count: 1
# Trigram: ('Engineer', 'Software', 'Engineer') Count: 1
# Trigram: ('Software', 'Engineer', '3') Count: 1
# Trigram: ('Engineer', '3', '-') Count: 1
# Trigram: ('3', '-', 'Data') Count: 1
# Trigram: ('Data', 'Engineering', 'GCP') Count: 1
# Trigram: ('Engineering', 'GCP', 'Data') Count: 1
# Trigram: ('GCP', 'Data', 'Engineer/Tech') Count: 1
# Trigram: ('Data', 'Engineer/Tech', 'Python-') Count: 1
# Trigram: ('Engineer/Tech', 'Python-', 'Data') Count: 1
# Trigram: ('Python-', 'Data', 'Management') Count: 1
# Trigram: ('Management', '(', 'Data') Count: 1
# Trigram: ('Engineering', 'Manager', '|') Count: 1
# Trigram: ('Manager', '|', 'FedEx') Count: 1
# Trigram: ('|', 'FedEx', 'Principal') Count: 1
# Trigram: ('FedEx', 'Principal', 'Software') Count: 1
# Trigram: ('Engineer', 'Principal', 'Software') Count: 1
# Trigram: ('Engineer', 'Immediate', 'Opening') Count: 1
# Trigram: ('Immediate', 'Opening', 'Azure') Count: 1
# Trigram: ('Opening', 'Azure', 'Architect') Count: 1
# Trigram: ('Azure', 'Architect', '(') Count: 1
# Trigram: ('Architect', '(', 'Data') Count: 1
# Trigram: ('Engineer', ')', 'Infogain') Count: 1
# Trigram: (')', 'Infogain', 'India') Count: 1
# Trigram: ('Infogain', 'India', 'Principal') Count: 1
# Trigram: ('India', 'Principal', 'Data') Count: 1
# Trigram: ('Engineer', '(', 'DBT/Snowflake') Count: 1
# Trigram: ('(', 'DBT/Snowflake', ')') Count: 1
# Trigram: ('DBT/Snowflake', ')', 'Data') Count: 1
# Trigram: ('Engineer', '-', 'Medical') Count: 1
# Trigram: ('-', 'Medical', 'Reporting') Count: 1
# Trigram: ('Medical', 'Reporting', 'Analytics') Count: 1
# Trigram: ('Reporting', 'Analytics', '|') Count: 1
# Trigram: ('Analytics', '|', 'Talent500') Count: 1
# Trigram: ('|', 'Talent500', 'Data') Count: 1
# Trigram: ('Talent500', 'Data', 'Engineer') Count: 1
# Trigram: ('Engineer', ',', 'GCP') Count: 1
# Trigram: (',', 'GCP', 'Data') Count: 1
# Trigram: ('Engineer', '@', 'pune') Count: 1
# Trigram: ('@', 'pune', 'location') Count: 1
# Trigram: ('pune', 'location', '/Work') Count: 1
# Trigram: ('location', '/Work', 'Ofice') Count: 1
# Trigram: ('/Work', 'Ofice', 'Data') Count: 1
# Trigram: ('Ofice', 'Data', 'Engineer') Count: 1
# Trigram: ('Engineer', 'AWS', 'DATA') Count: 1
# Trigram: ('AWS', 'DATA', 'ENGINEER') Count: 1
# Trigram: ('DATA', 'ENGINEER', 'Associate') Count: 1
# Trigram: ('ENGINEER', 'Associate', 'Principal') Count: 1
# Trigram: ('-', 'Pricing', 'Data') Count: 1
# Trigram: ('Pricing', 'Data', 'Engineer') Count: 1
# Trigram: ('Data', 'Engineer', 'Assistant') Count: 1
# Trigram: ('Engineer', 'Assistant', 'Manager') Count: 1
# Trigram: ('Assistant', 'Manager', '-') Count: 1
# Trigram: ('Urgent', 'Opening', ':') Count: 1
# Trigram: ('Opening', ':', 'Data') Count: 1
# Trigram: (':', 'Data', 'Engineer') Count: 1
# Trigram: ('Engineer', ':', 'Gurgaon') Count: 1
# Trigram: (':', 'Gurgaon', ':') Count: 1
# Trigram: ('Gurgaon', ':', 'Hybrid') Count: 1
# Trigram: (':', 'Hybrid', 'Data') Count: 1
# Trigram: ('Hybrid', 'Data', 'Engineering') Count: 1
# Trigram: ('Engineering', 'Analyst', 'Azure') Count: 1
# Trigram: ('Analyst', 'Azure', 'Data') Count: 1
# Trigram: ('Data', 'Engineer', 'Aws') Count: 1
# Trigram: ('Engineer', 'Aws', 'Data') Count: 1
# Trigram: ('Engineer', '-', 'Gcp') Count: 1
# Trigram: ('-', 'Gcp', 'Data') Count: 1
# Trigram: ('-', 'Pricing', '(') Count: 1
# Trigram: ('Pricing', '(', '18') Count: 1
# Trigram: ('(', '18', 'months') Count: 1
# Trigram: ('18', 'months', 'FTC') Count: 1
# Trigram: ('months', 'FTC', ')') Count: 1
# Trigram: ('FTC', ')', 'DataStage') Count: 1
# Trigram: (')', 'DataStage', 'Data') Count: 1
# Trigram: ('DataStage', 'Data', 'Engineer') Count: 1
# Trigram: ('Data', 'engineer', 'Associate') Count: 1
# Trigram: ('engineer', 'Associate', 'Manager-Reporting') Count: 1
# Trigram: ('Associate', 'Manager-Reporting', 'Factory') Count: 1
# Trigram: ('Manager-Reporting', 'Factory', '-') Count: 1
# Trigram: ('Factory', '-', 'Data') Count: 1
# Trigram: ('Engineer', 'II', 'Azure') Count: 1
# Trigram: ('II', 'Azure', 'Data') Count: 1
# Trigram: ('Data', 'Engineering', 'Azure') Count: 1
# Trigram: ('Engineering', 'Azure', 'Data') Count: 1
# Trigram: ('Hadoop', 'Developers', 'Data') Count: 1
# Trigram: ('Developers', 'Data', 'Engineer') Count: 1
# Trigram: ('Engineer', '-', 'Remote') Count: 1
# Trigram: ('Remote', 'Data', 'Model') Count: 1
# Trigram: ('Data', 'Model', 'Engineer') Count: 1
# Trigram: ('Model', 'Engineer', 'Associate') Count: 1
# Trigram: ('Engineer', 'Associate', 'Principal') Count: 1
# Trigram: ('Spark', '/', 'Python') Count: 1
# Trigram: ('Engineer', 'Python', 'Backend') Count: 1
# Trigram: ('Python', 'Backend', 'Developer') Count: 1
# Trigram: ('Backend', 'Developer', '/') Count: 1
# Trigram: ('Data', 'Engineer', 'Master') Count: 1
# Trigram: ('Engineer', 'Master', 'Data') Count: 1
# Trigram: ('Master', 'Data', 'Engineer') Count: 1
# Trigram: ('-', 'VBA', 'Data') Count: 1
# Trigram: ('VBA', 'Data', 'Engineer') Count: 1
# Trigram: ('(', 'Data', 'Architect') Count: 1
# Trigram: ('Data', 'Architect', ')') Count: 1
# Trigram: ('Architect', ')', 'Azure') Count: 1
# Trigram: ('Architect', ',', 'Azure') Count: 1
# Trigram: (',', 'Azure', 'Data') Count: 1
# Trigram: ('Principal', 'Data', 'Engineering') Count: 1
# Trigram: ('Data', 'Engineering', 'Architect') Count: 1
# Trigram: ('Engineering', 'Architect', '@') Count: 1
# Trigram: ('Architect', '@', 'Bangalore') Count: 1
# Trigram: ('@', 'Bangalore', 'Data') Count: 1
# Trigram: ('Bangalore', 'Data', 'Engineering') Count: 1
# Trigram: ('Engineering', 'Lead', ',') Count: 1
# Trigram: ('Lead', ',', 'Client') Count: 1
# Trigram: ('Client', 'Ops', 'Lead') Count: 1
# Trigram: ('Ops', 'Lead', 'GCP') Count: 1
# Trigram: ('Lead', 'GCP', 'Data') Count: 1
# Trigram: ('Engineer', '-', 'Python/SQL') Count: 1
# Trigram: ('-', 'Python/SQL', 'Data') Count: 1
# Trigram: ('Python/SQL', 'Data', 'Engineer') Count: 1
# Trigram: ('Engineer', '-', 'ETL/Data') Count: 1
# Trigram: ('-', 'ETL/Data', 'Pipeline') Count: 1
# Trigram: ('ETL/Data', 'Pipeline', 'Data') Count: 1
# Trigram: ('Pipeline', 'Data', 'Engineer') Count: 1
# Trigram: ('-', 'Spark', ',') Count: 1
# Trigram: ('Spark', ',', 'Python') Count: 1
# Trigram: ('Python', ',', 'SQL') Count: 1
# Trigram: ('SQL', ',', 'Kafka') Count: 1
# Trigram: (',', 'Kafka', '&') Count: 1
# Trigram: ('Kafka', '&', 'Spark') Count: 1
# Trigram: ('&', 'Spark', 'Streaming') Count: 1
# Trigram: ('Spark', 'Streaming', 'Hiring') Count: 1
# Trigram: ('Streaming', 'Hiring', 'GCP') Count: 1
# Trigram: ('Hiring', 'GCP', '/') Count: 1
# Trigram: ('GCP', '/', 'Data') Count: 1
# Trigram: ('/', 'Data', 'Engineering') Count: 1
# Trigram: ('Engineering', 'Lead', 'Lead') Count: 1
# Trigram: ('Lead', 'Lead', 'Data') Count: 1
# Trigram: ('Data', 'Engineer', 'Tech') Count: 1
# Trigram: ('Engineer', 'Tech', 'Lead') Count: 1
# Trigram: ('Engineering', 'Lead', '/') Count: 1
# Trigram: ('Lead', '/', 'SME') Count: 1
# Trigram: ('/', 'SME', 'Lead') Count: 1
# Trigram: ('SME', 'Lead', 'Data') Count: 1

# %%
jobs=[]
counts=[]

for bigram, count in sorted_bigrams:
    if count>100 and bigram not in jobs:
        #print('Bigram:', bigram, 'Count:', count)
        jobs.append(str(bigram))
        counts.append(count)
        
# Figure Size
fig, ax = plt.subplots(figsize =(16, 9))
 
# Horizontal Bar Plot
ax.barh(jobs, counts)
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
 
# Add x, y gridlines
#ax.grid(b = True, color ='grey',
#       linestyle ='-.', linewidth = 0.5,
#       alpha = 0.2)
 
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='grey')

#Add Plot Title
ax.set_title('JOB ROLES VS COUNT',
             loc ='left', )
 
# Add Text watermark
fig.text(0.9, 0.15, 'BIG DATA PROJECT', fontsize = 12,
         color ='grey', ha ='right', va ='bottom',
         alpha = 0.7)
 
# Show Plot
plt.show()

# %%
'''1.Data Engineer
2.Data Scientist
3.Business Analyst
4.Hadoop Developer'''
# Out:
# '1.Data Engineer\n2.Data Scientist\n3.Business Analyst\n4.Hadoop Developer'

# %% [markdown]
# ## CHALLENGE 2. HIGHLY VALUED BIGDATA SKILLS IDENTIFICATION

# %%
import nltk
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to C:\Users\Maram
# [nltk_data]     Aashritha\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
all_skills = ' '.join(df['Skills'].values)

# %%
all_skills
# Out:
# 'excel, Business Analytics, Problem Solving, Data Analysis, Python, Power Bi, Advanced Excel, Tableau Training, Application support, Business Analyst, Instructional design, Project management, Design development, Powerpoint, Sharepoint Automation, digital content, Business Analyst, Technology consulting, Technical design, Analytical, Manager Technology, SDK Telecom, Hospitality, Business Analyst, Agile scrum, Functional testing, Manager Technology, Agile methodology, Recruitment Business Analytics, SQL, Business Analysis, Power Bi, SQL Queries, Tableau, Dashboards, Salesforce CRM Business Analytics, analytical, Requirement Gathering, business analysis, Statistics, Requirements, Analysis, Analytics Policy Administration, Casualty, Property, Business analysis, Administration, Guidewire Guidewire, Forms, Integration, Billing Center, Policy Center, Rating, business analysis, Forming business analysis, vendor management, Life Insurance Analyst, INGENIUM, Business Analyst, Business Analytics, AIII, invoice processing Product training, Automation, Usage, Business Analyst, Machine learning, Agile, power bi, QlikView PowerBI, Qlikview, Tableau, Datastudio, data analytics, Business Analytics, BI, business analysis Manager Quality Assurance, Business Analyst, Compliance, Project management, Artificial Intelligence, Workflow, Data quality, Operations b2b, Business Analytics, Documentation, communication skills, Analytics, Business analysis Business Analysis, Business Analyst, Business Analytics, financial modelling, Market Analytics, competitive analysis, Marketing analytics, Marketing Claims, Duck Creek, Business Analysis, Analysis Property And Casualty Insurance, Policy Center, Duck Creek, Business Analysis, Pc Insurance, PC, Property, Casualty Web technologies, Business Analyst, JSP, Software Professional, Programming, ASP.Net, Business analysis, Software Computer science, Telecom, Hospitality, Business Analyst, Agile scrum, Functional testing, Manager Technology, Agile methodology Business Analysis, Business Analytics, business continuity management, Data Analysis, MIS Reporting, reporting, Analysis, Analytics IT services, remediation, Data management, ISO, Process improvement, Configuration management, Active directory, Javascript Front office, Business analysis, Project management, Fixed income, Back office, Manager Quality Control, Investment banking, Risk management Production support, Business Analyst, UML, Analytical, IFS, Agile, Capital market, Asset management Brd, User Stories, FRD, Gap Analysis, Business Analytics, Use Cases, Requirement Gathering, Flow Diagrams analytical, business requirements, presentation skills, business analysis, communication skills, Analysis, Analytics, Presentation Business Analysis, User Acceptance Testing, Wealth Management, Business Analyst, Investment Management, Equity Market, Analysis, User acceptance excel, Word, Data Analysis, business analysis, Powerpoint, Analysis, Data advanced excel, secondary research, data analysis, dashboards, Analysis, Data, Excel, Research Basic, Usage, Excel, Business Analyst, Database management, Senior Analyst, Analytical, IT support Business Documentation, Requirement Gathering, Market Research, Stakeholder Management, Technical Documentation, Gap Analysis, Use Cases, FRS Business Analytics, Analytical Skills, Problem Solving, Analytical, Business analysis, Analytics, Analytical Skill Business Analytics, Analytics, Business analysis Business Excellence, IT Services, Data Reporting, Business Analysis, Competitor Analysis, Strategic Thinking, Business Analytics, Project Management Business Analysis, insurance, Business Analytics, Analysis, Analytics data analysis, Business Analytics, CSAT, analytics, Customer Satisfaction, Stakeholder Management, Business analysis, Data Computer science, ERP, CMS, Agile, Workflow, Scrum, Adobe, JIRA Computer science, ERP, Business analysis, CMS, Agile, Workflow, Scrum, Adobe Service level, Business Analyst, Business analysis, XML, ...

# %%
skills_list = all_skills.split(",")

# %%
len(skills_list)
# Out:
# 25419

# %%
k=set(skills_list)

# %%
len(k)
# Out:
# 7133

# %%
import nltk
from nltk.corpus import stopwords  #stopwords
from nltk.stem import WordNetLemmatizer  
from sklearn.feature_extraction.text import TfidfVectorizer
stop_words=nltk.corpus.stopwords.words('english')

# %%
def clean_text(headline):
    le=WordNetLemmatizer()
    word_tokens=word_tokenize(headline)
    tokens=[le.lemmatize(w) for w in word_tokens if w not in stop_words and len(w)>3]
    cleaned_text=" ".join(tokens)
    return cleaned_text
df['JD']=df['Skills'].apply(clean_text)

# %%
vect =TfidfVectorizer(stop_words=stop_words,max_features=1000)
vect_text=vect.fit_transform(df['JD'])

# %%
from sklearn.decomposition import LatentDirichletAllocation
lda_model=LatentDirichletAllocation(n_components=4,learning_method='online',random_state=42,max_iter=1) 
lda_top=lda_model.fit_transform(vect_text)

# %%
print("Document 0: ")
for i,topic in enumerate(lda_top[0]):
    print("Topic ",i,": ",topic*100,"%")
# Out:
# Document 0:
# Topic  0 :  6.543285811987838 %
# Topic  1 :  6.686214644214148 %
# Topic  2 :  80.37112101219776 %
# Topic  3 :  6.399378531600251 %

# %%
vocab = vect.get_feature_names_out()
for i, comp in enumerate(lda_model.components_):
    vocab_comp = zip(vocab, comp)
    sorted_words = sorted(vocab_comp, key= lambda x:x[1], reverse=True)[:10]
    print("Topic "+str(i)+": ",end='\n')
    for t in sorted_words:
        print(t[0],end="\n")
# Out:
# Topic 0:
# data
# engineering
# azure
# python
# spark
# cloud
# scala
# hadoop
# pyspark
# warehousing
# Topic 1:
# data
# analytics
# learning
# machine
# mining
# analysis
# business
# management
# modeling
# analytical
# Topic 2:
# performance
# tuning
# python
# scientist
# analysis
# perl
# pandas
# matlab
# business
# data
# Topic 3:
# data
# management
# computer
# agile
# science
# technology
# quality
# design
# development
# application

# %% [markdown]
# ## CHALLENGE 3. COMPETENCE LEVEL CHARECTERIZATION

# %%
import numpy as np
import pandas as pd
import re , nltk ,gensim,spacy
from sklearn.decomposition import LatentDirichletAllocation, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from pprint import pprint
import pyLDAvis
import pyLDAvis.gensim_models
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.head()
# Out:
#    Unnamed: 0                                     Job_Role          Company  \
# 0           0  Merilytics - Business Analyst ( Analytics )       Merilytics
# 1           1                       Stars Business Analyst             Ford
# 2           2                             Business Analyst       Isoftstone
# 3           3                             Business Analyst  NCR Corporation
# 4           4                             Business Analyst          Regalix
#
#                                             Location Job Experience  \
# 0                             Hyderabad/Secunderabad            0-2
# 1                                            Chennai            0-5
# 2  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...            0-5
# 3                             Hyderabad/Secunderabad           5-10
# 4                                             Remote            1-4
#
#                                               Skills  \
# 0  excel, Business Analytics, Problem Solving, Da...
# 1  Training, Application support, Business Analys...
# 2  Automation, digital content, Business Analyst,...
# 3  Telecom, Hospitality, Business Analyst, Agile ...
# 4  Business Analytics, SQL, Business Analysis, Po...
#
#                                      Job_Description  \
# 0  (v) Cab reimbursement for women employees beyo...
# 1  Coordinate and / or deliver training to custom...
# 2  A Bachelors or Masters in Computer Science or ...
# 3  Along with the BA role, candidate should be ab...
# 4  Location: Bangalore/ Hyderabad ( Work From Hom...
#
#                                                   JD
# 0  excel Business Analytics Problem Solving Data ...
# 1  Training Application support Business Analyst ...
# 2  Automation digital content Business Analyst Te...
# 3  Telecom Hospitality Business Analyst Agile scr...
# 4  Business Analytics Business Analysis Power Que...

# %%
df['Skills'].values
# Out:
# array(['excel, Business Analytics, Problem Solving, Data Analysis, Python, Power Bi, Advanced Excel, Tableau',
#        'Training, Application support, Business Analyst, Instructional design, Project management, Design development, Powerpoint, Sharepoint',
#        'Automation, digital content, Business Analyst, Technology consulting, Technical design, Analytical, Manager Technology, SDK',
#        ...,
#        'Unix, GIT, Linux, Architecture, GCP, Machine learning, Data processing, Continuous improvement',
#        'Assurance, Data management, Analytical, Agile, Healthcare, PLSQL, Data quality, Informatica',
#        'Computer science, Business transformation, RDBMS, Agile development, Schema, Cloud, Corporate finance, Asset management'],
#       dtype=object)

# %%
# Convert to list
data = df.Skills.values.tolist()

pprint(data[:2])
# Out:
# ['excel, Business Analytics, Problem Solving, Data Analysis, Python, Power Bi, '
#  'Advanced Excel, Tableau',
#  'Training, Application support, Business Analyst, Instructional design, '
#  'Project management, Design development, Powerpoint, Sharepoint']

# %% [markdown]
# ## Tokenize
#
# Now we want to tokenize each sentence into a list of words, removing punctuations and unnecessary characters altogether.
#
# Tokenization is the act of breaking up a sequence of strings into pieces such as words, keywords, phrases, symbols and other elements called tokens. Tokens can be individual words, phrases or even whole sentences. In the process of tokenization, some characters like punctuation marks are discarded.
#
# We used Gensim here, use (deacc=True) to remove the punctuations.

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations
data_words = list(sent_to_words(data))
print(data_words[:1])
# Out:
# [['excel', 'business', 'analytics', 'problem', 'solving', 'data', 'analysis', 'python', 'power', 'bi', 'advanced', 'excel', 'tableau']]

# %% [markdown]
# ## Stemming
#
# Stemming is the process of reducing a word to its word stem that affixes to suffixes and prefixes or to the roots of words known as a lemma.
#
# The advantage of this is, we get to reduce the total number of unique words in the dictionary. As a result, the number of columns in the document-word matrix (created by CountVectorizer in the next step) will be denser with lesser columns. You can expect better topics to be generated in the end.

# %%
def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']): #'NOUN', 'ADJ', 'VERB', 'ADV'
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append(" ".join([token.lemma_ if token.lemma_ not in ['-PRON-'] else '' for token in doc if token.pos_ in allowed_postags]))
    return texts_out

# %%
# Initialize spacy ‘en’ model, keeping only tagger component (for efficiency)
# Run in terminal: python -m spacy download en
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])
# Do lemmatization keeping only Noun, Adj, Verb, Adverb
data_lemmatized = lemmatization(data_words, allowed_postags=['NOUN', 'VERB']) #select noun and verb
print(data_lemmatized[:2])
# Out:
# ['excel business analytic problem solve datum analysis advance tableau', 'training application support business analyst design project management design development powerpoint sharepoint']

# %% [markdown]
# ## Create the Document-Word matrix
# The LDA topic model algorithm requires a document word matrix as the main input.
#
# You can create one using CountVectorizer. In the below code, I have configured the CountVectorizer to consider words that has occurred at least 10 times (min_df), remove built-in english stopwords, convert all words to lowercase, and a word can contain numbers and alphabets of at least length 3 in order to be qualified as a word.

# %%
vectorizer = CountVectorizer(analyzer='word',min_df=30,stop_words='english',lowercase=True,token_pattern='[a-zA-Z0-9]{3,}')
data_vectorized = vectorizer.fit_transform(data_lemmatized)

# %% [markdown]
# ## Build LDA model with sklearn
#
# Everything is ready to build a Latent Dirichlet Allocation (LDA) model. Let’s initialise one and call fit_transform() to build the LDA model.
#
# We have set the n_topics as 4 based on prior knowledge about the dataset. Later we will find the optimal number using grid search.

# %%
# Build LDA Model
lda_model = LatentDirichletAllocation(n_components=4,               # Number of topics
                                      max_iter=10,               
# Max learning iterations
                                      learning_method='online',   
                                      random_state=100,          
# Random state
                                      batch_size=128,            
# n docs in each learning iter
                                      evaluate_every = -1,       
# compute perplexity every n iters, default: Don't
                                     )
lda_output = lda_model.fit_transform(data_vectorized)
#print(lda_model)  # Model attributes

# %% [markdown]
# ## Diagnose model performance with perplexity and log-likelihood
# A model with higher log-likelihood and lower perplexity (exp(-1. * log-likelihood per word)) is considered to be good.

# %%
# Log Likelyhood: Higher the better
print("Log Likelihood: ", lda_model.score(data_vectorized))
# Perplexity: Lower the better. Perplexity = exp(-1. * log-likelihood per word)
print("Perplexity: ", lda_model.perplexity(data_vectorized))
# See model parameters
pprint(lda_model.get_params())
# Out:
# Log Likelihood:  -115196.45279004614
# Perplexity:  78.00210837827872
# {'batch_size': 128,
#  'doc_topic_prior': None,
#  'evaluate_every': -1,
#  'learning_decay': 0.7,
#  'learning_method': 'online',
#  'learning_offset': 10.0,
#  'max_doc_update_iter': 100,
#  'max_iter': 10,
#  'mean_change_tol': 0.001,
#  'n_components': 4,
#  'n_jobs': None,
#  'perp_tol': 0.1,
#  'random_state': 100,
#  'topic_word_prior': None,
#  'total_samples': 1000000.0,
#  'verbose': 0}

# %% [markdown]
# ## Use GridSearch to determine the best LDA model.
#
# The most important tuning parameter for LDA models is n_components (number of topics).
#
# In addition,we are going to search learning_decay (which controls the learning rate) as well.
#
# Besides these, other possible search params could be learning_offset (downweigh early iterations. Should be > 1) and max_iter. These could be worth experimenting if you have enough computing resources. Be warned, the grid search constructs multiple LDA models for all possible combinations of param values in the param_grid dict. So, this process can consume a lot of time and resources.

# %%
# Define Search Param
search_params = {'n_components': [3,4,5,6], 'learning_decay': [.5, .7, .9]}
# Init the Model
lda = LatentDirichletAllocation(max_iter=5, learning_method='online', learning_offset=50.,random_state=0)
# Init Grid Search Class
model = GridSearchCV(lda, param_grid=search_params)
# Do the Grid Search
model.fit(data_vectorized)
GridSearchCV(cv=None, error_score='raise',
       estimator=LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
             evaluate_every=-1, learning_decay=0.7, learning_method=None,
             learning_offset=10.0, max_doc_update_iter=100, max_iter=10,
             mean_change_tol=0.001, n_components=10, n_jobs=1, perp_tol=0.1, random_state=None,
             topic_word_prior=None, total_samples=1000000.0, verbose=0), n_jobs=1,
       param_grid={'n_topics': [3,4,5,6], 'learning_decay': [0.5, 0.7, 0.9]},
       pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
       scoring=None, verbose=0)
# Out:
# GridSearchCV(error_score='raise',
#              estimator=LatentDirichletAllocation(learning_method=None,
#                                                  n_jobs=1),
#              n_jobs=1,
#              param_grid={'learning_decay': [0.5, 0.7, 0.9],
#                          'n_topics': [3, 4, 5, 6]},
#              return_train_score='warn')

# %%
# Best Model
lda_model = model.best_estimator_
# Model Parameters
print("Best Model's Params: ", model.best_params_)
# Log Likelihood Score
print("Best Log Likelihood Score: ", model.best_score_)
# Perplexity
print("Model Perplexity: ", lda_model.perplexity(data_vectorized))
# Out:
# Best Model's Params:  {'learning_decay': 0.9, 'n_components': 3}
# Best Log Likelihood Score:  -24622.648060445394
# Model Perplexity:  80.44735959447107

# %% [markdown]
# ## Dominant topic
#
# To classify a document as belonging to a particular topic, a logical approach is to see which topic has the highest contribution to that document and assign it. In the table below, we have greened out all major topics in a document and assigned the most dominant topic in its own column.

# %%
# Create Document — Topic Matrix
lda_output = lda_model.transform(data_vectorized)
# column names
topicnames = ['Topic' + str(i) for i in range(lda_model.n_components)]
# index names
docnames = ['Doc' + str(i) for i in range(len(data))]
# Make the pandas dataframe
df_document_topic = pd.DataFrame(np.round(lda_output, 2), columns=topicnames, index=docnames)
# Get dominant topic for each document
dominant_topic = np.argmax(df_document_topic.values, axis=1)
df_document_topic['dominant_topic'] = dominant_topic
# Styling
def color_green(val):
    color = 'green' if val > .1 else 'black'
    return 'color: {col}'.format(col=color)
def make_bold(val):
    weight = 700 if val > .1 else 400
    return 'font-weight: {weight}'.format(weight=weight)
# Apply Style
df_document_topics = df_document_topic.head(15).style.applymap(color_green).applymap(make_bold)
df_document_topics
# Out:
# <style type="text/css">
# #T_9a387_row0_col0, #T_9a387_row0_col2, #T_9a387_row1_col0, #T_9a387_row1_col1, #T_9a387_row2_col0, #T_9a387_row2_col1, #T_9a387_row3_col0, #T_9a387_row4_col0, #T_9a387_row4_col2, #T_9a387_row5_col0, #T_9a387_row6_col0, #T_9a387_row7_col0, #T_9a387_row7_col1, #T_9a387_row8_col0, #T_9a387_row8_col1, #T_9a387_row9_col0, #T_9a387_row9_col1, #T_9a387_row10_col0, #T_9a387_row11_col0, #T_9a387_row11_col2, #T_9a387_row12_col0, #T_9a387_row13_col0, #T_9a387_row14_col0 {
#   color: green;
#   font-weight: 700;
# }
# #T_9a387_row0_col1, #T_9a387_row0_col3, #T_9a387_row1_col2, #T_9a387_row1_col3, #T_9a387_row2_col2, #T_9a387_row2_col3, #T_9a387_row3_col1, #T_9a387_row3_col2, #T_9a387_row3_col3, #T_9a387_row4_col1, #T_9a387_row4_col3, #T_9a387_row5_col1, #T_9a387_row5_col2, #T_9a387_row5_col3, #T_9a387_row6_col1, #T_9a387_row6_col2, #T_9a387_row6_col3, #T_9a387_row7_col2, #T_9a387_row7_col3, #T_9a387_row8_col2, #T_9a387_row8_col3, #T_9a387_row9_col2, #T_9a387_row9_col3, #T_9a387_row10_col1, #T_9a387_row10_col2, #T_9a387_row10_col3, #T_9a387_row11_col1, #T_9a387_row11_col3, #T_9a387_row12_col1, #T_9a387_row12_col2, #T_9a387_row12_col3, #T_9a387_row13_col1, #T_9a387_row13_col2, #T_9a387_row13_col3, #T_9a387_row14_col1, #T_9a387_row14_col2, #T_9a387_row14_col3 {
#   color: black;
#   font-weight: 400;
# }
# </style>
# <table id="T_9a387">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a387_level0_col0" class="col_heading level0 col0" >Topic0</th>
#       <th id="T_9a387_level0_col1" class="col_heading level0 col1" >Topic1</th>
#       <th id="T_9a387_level0_col2" class="col_heading level0 col2" >Topic2</th>
#       <th id="T_9a387_level0_col3" class="col_heading level0 col3" >dominant_topic</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a387_level0_row0" class="row_heading level0 row0" >Doc0</th>
#       <td id="T_9a387_row0_col0" class="data row0 col0" >0.660000</td>
#       <td id="T_9a387_row0_col1" class="data row0 col1" >0.060000</td>
#       <td id="T_9a387_row0_col2" class="data row0 col2" >0.280000</td>
#       <td id="T_9a387_row0_col3" class="data row0 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9a387_level0_row1" class="row_heading level0 row1" >Doc1</th>
#       <td id="T_9a387_row1_col0" class="data row1 col0" >0.630000</td>
#       <td id="T_9a387_row1_col1" class="data row1 col1" >0.340000</td>
#       <td id="T_9a387_row1_col2" class="data row1 col2" >0.030000</td>
#       <td id="T_9a387_row1_col3" class="data row1 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9a387_level0_row2" class="row_heading level0 row2" >Doc2</th>
#       <td id="T_9a387_row2_col0" class="data row2 col0" >0.780000</td>
#       <td id="T_9a387_row2_col1" class="data row2 col1" >0.180000</td>
#       <td id="T_9a387_row2_col2" class="data row2 col2" >0.040000</td>
#       <td id="T_9a387_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9a387_level0_row3" class="row_heading level0 row3" >Doc3</th>
#       <td id="T_9a387_row3_col0" class="data row3 col0" >0.900000</td>
#       <td id="T_9a387_row3_col1" class="data row3 col1" >0.050000</td>
#       <td id="T_9a387_row3_col2" class="data row3 col2" >0.050000</td>
#       <td id="T_9a387_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9a387_level0_row4" class="row_heading level0 row4" >Doc4</th>
#       <td id="T_9a387_row4_col0" class="data row4 col0" >0.530000</td>
#       <td id="T_9a387_row4_col1" class="data row4 col1" >0.040000</td>
#       <td id="T_9a387_row4_col2" class="data row4 col2" >0.420000</td>
#       <td id="T_9a387_row4_col3" class="data row4 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9a387_level0_row5" class="row_heading level0 row5" >Doc5</th>
#       <td id="T_9a387_row5_col0" class="data row5 col0" >0.930000</td>
#       <td id="T_9a387_row5_col1" class="data row5 col1" >0.040000</td>
#       <td id="T_9a387_row5_col2" class="data row5 col2" >0.030000</td>
#       <td id="T_9a387_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9a387_level0_row6" class="row_heading level0 row6" >Doc6</th>
#       <td id="T_9a387_row6_col0" class="data row6 col0" >0.860000</td>
#       <td id="T_9a387_row6_col1" class="data row6 col1" >0.070000</td>
#       <td id="T_9a387_row6_col2" class="data row6 col2" >0.070000</td>
#       <td id="T_9a387_row6_col3" class="data row6 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9a387_level0_row7" class="row_heading level0 row7" >Doc7</th>
#       <td id="T_9a387_row7_col0" class="data row7 col0" >0.740000</td>
#       <td id="T_9a387_row7_col1" class="data row7 col1" >0.170000</td>
#       <td id="T_9a387_row7_col2" class="data row7 col2" >0.090000</td>
#       <td id="T_9a387_row7_col3" class="data row7 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9a387_level0_row8" class="row_heading level0 row8" >Doc8</th>
#       <td id="T_9a387_row8_col0" class="data row8 col0" >0.860000</td>
#       <td id="T_9a387_row8_col1" class="data row8 col1" >0.110000</td>
#       <td id="T_9a387_row8_col2" class="data row8 col2" >0.030000</td>
#       <td id="T_9a387_row8_col3" class="data row8 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9a387_level0_row9" class="row_heading level0 row9" >Doc9</th>
#       <td id="T_9a387_row9_col0" class="data row9 col0" >0.500000</td>
#       <td id="T_9a387_row9_col1" class="data row9 col1" >0.460000</td>
#       <td id="T_9a387_row9_col2" class="data row9 col2" >0.040000</td>
#       <td id="T_9a387_row9_col3" class="data row9 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9a387_level0_row10" class="row_heading level0 row10" >Doc10</th>
#       <td id="T_9a387_row10_col0" class="data row10 col0" >0.880000</td>
#       <td id="T_9a387_row10_col1" class="data row10 col1" >0.060000</td>
#       <td id="T_9a387_row10_col2" class="data row10 col2" >0.060000</td>
#       <td id="T_9a387_row10_col3" class="data row10 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9a387_level0_row11" class="row_heading level0 row11" >Doc11</th>
#       <td id="T_9a387_row11_col0" class="data row11 col0" >0.680000</td>
#       <td id="T_9a387_row11_col1" class="data row11 col1" >0.030000</td>
#       <td id="T_9a387_row11_col2" class="data row11 col2" >0.290000</td>
#       <td id="T_9a387_row11_col3" class="data row11 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9a387_level0_row12" class="row_heading level0 row12" >Doc12</th>
#       <td id="T_9a387_row12_col0" class="data row12 col0" >0.920000</td>
#       <td id="T_9a387_row12_col1" class="data row12 col1" >0.040000</td>
#       <td id="T_9a387_row12_col2" class="data row12 col2" >0.040000</td>
#       <td id="T_9a387_row12_col3" class="data row12 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9a387_level0_row13" class="row_heading level0 row13" >Doc13</th>
#       <td id="T_9a387_row13_col0" class="data row13 col0" >0.950000</td>
#       <td id="T_9a387_row13_col1" class="data row13 col1" >0.030000</td>
#       <td id="T_9a387_row13_col2" class="data row13 col2" >0.030000</td>
#       <td id="T_9a387_row13_col3" class="data row13 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9a387_level0_row14" class="row_heading level0 row14" >Doc14</th>
#       <td id="T_9a387_row14_col0" class="data row14 col0" >0.830000</td>
#       <td id="T_9a387_row14_col1" class="data row14 col1" >0.080000</td>
#       <td id="T_9a387_row14_col2" class="data row14 col2" >0.090000</td>
#       <td id="T_9a387_row14_col3" class="data row14 col3" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Topic-Keyword Matrix
df_topic_keywords = pd.DataFrame(lda_model.components_)
# Assign Column and Index
df_topic_keywords.columns = vectorizer.get_feature_names_out()
df_topic_keywords.index = topicnames
# View
df_topic_keywords.head()
# Out:
#         acceptance    account  accounting  administration      agile  \
# Topic0   36.863563   1.055309    1.966341       20.092682  18.675838
# Topic1    0.756972   5.374955    1.654470       16.265517  13.434704
# Topic2    0.433625  38.142752   55.195511        9.035212   1.068411
#
#         algorithm    analysis     analyst    analytic     apache  ...  \
# Topic0   0.549907  818.064896  473.656948  177.781503   0.458996  ...
# Topic1  25.062948   16.116489    1.118437   39.269805   9.192529  ...
# Topic2   5.715741  222.612189    2.008505  311.958695  29.786554  ...
#
#               use       user      visio     vision  visualization  warehouse  \
# Topic0  27.042525  56.185916  25.422740   0.414955       0.747803   0.633131
# Topic1   0.551467   0.777779   0.575735  42.681775       0.811882   6.084953
# Topic2   0.453968   0.547496   0.757747   1.706130      99.967988  49.037528
#
#         warehousing        web   workflow        xml
# Topic0     0.479973  27.834764  32.744508   4.275311
# Topic1     0.936587  78.292519  15.131060  15.951043
# Topic2   109.499542   1.091423  13.451726  14.092944
#
# [3 rows x 179 columns]

# %%
topic0=df_topic_keywords.iloc[0].sort_values()
topic0=topic0.iloc[-10:]

# %%
list(topic0.index)
# Out:
# ['development',
#  'manager',
#  'analytic',
#  'skill',
#  'project',
#  'process',
#  'analyst',
#  'management',
#  'analysis',
#  'business']

# %%
scores=[]
for i in range(len(topic0)):
    scores.append(topic0[:][i])
    skills=list(topic0.index)
    
# Figure Size
fig, ax = plt.subplots(figsize =(16, 9))
 
# Horizontal Bar Plot
ax.barh(skills, scores)
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
 
# Add x, y gridlines
#ax.grid(b = True, color ='grey',
#       linestyle ='-.', linewidth = 0.5,
#       alpha = 0.2)
 
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='grey')

#Add Plot Title
ax.set_title('JOB skills VS score',
             loc ='left', )
 
# Add Text watermark
fig.text(0.9, 0.15, 'BIG DATA PROJECT', fontsize = 12,
         color ='grey', ha ='right', va ='bottom',
         alpha = 0.7)
 
# Show Plot
plt.show()

# %%
# Show top n keywords for each topic
def show_topics(vectorizer=vectorizer, lda_model=lda_model, n_words=20):
    keywords = np.array(vectorizer.get_feature_names_out())
    topic_keywords = []
    for topic_weights in lda_model.components_:
        top_keyword_locs = (-topic_weights).argsort()[:n_words]
        topic_keywords.append(keywords.take(top_keyword_locs))
    return topic_keywords
topic_keywords = show_topics(vectorizer=vectorizer, lda_model=lda_model, n_words=15)
# Topic - Keywords Dataframe
df_topic_keywords = pd.DataFrame(topic_keywords)
df_topic_keywords.columns = ['Word '+str(i) for i in range(df_topic_keywords.shape[1])]
df_topic_keywords.index = ['Topic '+str(i) for i in range(df_topic_keywords.shape[0])]
df_topic_keywords
# Out:
#            Word 0    Word 1       Word 2       Word 3   Word 4       Word 5  \
# Topic 0  business  analysis   management      analyst  process      project
# Topic 1     learn   machine  application  development    datum  engineering
# Topic 2     datum  analytic      science     analysis     data       mining
#
#              Word 6    Word 7      Word 8        Word 9      Word 10  \
# Topic 0       skill  analytic     manager   development  requirement
# Topic 1  processing    design    computer  architecture      science
# Topic 2       model     azure  management           sql  engineering
#
#             Word 11  Word 12     Word 13  Word 14
# Topic 0  technology  service     product  testing
# Topic 1        test   hadoop  automation  process
# Topic 2    modeling  service     dynamic  quality

# %%
import pandas as pd

# Assuming df_topic_keywords is already created or you create an empty DataFrame
df_topic_keywords = pd.DataFrame()

# List of topics
Topics = ["Developer", "Data Science", "Data Engineer", "Business Analyst"]

# Assigning the list to a new column named "Topics" in the DataFrame
df_topic_keywords["Topics"] = Topics

# Printing the DataFrame
print(df_topic_keywords)
# Out:
#              Topics
# 0         Developer
# 1      Data Science
# 2     Data Engineer
# 3  Business Analyst
